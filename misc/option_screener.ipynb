# %% [markdown]
# # Option screener for buying call/put options
# Todo list:
# - [ ] Get companies with market cap under \\$50 million (later \\$300 million)
#     - [ ] individual stock price velow \\$2.50
# - [ ] optionsprofitcalculator
# - [ ] Get call/put buy option (ask) prices
#     - [ ] short term calls and long term puts are cheap
#     - [ ] puts more expensive than strike price

# %%
import os
import numpy as np
import pandas as pd
import finviz

# %% [markdown]
# ## Get company market cap info
# Use the stock screener finviz

# %%
#!pip install -U git+https://github.com/mariostoev/finviz

# %%
stock_list = finviz.Screener(filters=['cap_microunder','sh_opt_option'], table='Overview', order='marketcap')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 52/52 [00:16<00:00,  3.08it/s]

# %%
stock_df = pd.DataFrame(stock_list.data)
stock_df
# Out:
#        No. Ticker                      Company                  Sector  \
# 0        1   VINO  Gaucho Group Holdings, Inc.             Real Estate
# 1        2   BXRX             Baudax Bio, Inc.              Healthcare
# 2        3   APDN   Applied DNA Sciences, Inc.              Healthcare
# 3        4   KRBP      Kiromic BioPharma, Inc.              Healthcare
# 4        5   AUTO                AutoWeb, Inc.  Communication Services
# ...    ...    ...                          ...                     ...
# 1025  1026   KRON             Kronos Bio, Inc.              Healthcare
# 1026  1027   NWPX       Northwest Pipe Company             Industrials
# 1027  1028   ZYXI                  Zynex, Inc.              Healthcare
# 1028  1029   STRO        Sutro Biopharma, Inc.              Healthcare
# 1029  1030   ALTO       Alto Ingredients, Inc.         Basic Materials
#
#                             Industry Country Market Cap    P/E  Price  Change  \
# ...

# %%
stock_df['marketcap_mil'] = [float(x[:-1]) for x in stock_df['Market Cap']]
