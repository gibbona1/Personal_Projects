# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16, VGG19, ResNet50
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
import numpy as np
import pandas as pd
import os
from datetime import datetime
import time
import plotly
import umap.umap_ as umap
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import librosa

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, auc
import plotly.figure_factory as ff
from sklearn.preprocessing import OneHotEncoder
from data_set_params import DataSetParams
from scipy.io import wavfile
params = DataSetParams()

# %%
#import os
#
#def get_size(start_path = '.'):
#    total_size = 0
#    for dirpath, dirnames, filenames in os.walk(start_path):
#        for f in filenames:
#            fp = os.path.join(dirpath, f)
#            # skip if it is symbolic link
#            if not os.path.islink(fp):
#                print(fp)
#                print("\tsize:", os.path.getsize(fp))
#                total_size += os.path.getsize(fp)
#
#    return total_size
#total_size = get_size()

# %%
#print(total_size, 'bytes')
#print(total_size/(1024), 'kilobytes')
#print(total_size/(1024**2), 'megabytes')
#print(total_size/(1024**3), 'gigabytes')

# %%
#!pip install tensorflow

# %%
#!zip -r models_20220303.zip models

# %%
#!zip -r results.zip results

# %%
#! unzip ~/data/wav_clips.zip -d ~/data/

# %%
#! unzip ~/data/ff1010bird.zip -d ~/data/

# %%
#import matplotlib.pyplot as plt

# %%
#ff1010bird_meta = pd.read_csv('C:\\Users\\Anthony\\Downloads\\ff1010bird_metadata.csv')

# %%
#ff1010bird_meta

# %%
#b_dict = {0: 'not_bird',
#          1: 'bird'}

# %%
#os.mkdir(os.path.join(data_dir, 'bird'))
#os.mkdir(os.path.join(data_dir, 'not_bird'))

# %%
#os.rename(data_dir, "path/to/new/destination/for/file.foo")
#os.listdir(data_dir)

# %%
#for i,row in ff1010bird_meta.iterrows():
#    st_dir  = os.path.join(data_dir, str(row.itemid)+'.wav')
#    sav_dir = os.path.join(data_dir, b_dict[row.hasbird], str(row.itemid)+'.wav')
    #print(st_dir)
    #print()
#    os.rename(st_dir, sav_dir)
    #print(row.itemid)
    #print(row.hasbird)
    #print(str(row.itemid)+'.wav' in os.listdir(data_dir))
    #print()

# %%
#data_dir   = 'C:\\Users\\Anthony\\Downloads\\ff1010bird\\ff1010bird_wav\\wav'

# %%
#data_dir = pathlib.Path('/root/tensorflow_datasets/downloads/extracted/TAR_GZ.opihi.cs.uvic.ca_sound_music_speechbya81rFcWfLSW6ey5cynqyeq2qiePcL-7asMoNO6IQ0.tar.gz/music_speech')
#data_dir   = 'C:\\Users\\Anthony\\Downloads\\ff1010bird\\ff1010bird_wav\\wav'#
data_dir   = 'data/Richfield'#'dublin_dl_birds_split'#
data_dir   = 'richfield_birds_split'
categories = np.array(tf.io.gfile.listdir(data_dir))
categories = [category for category in categories if 'wav' not in category and '.TAG' not in category]
categories
# Out:
# ['Common Buzzard',
#  'Common Kestrel',
#  'Common Snipe',
#  'Eurasian Curlew',
#  'European Herring Gull',
#  'European Robin',
#  'Meadow Pipit',
#  'Mute Swan',
#  'Northern Lapwing',
#  'Rook',
#  'Tundra Swan',
#  'Tundra Swan (Bewicks)']

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)

    # Note: You'll use indexing here instead of tuple unpacking to enable this 
    # to work in a TensorFlow graph.
    return parts[-2]

# %%
def preload_vgg19(input_shape):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        Flatten(), # Flatten dimensions to for use in FC layers
        Dense(256, activation='relu'),
        Dropout(0.5), # Dropout layer to reduce overfitting
        Dense(64, activation='relu'),
        Dense(num_classes, activation='softmax') # Softmax for multiclass
    ])
    model.compile(
        optimizer = optimizers.Adam(learning_rate=0.0001),
        loss      = losses.SparseCategoricalCrossentropy(),
        metrics   = 'accuracy'
        )
    return model

# %%
def preload_vgg19_concat(input_shape, num_channels):
    from tensorflow.keras.layers import concatenate
    out_list   = []
    input_list = []
    for c in range(num_channels):
        input_a = layers.Input(shape=input_shape)
        input_list.append(input_a)
        #out_list.append(vgg_model.output)
    #vgg_model.summary()
    #x = vgg_model.output
    concatenated = concatenate(input_list, axis=-1)
    x = Flatten()(concatenated) # Flatten dimensions to for use in FC layers
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
    x = Dense(64, activation='relu')(x)
    x = Dense(num_classes, activation='softmax')(x) # Softmax for multiclass
    concat_vgg_model = Model(inputs=input_list, outputs=x)
    concat_vgg_model.compile(
        optimizer = optimizers.Adam(learning_rate=0.0001),
        loss      = losses.SparseCategoricalCrossentropy(),
        metrics   = 'accuracy'
        )
    return concat_vgg_model

# %%
def preload_vgg19_mfcc(input_shape, mfcc_shape):
    from tensorflow.keras.layers import concatenate
    input_list = [layers.Input(shape=input_shape), layers.Input(shape=mfcc_shape)]
    x = Flatten()(input_list[0]) # Flatten dimensions to for use in FC layers
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
    x = Dense(64, activation='relu')(x)
    concatenated = concatenate([x, input_list[1]], axis=-1)
    x = Dense(num_classes, activation='softmax')(concatenated) # Softmax for multiclass
    vgg_mfcc_model = Model(inputs=input_list, outputs=x)
    vgg_mfcc_model.compile(
        optimizer = optimizers.Adam(learning_rate=0.0001),
        loss      = losses.SparseCategoricalCrossentropy(),
        metrics   = 'accuracy'
        )
    return vgg_mfcc_model

# %%
def preload_vgg19_mfcc_umap(input_shape, umap_shape):
    from tensorflow.keras.layers import concatenate
    input_list = [layers.Input(shape=input_shape), layers.Input(shape=umap_shape)]
    x = Flatten()(input_list[0]) # Flatten dimensions to for use in FC layers
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
    x = Dense(64, activation='relu')(x)
    concatenated = concatenate([x, input_list[1]], axis=-1)
    x = Dense(num_classes, activation='softmax')(concatenated) # Softmax for multiclass
    vgg_mfcc_umap_model = Model(inputs=input_list, outputs=x)
    vgg_mfcc_umap_model.compile(
        optimizer = optimizers.Adam(learning_rate=0.0001),
        loss      = losses.SparseCategoricalCrossentropy(),
        metrics   = 'accuracy'
        )
    return vgg_mfcc_umap_model

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
#filenames = tf.io.gfile.glob('birds/*/*')
filenames = [filename for filename in filenames if 'wav' in filename]
filenames = tf.random.shuffle(filenames)

# %%
AUTOTUNE   = tf.data.experimental.AUTOTUNE
batch_size = 32
EPOCHS     = 50

# %%
num_classes = len(categories)

# %%
from tf_helpers import *

# %%
from sklearn.metrics import accuracy_score, precision_score, f1_score, roc_auc_score, top_k_accuracy_score
from sklearn.preprocessing import OneHotEncoder
from math import prod

# %%
def save_results(model, x_test, y_true, name, filename_run, index):
        #model.save('models/'+filename_run+'.h5')
    
        pred_lists = model.predict(x_test)
        y_pred     = np.argmax(pred_lists, axis=-1)
        pred_df    = pd.DataFrame(pred_lists, columns = categories)
        
        softmax_prediction_df = pred_df.apply(lambda x: np.exp(x - np.max(x))/np.exp(x - np.max(x)).sum(), axis=1)
        softmax_prediction_df.to_csv('results/'+filename_run+'_softmax_prediction_df.csv')
        
        cm = confusion_matrix(y_true, y_pred)
        fig = plotly_cm(cm, categories)
        fig.write_html('results/'+filename_run+'_confusion_matrix.html')
        
        num_trainable    = sum([prod(w.shape) for w in model.trainable_weights])
        num_nontrainable = sum([prod(w.shape) for w in model.non_trainable_weights])
        
        onehot_data = OneHotEncoder(sparse=False)
        onehot_data = onehot_data.fit_transform(np.array(y_true).reshape(len(y_true),1))
        roc_auc = [0]*num_classes
        
        for i in range(num_classes):
            roc_auc[i] = roc_auc_score(onehot_data[:, i], softmax_prediction_df.to_numpy()[:, i])
        
        name_df = pd.DataFrame(data={
                  'model':     name}, index=[index])
        metric_df = pd.DataFrame(data={
                  'top_1_acc': [accuracy_score(y_pred, y_true)],
                  #'top_5_acc': [top_k_accuracy_score(y_true, softmax_prediction_df, k=5)],
                  'precision': [precision_score(y_pred, y_true, average = 'weighted')], 
                  'f1':        [f1_score(y_pred, y_true, average = 'weighted')]
                 })
        param_df = pd.DataFrame(data={
                  'trainable_params': [num_trainable],
                  'nontrainable_params': [num_nontrainable]
                 })
        auc_df = pd.DataFrame([roc_auc], columns = ['auc_'+categories[i].replace(' ', '') for i in range(num_classes)])
        
        metric_df =  pd.concat([name_df, metric_df],axis=1)
        metric_df.to_csv('results/'+filename_run+'_metric_df.csv')
        
        param_df  =  pd.concat([name_df, param_df],axis=1)
        param_df.to_csv('results/'+filename_run+'_param_df.csv')
        
        auc_df    =  pd.concat([name_df, auc_df],axis=1)
        auc_df.to_csv('results/'+filename_run+'_auc_df.csv')

# %%
def load_vgg19(input_shape):
    vgg_model = VGG19(weights='imagenet', include_top=False, input_shape=input_shape)
    vgg_model.trainable = False ## Not trainable weights
    #vgg_model.summary()
    x = vgg_model.output
    x = Flatten()(x) # Flatten dimensions to for use in FC layers
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
    x = Dense(64, activation='relu')(x)
    x = Dense(num_classes, activation='softmax')(x) # Softmax for multiclass
    transfer_vgg_model = Model(inputs=vgg_model.input, outputs=x)
    transfer_vgg_model.compile(
        optimizer = optimizers.Adam(learning_rate=0.0001),
        loss      = losses.SparseCategoricalCrossentropy(),
        metrics   = 'accuracy'
        )
    return transfer_vgg_model

# %%
def load_vgg19_concat(input_shape, num_channels):
    from tensorflow.keras.layers import concatenate
    out_list   = []
    input_list = []
    for c in range(num_channels):
        vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
        vgg_model._name = vgg_model._name + str(c)
        for layer in vgg_model.layers:
            layer._name = layer._name + '_' + str(c)
        vgg_model.trainable = False ## Not trainable weights
        input_a = vgg_model.input
        input_list.append(input_a)
        out_list.append(vgg_model.output)
    #vgg_model.summary()
    #x = vgg_model.output
    concatenated = concatenate(out_list)
    x = Flatten()(concatenated) # Flatten dimensions to for use in FC layers
    x = Dense(256*num_channels, activation='relu')(x)
    x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
    x = Dense(64*num_channels, activation='relu')(x)
    x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
    x = Dense(64, activation='relu')(x)
    x = Dense(num_classes, activation='softmax')(x) # Softmax for multiclass
    concat_vgg_model = Model(inputs=input_list, outputs=x)
    concat_vgg_model.compile(
        optimizer = optimizers.Adam(learning_rate=0.0001),
        loss      = losses.SparseCategoricalCrossentropy(),
        metrics   = 'accuracy'
        )
    return concat_vgg_model

# %%
def load_resnet50(input_shape):
    resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    resnet_model.trainable = False ## Not trainable weights
    #resnet_model.summary()
    x = resnet_model.output
    x = Flatten()(x) # Flatten dimensions to for use in FC layers
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
    x = Dense(64, activation='relu')(x)
    x = Dense(num_classes, activation='softmax')(x) # Softmax for multiclass
    transfer_resnet_model = Model(inputs=resnet_model.input, outputs=x)
    transfer_resnet_model.compile(
        optimizer = optimizers.Adam(learning_rate=0.0001),
        loss      = losses.SparseCategoricalCrossentropy(),
        metrics   = 'accuracy'
        )
    return transfer_resnet_model

# %%
def load_resnet50_concat(input_shape, num_channels):
    from tensorflow.keras.layers import concatenate
    out_list   = []
    input_list = []
    for c in range(num_channels):
        resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
        resnet_model._name = resnet_model._name + str(c)
        for layer in resnet_model.layers:
            layer._name = layer._name + '_' + str(c)
        resnet_model.trainable = False ## Not trainable weights
        input_a = resnet_model.input
        input_list.append(input_a)
        out_list.append(resnet_model.output)
    #vgg_model.summary()
    #x = vgg_model.output
    concatenated = concatenate(out_list)
    x = Flatten()(concatenated) # Flatten dimensions to for use in FC layers
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
    x = Dense(64, activation='relu')(x)
    x = Dense(num_classes, activation='softmax')(x) # Softmax for multiclass
    concat_resnet_model = Model(inputs=input_list, outputs=x)
    concat_resnet_model.compile(
        optimizer = optimizers.Adam(learning_rate=0.0001),
        loss      = losses.SparseCategoricalCrossentropy(),
        metrics   = 'accuracy'
        )
    return concat_resnet_model

# %%
def main_model_run(filenames, index,
                   vgg19        = False,
                   vgg19_concat = False,
                   resnet50     = False,
                   resnet50_concat = False,
                   smallcnn = False,
                   concat   = False,
                   concat2  = False,
                   concat3  = False,
                   concat4  = False,
                   vgg_mfcc = False,
                   vgg_umap = False,
                   vgg_pca  = False,
                   smallcnn_mfcc = False):
    print("Index: ", index)
    
    filenames   = tf.random.shuffle(filenames)
    all_labs    = [get_label(y).numpy().decode() for y in filenames]
    filename_df = pd.DataFrame({'name': filenames.numpy(),
                                'label': all_labs})
    
    train, rest_df = train_test_split(filename_df, test_size=0.2, stratify=filename_df[['label']])
    val, test      = train_test_split(rest_df, test_size=0.5, stratify = rest_df[['label']])
    
    train_files = tf.random.shuffle(train['name'])
    val_files   = tf.random.shuffle(val['name'])
    test_files  = tf.random.shuffle(test['name'])

    def concat_xy(ds):
            x_tmp  = [x for x,_ in ds]
            x_tmp  = tf.stack(x_tmp)
            xs_tmp = tf.unstack(x_tmp, axis=-1)
            xs_tmp = [tf.expand_dims(x_ind, axis=-1) for x_ind in xs_tmp]
            y      = np.array([y for _,y in ds])
            return xs_tmp, y
    
    print('Getting data')
    choices  = ['Mod']
    train_ds = preprocess_dataset(train_files, choices, categories, req_width=750, resize = 4, spec_norm = True)
    val_ds   = preprocess_dataset(val_files,   choices, categories, req_width=750, resize = 4, spec_norm = True)
    test_ds  = preprocess_dataset(test_files,  choices, categories, req_width=750, resize = 4, spec_norm = True)
    
    train_ds_vgg = preprocess_dataset(train_files, choices, categories, req_width=750, single_to_rgb = True, resize = 4, spec_norm = True)
    val_ds_vgg   = preprocess_dataset(val_files,   choices, categories, req_width=750, single_to_rgb = True, resize = 4, spec_norm = True)
    test_ds_vgg  = preprocess_dataset(test_files,  choices, categories, req_width=750, single_to_rgb = True, resize = 4, spec_norm = True)
    
    X_train_vgg = np.array([x for x,y in train_ds_vgg])
    X_val_vgg   = np.array([x for x,y in val_ds_vgg])
    X_test_vgg  = np.array([x for x,y in test_ds_vgg])
    
    y_train = np.array([y for _,y in train_ds_vgg])
    y_val   = np.array([y for _,y in val_ds_vgg])
    y_test  = np.array([y for _,y in test_ds_vgg])
    
    if vgg_mfcc or smallcnn_mfcc or vgg_umap or vgg_pca:
        print("MFCC features")
        def get_features(waveform, sr):
            #audio = np.array(audio)#.numpy()
            waveform = waveform[:sr]  # analyze just first second
            S = librosa.feature.melspectrogram(waveform, sr=sr, n_mels=128)
            log_S = librosa.amplitude_to_db(S, ref=np.max)
            mfcc  = librosa.feature.mfcc(S=log_S, n_mfcc=13)
            delta_mfcc  = librosa.feature.delta(mfcc, mode='nearest')
            delta2_mfcc = librosa.feature.delta(mfcc, order=2, mode='nearest')
            feature_vector = np.concatenate((np.mean(mfcc,1), np.mean(delta_mfcc,1), np.mean(delta2_mfcc,1)))
            feature_vector = (feature_vector-np.mean(feature_vector)) / (np.std(feature_vector)+np.finfo(np.float32).eps)
            return feature_vector
        
        def get_pca(features):
            pca = PCA(n_components=5)
            transformed = pca.fit(features).transform(features)
            scaler = MinMaxScaler()
            scaler.fit(transformed)
            return scaler.transform(transformed)

        def get_mfcc_features(file_names):
            feature_vectors = []
            sound_paths     = []
            for i,f in enumerate(file_names):
                #f = f.numpy()
                if i % 100 == 0:
                    print("get %d of %d = %s"%(i+1, len(file_names), f))
                try:
                    #print(f)
                    #print(type(f))
                    y, sr = librosa.load(f)
                    #print(len(y))
                    #print(len(y)<2)
                    if len(y) < 2:
                        print("error loading %s" % f)
                        continue
                    feat = get_features(y, sr)
                    #print(feat)
                    feature_vectors.append(feat)
                    sound_paths.append(f)
                except:
                    print("error loading %s" % f)

            print("calculated %d feature vectors"%len(feature_vectors))
            return np.array(feature_vectors)
        
        train_files = [f.decode().replace('\\', '/') for f in train['name'].to_list()]
        val_files   = [f.decode().replace('\\', '/') for f in val['name'].to_list()]
        test_files  = [f.decode().replace('\\', '/') for f in test['name'].to_list()]
        
        train_mfcc = get_mfcc_features(train_files)
        val_mfcc   = get_mfcc_features(val_files)
        test_mfcc  = get_mfcc_features(test_files)
        
        #exclude_idx = np.unique(np.where(np.isnan(test_mfcc))[0])
        #feature_sub = [feature_vectors[i] for i in range(len(feature_vectors)) if i not in exclude_idx]
        #class_sub   = [class_smp[i] for i in range(len(class_smp)) if i not in exclude_idx]
        
        #tsne_embed = TSNE(n_components=2, learning_rate=150, perplexity=30, verbose=2, angle=0.1).fit(train_mfcc)
        
        umap_embed = umap.UMAP(n_neighbors=5, random_state=42, n_components=10).fit(train_mfcc)
        
        umap_embed_train = umap_embed.embedding_
        umap_embed_val   = umap_embed.transform(val_mfcc)
        umap_embed_test  = umap_embed.transform(test_mfcc)
        #test_embedding = trans.transform(X_test)
        #pca_embed  = get_pca(feature_sub)
        pca_embed = PCA(n_components=5).fit(train_mfcc)
        
        pca_embed_train = pca_embed.embedding_
        
        scaler = MinMaxScaler()
        scaler.fit(pca_embed_train)
        
        pca_embed_train = scaler.transform(pca_embed_train)
        
        pca_embed_val   = scaler.transform(pca_embed.transform(val_mfcc))
        pca_embed_test  = scaler.transform(pca_embed.transform(test_mfcc))
        #transformed = pca.fit(features).transform(features)
        #scaler = MinMaxScaler()
        #scaler.fit(transformed)
        #return scaler.transform(transformed)

    print("Done")
    
    
    #concat_shape     = X_train_mult[0].shape[1:]
    #vgg_concat_shape = X_train_mult_vgg[0].shape[1:]
    
    for spec, _ in train_ds.take(1):
        input_shape = spec.shape
    for spec, _ in train_ds_vgg.take(1):
        input_shape_vgg = spec.shape
        #print(tf.math.reduce_std(spec[:,:,0]))
        #print(tf.math.reduce_std(spec[:,:,1]))
        #print(tf.math.reduce_std(spec[:,:,2]))
        
    train_ds = train_ds.batch(batch_size)
    val_ds   = val_ds.batch(batch_size)
    test_ds  = test_ds.batch(batch_size)
    train_ds = train_ds.cache().prefetch(AUTOTUNE)
    val_ds   = val_ds.cache().prefetch(AUTOTUNE)
    test_ds  = test_ds.cache().prefetch(AUTOTUNE)
    
    if data_dir.startswith("C:"):
        sv_dir = '_'.join(data_dir.split(os.path.sep)[1:-2])
    else:
        sv_dir = data_dir
    filename_idx = datetime.now().strftime("%Y%m%d-%H%M%S").replace('-', '_')+'_'+sv_dir.replace('/','_')+'_'+str(index)
    results_folder = 'results'
    if not os.path.isdir(results_folder):
        os.mkdir(results_folder)
    
    train.to_csv(results_folder+'/'+filename_idx+'_filenames_train.csv')
    val.to_csv(results_folder+'/'+filename_idx+'_filenames_val.csv')
    test.to_csv(results_folder+'/'+filename_idx+'_filenames_test.csv')
    #np.save('results/'+filename_idx+'_filenames.npy', filenames.numpy())
    
    #this will save the model performing best on val accuracy
    def best_model_cp():
        checkpoint = tf.keras.callbacks.ModelCheckpoint(
            "best_model",
            monitor = "val_accuracy",
            mode    = "max",
            save_best_only = True,
            save_weights_only = True)
        return checkpoint
    
    ## Load and run models
    
    if vgg19 or vgg19_concat:
        vgg_model = VGG19(weights='imagenet', include_top=False, input_shape=input_shape_vgg)
    #VGG19
    if vgg19:
        print("VGG19")
        tmp_vgg_trainX = vgg_model.predict(X_train_vgg)
        tmp_vgg_valX   = vgg_model.predict(X_val_vgg)
        tmp_vgg_testX  = vgg_model.predict(X_test_vgg)
        model = preload_vgg19(tmp_vgg_trainX.shape[1:])
        model_name   = 'vgg19'
        filename_run = filename_idx+'_'+model_name
        print(model.summary())
        history = model.fit(tmp_vgg_trainX, y_train,
                            validation_data = (tmp_vgg_valX, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, tmp_vgg_testX, y_test, model_name, filename_run, index)
    
    
    #VGG19_concat
    if vgg19_concat:
        print("VGG19_concat")
        tmp_X_train_mult_vgg = [vgg_model.predict(xt) for xt in X_train_mult_vgg]
        tmp_X_val_mult_vgg   = [vgg_model.predict(xt) for xt in X_val_mult_vgg]
        tmp_X_test_mult_vgg  = [vgg_model.predict(xt) for xt in X_test_mult_vgg]
        #model    = load_vgg19_concat(vgg_concat_shape, num_channels)
        model_name   = 'vgg19_concat'
        filename_run = filename_idx+'_'+model_name
        model = preload_vgg19_concat(tmp_X_train_mult_vgg[0].shape[1:], num_channels)
        print(model.summary())
        history = model.fit(tmp_X_train_mult_vgg, y_train,
                            validation_data = (tmp_X_val_mult_vgg, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, tmp_X_test_mult_vgg, y_test, model_name, filename_run, index)


    #ResNet50
    if resnet50:
        print("ResNet50")
        model = load_resnet50(input_shape_vgg)
        model_name   = 'resnet50'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(train_ds,
                            validation_data = val_ds,
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, test_ds, y_test, model_name, filename_run, index)
    
    #ResNet50_concat
    if resnet50_concat:
        print("ResNet50_concat")
        model    = load_resnet50_concat(vgg_concat_shape, num_channels)
        model_name   = 'resnet50_concat'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(X_train_vgg, y_train,
                            validation_data = (X_val_vgg, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, X_test_vgg, y_test, model_name, filename_run, index)

    #small_cnn
    if smallcnn:
        print("Small CNN")
        model  = main_cnn(input_shape, num_classes)
        model_name   = 'smallcnn'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(train_ds,
                            validation_data = val_ds,
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, test_ds, y_test, model_name, filename_run, index)
    
    #concat
    if concat:
        print("Concat")
        model        = concat_model(concat_shape, num_channels, num_classes)
        model_name   = 'concat'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(X_train_mult, y_train,
                            validation_data = (X_val_mult, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, X_test_mult, y_test, model_name, filename_run, index)

    #concat2
    if concat2:
        print("Concat2")
        model     = concat_model2(concat_shape, num_channels, num_classes)
        model_name   = 'concat2'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(X_train_mult, y_train,
                            validation_data = (X_val_mult, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, X_test_mult, y_test, model_name, filename_run, index)
    
    #concat3
    if concat3:
        print("Concat3")
        model     = concat_model3(concat_shape, num_channels, num_classes)
        model_name   = 'concat3'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(X_train_mult, y_train,
                            validation_data = (X_val_mult, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, X_test_mult, y_test, model_name, filename_run, index)
    
    #concat4
    if concat4:
        print("Concat4")
        model     = concat_model4(concat_shape, num_channels, num_classes)
        model_name   = 'concat4'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(X_train_mult, y_train,
                            validation_data = (X_val_mult, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, X_test_mult, y_test, model_name, filename_run, index)

    if vgg_mfcc:
        print("VGG MFCC")
        
        model        = preload_vgg19_mfcc(tmp_vgg_trainX.shape[1:], train_mfcc.shape[-1])
        #model        = concat_model4(concat_shape, num_channels, num_classes)
        model_name   = 'vgg_mfcc'
        filename_run = filename_idx+'_'+model_name

        history = model.fit([tmp_vgg_trainX, train_mfcc], y_train,
                            validation_data = ([tmp_vgg_valX, val_mfcc], y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, [tmp_vgg_testX, test_mfcc], y_test, model_name, filename_run, index)
        
    if vgg_umap:
        print("VGG MFCC Umap")
        
        model        = preload_vgg19_mfcc_umap(tmp_vgg_trainX.shape[1:], umap_embed_train.shape[-1])
        #model        = concat_model4(concat_shape, num_channels, num_classes)
        model_name   = 'vgg_mfcc_umap'
        filename_run = filename_idx+'_'+model_name

        history = model.fit([tmp_vgg_trainX, umap_embed_train], y_train,
                            validation_data = ([tmp_vgg_valX, umap_embed_val], y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, [tmp_vgg_testX, umap_embed_test], y_test, model_name, filename_run, index)
        
    if vgg_pca:
        print("VGG MFCC PCA")
        
        model        = preload_vgg19_mfcc_umap(tmp_vgg_trainX.shape[1:], pca_embed_train.shape[-1])
        #model        = concat_model4(concat_shape, num_channels, num_classes)
        model_name   = 'vgg_mfcc_pca'
        filename_run = filename_idx+'_'+model_name

        history = model.fit([tmp_vgg_trainX, pca_embed_train], y_train,
                            validation_data = ([tmp_vgg_valX, pca_embed_val], y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, [tmp_vgg_testX, pca_embed_test], y_test, model_name, filename_run, index)
           
    #if smallcnn_mfcc:

# %% [markdown]
# ## Evaluate

# %%
tic = time.time()

# %%
len(filenames)
# Out:
# 2840

# %%
#for i in range(1,5+1):
#    main_model_run(filenames[:2000], i,
#                   vgg19        = True,
                   #vgg19_concat = True
                   #resnet50     = True,
                   #resnet50_concat = True,
                   #smallcnn     = True,
                   #concat   = True
                  #)
                   #concat2  = True,
                   #concat3  = True,
                   #concat4  = True,
#                    vgg_mfcc = True,
#                    vgg_umap = True,
#                    vgg_pca  = True)#,
                    #smallcnn_mfcc = True)
#    print("Time so far:", time.time() - tic)
# Out:
# Index:  1
# Getting data
# MFCC features
# get 1 of 1600 = richfield_birds_split/Northern Lapwing/xc654703_left_start_1_30.wav
# get 101 of 1600 = richfield_birds_split/Tundra Swan/xc591621_left_start_2_15.wav
# get 201 of 1600 = richfield_birds_split/Rook/xc631334_left_start_10_15.wav
# get 301 of 1600 = richfield_birds_split/Common Buzzard/xc638316_left_start_1_0.wav
# get 401 of 1600 = richfield_birds_split/Mute Swan/xc617727_left_start_3_15.wav
# get 501 of 1600 = richfield_birds_split/Tundra Swan/xc135447_left_start_0_45.wav
# get 601 of 1600 = richfield_birds_split/Common Snipe/xc637615_left_start_0_15.wav
# get 701 of 1600 = richfield_birds_split/Common Buzzard/xc665227_left_start_0_45.wav
# get 801 of 1600 = richfield_birds_split/Common Buzzard/xc591197_left_start_0_45.wav
# get 901 of 1600 = richfield_birds_split/European Robin/xc670910_left_start_0_0.wav
# get 1001 of 1600 = richfield_birds_split/Common Kestrel/xc478287_start_1_15.wav
# get 1101 of 1600 = richfield_birds_split/Tundra Swan/xc650564_left_start_0_15.wav
# get 1201 of 1600 = richfield_birds_split/Mute Swan/xc640259_left_start_0_15.wav
# get 1301 of 1600 = richfield_birds_split/Mute Swan/xc570981_start_0_0.wav
# get 1401 of 1600 = richfield_birds_split/Common Kestrel/xc526998_left_start_0_45.wav
# get 1501 of 1600 = richfield_birds_split/Mute Swan/xc623770_left_start_0_0.wav
# calculated 1600 feature vectors
# get 1 of 200 = richfield_birds_split/Common Buzzard/xc581056_left_start_0_45.wav
# get 101 of 200 = richfield_birds_split/European Robin/xc678917_left_start_0_0.wav
# calculated 200 feature vectors
# get 1 of 200 = richfield_birds_split/Common Kestrel/xc608709_left_start_0_0.wav
# get 101 of 200 = richfield_birds_split/European Herring Gull/xc623691_left_start_0_0.wav
# calculated 200 feature vectors
# Done
# VGG19
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 47104)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               12058880
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                780
# =================================================================
# Total params: 12,076,108
# Trainable params: 12,076,108
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 50/50 [==============================] - 2s 36ms/step - loss: 2.3000 - accuracy: 0.2625 - val_loss: 1.7695 - val_accuracy: 0.4150
# Epoch 2/50
# 50/50 [==============================] - 2s 33ms/step - loss: 1.7424 - accuracy: 0.4294 - val_loss: 1.4819 - val_accuracy: 0.5350
# Epoch 3/50
# 50/50 [==============================] - 2s 33ms/step - loss: 1.5114 - accuracy: 0.5206 - val_loss: 1.3747 - val_accuracy: 0.5650
# Epoch 4/50
# 50/50 [==============================] - 2s 34ms/step - loss: 1.3422 - accuracy: 0.5656 - val_loss: 1.1560 - val_accuracy: 0.6600
# Epoch 5/50
# 50/50 [==============================] - 2s 33ms/step - loss: 1.2445 - accuracy: 0.6037 - val_loss: 1.1492 - val_accuracy: 0.6550
# Epoch 6/50
# 50/50 [==============================] - 2s 34ms/step - loss: 1.1282 - accuracy: 0.6419 - val_loss: 1.0722 - val_accuracy: 0.6750
# Epoch 7/50
# 50/50 [==============================] - 2s 33ms/step - loss: 1.0881 - accuracy: 0.6475 - val_loss: 1.0049 - val_accuracy: 0.7200
# Epoch 8/50
# 50/50 [==============================] - 2s 33ms/step - loss: 0.9946 - accuracy: 0.6825 - val_loss: 0.9975 - val_accuracy: 0.6900
# Epoch 9/50
# 50/50 [==============================] - 2s 33ms/step - loss: 0
50
# 50/50 [==============================] - 2s 33ms/step - loss: 0.4577 - accuracy: 0.8656 - val_loss: 0.8770 - val_accuracy: 0.7200
# Epoch 26/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.4401 - accuracy: 0.8631 - val_loss: 0.8215 - val_accuracy: 0.7400
# Epoch 27/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.4055 - accuracy: 0.8813 - val_loss: 0.8103 - val_accuracy: 0.7600
# Epoch 28/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.3783 - accuracy: 0.8900 - val_loss: 0.8394 - val_accuracy: 0.7750
# Epoch 29/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.3746 - accuracy: 0.8863 - val_loss: 0.8291 - val_accuracy: 0.7400
# Epoch 30/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.3748 - accuracy: 0.8850 - val_loss: 0.8003 - val_accuracy: 0.7650
# Epoch 31/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.3344 - accuracy: 0.9038 - val_loss: 0.8271 - val_accuracy: 0.7650
# Epoch 32/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.3463 - accuracy: 0.8963 - val_loss: 0.8033 - val_accuracy: 0.7550
# Epoch 33/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.3247 - accuracy: 0.8969 - val_loss: 0.8512 - val_accuracy: 0.7600
# Epoch 34/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2965 - accuracy: 0.9137 - val_loss: 0.8258 - val_accuracy: 0.7450
# Epoch 35/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.2986 - accuracy: 0.9137 - val_loss: 0.8371 - val_accuracy: 0.7600
# Epoch 36/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.3259 - accuracy: 0.9013 - val_loss: 0.8201 - val_accuracy: 0.7450
# Epoch 37/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2760 - accuracy: 0.9200 - val_loss: 0.8361 - val_accuracy: 0.7550
# Epoch 38/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.2836 - accuracy: 0.9100 - val_loss: 0.8364 - val_accuracy: 0.7750
# Epoch 39/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2780 - accuracy: 0.9106 - val_loss: 0.8236 - val_accuracy: 0.7650
# Epoch 40/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2626 - accuracy: 0.9212 - val_loss: 0.7893 - val_accuracy: 0.7800
# Epoch 41/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2501 - accuracy: 0.9356 - val_loss: 0.8769 - val_accuracy: 0.7600
# Epoch 42/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2504 - accuracy: 0.9250 - val_loss: 0.8512 - val_accuracy: 0.7500
# Epoch 43/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.2335 - accuracy: 0.9300 - val_loss: 0.8085 - val_accuracy: 0.7900
# Epoch 44/50
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2216 - accuracy: 0.9344 - val_loss: 0.8575 - val_accuracy: 0.7700
# Epoch 45/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2342 - accuracy: 0.9312 - val_loss: 0.7791 - val_accuracy: 0.7700
# Epoch 46/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2004 - accuracy: 0.9500 - val_loss: 0.8464 - val_accuracy: 0.7750
# Epoch 47/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.2043 - accuracy: 0.9431 - val_loss: 0.8877 - val_accuracy: 0.7750
# Epoch 48/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.2061 - accuracy: 0.9369 - val_loss: 0.8901 - val_accuracy: 0.7750
# Epoch 49/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.2006 - accuracy: 0.9431 - val_loss: 0.8215 - val_accuracy: 0.7800
# Epoch 50/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.2027 - accuracy: 0.9444 - val_loss: 0.9518 - val_accuracy: 0.7600
# Time so far: 1884.4826636314392
# Index:  2
# Getting data
# MFCC features
# get 1 of 1600 = richfield_birds_split/European Herring Gull/xc485307_start_0_0.wav
# get 101 of 1600 = richfield_birds_split/Common Kestrel/xc672833_start_2_30.wav
# get 201 of 1600 = richfield_birds_split/Tundra Swan/xc128225_start_1_15.wav
# get 301 of 1600 = richfield_birds_split/Northern Lapwing/xc650809_left_start_0_0.wav
# get 401 of 1600 = richfield_birds_split/Common Kestrel/xc636321_left_start_1_45.wav
# get 501 of 1600 = richfield_birds_split/Mute Swan/xc640260_left_start_0_15.wav
# get 601 of 1600 = richfield_birds_split/European Herring Gull/xc599934_left_start_0_15.wav
# get 701 of 1600 = richfield_birds_split/Meadow Pipit/xc511712_left_start_0_0.wav
# get 801 of 1600 = richfield_birds_split/Tundra Swan (Bewicks)/xc102851_start_0_15.wav
# get 901 of 1600 = richfield_birds_split/Meadow Pipit/xc651319_start_1_15.wav
# get 1001 of 1600 = richfield_birds_split/European Herring Gull/xc483105_start_0_45.wav
# get 1101 of 1600 = richfield_birds_split/Tundra Swan (Bewicks)/xc280868_left_start_1_0.wav
# get 1201 of 1600 = richfield_birds_split/Rook/xc608750_left_start_0_0.wav
# get 1301 of 1600 = richfield_birds_split/Northern Lapwing/xc678862_left_start_1_30.wav
# get 1401 of 1600 = richfield_birds_split/Tundra Swan/xc535039_start_0_15.wav
# get 1501 of 1600 = richfield_birds_split/Northern Lapwing/xc678087_left_start_1_45.wav
# calculated 1600 feature vectors
# get 1 of 200 = richfield_birds_split/Common Buzzard/xc660623_left_start_2_0.wav
# get 101 of 200 = richfield_birds_split/European Herring Gull/xc611006_left_start_1_0.wav
# calculated 200 feature vectors
# get 1 of 200 = richfield_birds_split/Common Kestrel/xc672836_start_1_30.wav
# get 101 of 200 = richfield_birds_split/Mute Swan/xc640267_left_start_2_0.wav
# calculated 200 feature vectors
# Done
# VGG19
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 47104)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               12058880
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_11 (Dense)             (None, 12)                780
# =================================================================
# Total params: 12,076,108
# Trainable params: 12,076,108
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 50/50 [==============================] - 2s 43ms/step - loss: 2.2483 - accuracy: 0.2756 - val_loss: 1.7055 - val_accuracy: 0.4950
# Epoch 2/50
# 50/50 [==============================] - 2s 34ms/step - loss: 1.7546 - accuracy: 0.4200 - val_loss: 1.4209 - val_accuracy: 0.5900
# Epoch 3/50
# 50/50 [==============================] - 2s 34ms/step - loss: 1.5325 - accuracy: 0.5025 - val_loss: 1.3166 - val_accuracy: 0.6200
# Epoch 4/50
# 50/50 [==============================] - 2s 34ms/step - loss: 1.3952 - accuracy: 0.5375 - val_loss: 1.2462 - val_accuracy: 0.6050
# Epoch 5/50
# 50/50 [==============================] - 2s 34ms/step - loss: 1.3045 - accuracy: 0.5675 - val_loss: 1.1255 - val_accuracy: 0.6500
# Epoch 6/50
# 50/50 [==============================] - 2s 34ms/step - loss: 1.1636 - accuracy: 0.6206 - val_loss: 1.0905 - val_accuracy: 0.6900
# Epoch 7/50
# 50/50 [==============================] - 2s 34ms/step - loss: 1.1052 - accuracy: 0.6288 - val_loss: 1.1543 - val_accuracy: 0.6400
# Epoch 8/50
# 50/50 [==============================] - 2s 34ms/step - loss: 1.0617 - accuracy: 0.6550 - val_loss: 1.0357 - val_accuracy: 0.6550
# Epoch 9/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.9660 - accuracy: 0.6862 - val_loss: 0.9407 - val_accuracy: 0.7250
# Epoch 10/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.9181 - accuracy: 0.7069 - val_loss: 0.9440 - val_accuracy: 0.7150
# Epoch 11/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.8713 - accuracy: 0.7231 - val_loss: 0.9228 - val_accuracy: 0.7150
# Epoch 12/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.8090 - accuracy: 0.7444 - val_loss: 0.8895 - val_accuracy: 0.7450
# Epoch 13/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.7657 - accuracy: 0.7575 - val_loss: 0.8603 - val_accuracy: 0.6950
# Epoch 14/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.7370 - accuracy: 0.7650 - val_loss: 0.8608 - val_accuracy: 0.7300
# Epoch 15/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.
50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.1878 - accuracy: 0.9431 - val_loss: 0.6988 - val_accuracy: 0.8000
# Epoch 47/50
# 50/50 [==============================] - 2s 42ms/step - loss: 0.2145 - accuracy: 0.9306 - val_loss: 0.7594 - val_accuracy: 0.8000
# Epoch 48/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.1720 - accuracy: 0.9494 - val_loss: 0.7670 - val_accuracy: 0.7900
# Epoch 49/50
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1711 - accuracy: 0.9538 - val_loss: 0.7447 - val_accuracy: 0.7900
# Epoch 50/50
# 50/50 [==============================] - 2s 45ms/step - loss: 0.1701 - accuracy: 0.9456 - val_loss: 0.7702 - val_accuracy: 0.7950
# VGG MFCC
# Epoch 1/50
# 50/50 [==============================] - 2s 39ms/step - loss: 2.2783 - accuracy: 0.2644 - val_loss: 1.7816 - val_accuracy: 0.5150
# Epoch 2/50
# 50/50 [==============================] - 2s 35ms/step - loss: 1.8335 - accuracy: 0.3963 - val_loss: 1.5809 - val_accuracy: 0.5450
# Epoch 3/50
# 50/50 [==============================] - 2s 36ms/step - loss: 1.5456 - accuracy: 0.5006 - val_loss: 1.3657 - val_accuracy: 0.6350
# Epoch 4/50
# 50/50 [==============================] - 2s 35ms/step - loss: 1.4000 - accuracy: 0.5500 - val_loss: 1.2871 - val_accuracy: 0.6350
# Epoch 5/50
# 50/50 [==============================] - 2s 36ms/step - loss: 1.2776 - accuracy: 0.5944 - val_loss: 1.2232 - val_accuracy: 0.6300
# Epoch 6/50
# 50/50 [==============================] - 2s 36ms/step - loss: 1.1939 - accuracy: 0.6112 - val_loss: 1.1284 - val_accuracy: 0.6850
# Epoch 7/50
# 50/50 [==============================] - 2s 37ms/step - loss: 1.1087 - accuracy: 0.6475 - val_loss: 1.0719 - val_accuracy: 0.6750
# Epoch 8/50
# 50/50 [==============================] - 2s 36ms/step - loss: 1.0245 - accuracy: 0.6619 - val_loss: 1.0327 - val_accuracy: 0.7300
# Epoch 9/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.9547 - accuracy: 0.6856 - val_loss: 0.9552 - val_accuracy: 0.7300
# Epoch 10/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.9072 - accuracy: 0.7119 - val_loss: 0.9313 - val_accuracy: 0.7300
# Epoch 11/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.8321 - accuracy: 0.7419 - val_loss: 0.8920 - val_accuracy: 0.7500
# Epoch 12/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.8209 - accuracy: 0.7437 - val_loss: 0.8918 - val_accuracy: 0.7550
# Epoch 13/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.7833 - accuracy: 0.7600 - val_loss: 0.8880 - val_accuracy: 0.7250
# Epoch 14/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.7126 - accuracy: 0.7731 - val_loss: 0.8842 - val_accuracy: 0.7450
# Epoch 15/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.6816 - accuracy: 0.7994 - val_loss: 0.8294 - val_accuracy: 0.7550
# Epoch 16/50
# 50/50 [==============================] - ETA: 0s - loss: 0.6489 - accuracy: 0.79 - 2s 36ms/step - loss: 0.6538 - accuracy: 0.7956 - val_loss: 0.7997 - val_accuracy: 0.7600
# Epoch 17/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.6171 - accuracy: 0.8031 - val_loss: 0.8379 - val_accuracy: 0.7700
# Epoch 18/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.5768 - accuracy: 0.8269 - val_loss: 0.7801 - val_accuracy: 0.7700
# Epoch 19/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0
50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.4509 - accuracy: 0.8606 - val_loss: 0.7649 - val_accuracy: 0.7550
# Epoch 27/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.4392 - accuracy: 0.8581 - val_loss: 0.7501 - val_accuracy: 0.7800
# Epoch 28/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.3873 - accuracy: 0.8806 - val_loss: 0.7569 - val_accuracy: 0.7750
# Epoch 29/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.3786 - accuracy: 0.8856 - val_loss: 0.8133 - val_accuracy: 0.7700
# Epoch 30/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.4034 - accuracy: 0.8737 - val_loss: 0.7348 - val_accuracy: 0.7800
# Epoch 31/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.3627 - accuracy: 0.8900 - val_loss: 0.7248 - val_accuracy: 0.8150
# Epoch 32/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.3166 - accuracy: 0.9050 - val_loss: 0.7422 - val_accuracy: 0.7750
# Epoch 33/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.3411 - accuracy: 0.9031 - val_loss: 0.7148 - val_accuracy: 0.8000
# Epoch 34/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.3278 - accuracy: 0.8994 - val_loss: 0.7248 - val_accuracy: 0.8050
# Epoch 35/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.3189 - accuracy: 0.9038 - val_loss: 0.7368 - val_accuracy: 0.8050
# Epoch 36/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.2961 - accuracy: 0.9050 - val_loss: 0.7069 - val_accuracy: 0.7950
# Epoch 37/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2743 - accuracy: 0.9137 - val_loss: 0.7359 - val_accuracy: 0.7850
# Epoch 38/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.2687 - accuracy: 0.9250 - val_loss: 0.7201 - val_accuracy: 0.7850
# Epoch 39/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.2718 - accuracy: 0.9262 - val_loss: 0.7041 - val_accuracy: 0.8050
# Epoch 40/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.2595 - accuracy: 0.9237 - val_loss: 0.7412 - val_accuracy: 0.8000
# Epoch 41/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.2445 - accuracy: 0.9294 - val_loss: 0.7184 - val_accuracy: 0.8100
# Epoch 42/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.2445 - accuracy: 0.9306 - val_loss: 0.6872 - val_accuracy: 0.8200
# Epoch 43/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.2331 - accuracy: 0.9294 - val_loss: 0.7652 - val_accuracy: 0.7800
# Epoch 44/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.2256 - accuracy: 0.9306 - val_loss: 0.7654 - val_accuracy: 0.8050
# Epoch 45/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.2336 - accuracy: 0.9281 - val_loss: 0.7015 - val_accuracy: 0.7950
# Epoch 46/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.1944 - accuracy: 0.9500 - val_loss: 0.7508 - val_accuracy: 0.7850
# Epoch 47/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2083 - accuracy: 0.9381 - val_loss: 0.7386 - val_accuracy: 0.7950
# Epoch 48/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.1833 - accuracy: 0.9475 - val_loss: 0.8065 - val_accuracy: 0.7850
# Epoch 49/50
# 50/50 [==============================] - 2s 34ms/step - loss: 0.1675 - accuracy: 0.9513 - val_loss: 0.7029 - val_accuracy: 0.8300
# Epoch 50/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.1718 - accuracy: 0.9488 - val_loss: 0.7392 - val_accuracy: 0.8100
# Time so far: 3824.048456430435
# Index:  3
# Getting data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-f731e01b4609> in <module>
#       1 for i in range(1,5+1):
# ----> 2     main_model_run(filenames[:2000], i,
#       3                    vgg19        = True,
#       4                    #vgg19_concat = True
#       5                    #resnet50     = True,
#
# <ipython-input-34-1b522092c7ad> in main_model_run(filenames, index, vgg19, vgg19_concat, resnet50, resnet50_concat, smallcnn, concat, concat2, concat3, concat4, vgg_mfcc, vgg_umap, smallcnn_mfcc)
#      44     test_ds_vgg  = preprocess_dataset(test_files,  choices, categories, req_width=750, single_to_rgb = True, resize = 4, spec_norm = True)
#      45
# ---> 46     X_train_vgg = np.array([x for x,y in train_ds_vgg])
#      47     X_val_vgg   = np.array([x for x,y in val_ds_vgg])
#      48     X_test_vgg  = np.array([x for x,y in test_ds_vgg])
#
# <ipython-input-34-1b522092c7ad> in <listcomp>(.0)
#      44     test_ds_vgg  = preprocess_dataset(test_files,  choices, categories, req_width=750, single_to_rgb = True, resize = 4, spec_norm = True)
#      45
# ---> 46     X_train_vgg = np.array([x for x,y in train_ds_vgg])
#      47     X_val_vgg   = np.array([x for x,y in val_ds_vgg])
#      48     X_test_vgg  = np.array([x for x,y in test_ds_vgg])
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in __next__(self)
#     759   def __next__(self):
#     760     try:
# --> 761       return self._next_internal()
#     762     except errors.OutOfRangeError:
#     763       raise StopIteration
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in _next_internal(self)
#     742     # to communicate that there is no more data to iterate over.
#     743     with context.execution_mode(context.SYNC):
# --> 744       ret = gen_dataset_ops.iterator_get_next(
#     745           self._iterator_resource,
#     746           output_types=self._flat_output_types,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    2720   if tld.is_eager:
#    2721     try:
# -> 2722       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2723         _ctx, "IteratorGetNext", name, iterator, "output_types", output_types,
#    2724         "output_shapes", output_shapes)
#
# KeyboardInterrupt:

# %%
filenames   = tf.random.shuffle(filenames)
all_labs    = [get_label(y).numpy().decode() for y in filenames]
filename_df = pd.DataFrame({'name': filenames.numpy(),
                            'label': all_labs})

train, rest_df = train_test_split(filename_df, test_size=0.2, stratify=filename_df[['label']])
val, test      = train_test_split(rest_df, test_size=0.5, stratify = rest_df[['label']])

train_files = tf.random.shuffle(train['name'])
val_files   = tf.random.shuffle(val['name'])
test_files  = tf.random.shuffle(test['name'])

def concat_xy(ds):
        x_tmp  = [x for x,_ in ds]
        x_tmp  = tf.stack(x_tmp)
        xs_tmp = tf.unstack(x_tmp, axis=-1)
        xs_tmp = [tf.expand_dims(x_ind, axis=-1) for x_ind in xs_tmp]
        y      = np.array([y for _,y in ds])
        return xs_tmp, y

print('Getting data')
choices  = ['Mod']
train_ds = preprocess_dataset(train_files, choices, categories, req_width=750, resize = 4, spec_norm = True)
val_ds   = preprocess_dataset(val_files,   choices, categories, req_width=750, resize = 4, spec_norm = True)
test_ds  = preprocess_dataset(test_files,  choices, categories, req_width=750, resize = 4, spec_norm = True)

train_ds_vgg = preprocess_dataset(train_files, choices, categories, req_width=750, single_to_rgb = True, resize = 4, spec_norm = True)
val_ds_vgg   = preprocess_dataset(val_files,   choices, categories, req_width=750, single_to_rgb = True, resize = 4, spec_norm = True)
test_ds_vgg  = preprocess_dataset(test_files,  choices, categories, req_width=750, single_to_rgb = True, resize = 4, spec_norm = True)

X_train_vgg = np.array([x for x,y in train_ds_vgg])
X_val_vgg   = np.array([x for x,y in val_ds_vgg])
X_test_vgg  = np.array([x for x,y in test_ds_vgg])

y_train = np.array([y for _,y in train_ds_vgg])
y_val   = np.array([y for _,y in val_ds_vgg])
y_test  = np.array([y for _,y in test_ds_vgg])

for spec, _ in train_ds.take(1):
    input_shape = spec.shape
for spec, _ in train_ds_vgg.take(1):
    input_shape_vgg = spec.shape
vgg19 = True
if vgg19 or vgg19_concat:
    vgg_model = VGG19(weights='imagenet', include_top=False, input_shape=input_shape_vgg)
    tmp_vgg_trainX = vgg_model.predict(X_train_vgg)
    tmp_vgg_valX   = vgg_model.predict(X_val_vgg)
    tmp_vgg_testX  = vgg_model.predict(X_test_vgg)
vgg_mfcc = True
if vgg_mfcc or smallcnn_mfcc or vgg_umap or vgg_pca:
    print("MFCC features")
    def get_features(waveform, sr):
        #audio = np.array(audio)#.numpy()
        waveform = waveform[:sr]  # analyze just first second
        S = librosa.feature.melspectrogram(waveform, sr=sr, n_mels=128)
        log_S = librosa.amplitude_to_db(S, ref=np.max)
        mfcc  = librosa.feature.mfcc(S=log_S, n_mfcc=13)
        delta_mfcc  = librosa.feature.delta(mfcc, mode='nearest')
        delta2_mfcc = librosa.feature.delta(mfcc, order=2, mode='nearest')
        feature_vector = np.concatenate((np.mean(mfcc,1), np.mean(delta_mfcc,1), np.mean(delta2_mfcc,1)))
        feature_vector = (feature_vector-np.mean(feature_vector)) / (np.std(feature_vector)+np.finfo(np.float32).eps)
        return feature_vector

    def get_pca(features):
        pca = PCA(n_components=5)
        transformed = pca.fit(features).transform(features)
        scaler = MinMaxScaler()
        scaler.fit(transformed)
        return scaler.transform(transformed)

    def get_mfcc_features(file_names):
        feature_vectors = []
        sound_paths     = []
        for i,f in enumerate(file_names):
            #f = f.numpy()
            if i % 100 == 0:
                print("get %d of %d = %s"%(i+1, len(file_names), f))
            try:
                #print(f)
                #print(type(f))
                y, sr = librosa.load(f)
                #print(len(y))
                #print(len(y)<2)
                if len(y) < 2:
                    print("error loading %s" % f)
                    continue
                feat = get_features(y, sr)
                #print(feat)
                feature_vectors.append(feat)
                sound_paths.append(f)
            except:
                print("error loading %s" % f)

        print("calculated %d feature vectors"%len(feature_vectors))
        return np.array(feature_vectors)

    train_files = [f.decode().replace('\\', '/') for f in train['name'].to_list()]
    val_files   = [f.decode().replace('\\', '/') for f in val['name'].to_list()]
    test_files  = [f.decode().replace('\\', '/') for f in test['name'].to_list()]

    train_mfcc = get_mfcc_features(train_files)
    val_mfcc   = get_mfcc_features(val_files)
    test_mfcc  = get_mfcc_features(test_files)

    #exclude_idx = np.unique(np.where(np.isnan(test_mfcc))[0])
    #feature_sub = [feature_vectors[i] for i in range(len(feature_vectors)) if i not in exclude_idx]
    #class_sub   = [class_smp[i] for i in range(len(class_smp)) if i not in exclude_idx]

    #tsne_embed = TSNE(n_components=2, learning_rate=150, perplexity=30, verbose=2, angle=0.1).fit(train_mfcc)

    umap_embed = umap.UMAP(n_neighbors=5, random_state=42, n_components=10).fit(train_mfcc)

    umap_embed_train = umap_embed.embedding_
    umap_embed_val   = umap_embed.transform(val_mfcc)
    umap_embed_test  = umap_embed.transform(test_mfcc)
    #test_embedding = trans.transform(X_test)
    #pca_embed  = get_pca(feature_sub)
    pca_embed = PCA(n_components=5).fit(train_mfcc)

    pca_embed_train = pca_embed.transform(train_mfcc)

    scaler = MinMaxScaler()
    scaler.fit(pca_embed_train)

    pca_embed_train = scaler.transform(pca_embed_train)

    pca_embed_val   = scaler.transform(pca_embed.transform(val_mfcc))
    pca_embed_test  = scaler.transform(pca_embed.transform(test_mfcc))
    #transformed = pca.fit(features).transform(features)
    #scaler = MinMaxScaler()
    #scaler.fit(transformed)
    #return scaler.transform(transformed)

print("Done")
# Out:
# Getting data
# MFCC features
# get 1 of 2272 = richfield_birds_split/Eurasian Curlew/xc656570_start_1_30.wav
# get 101 of 2272 = richfield_birds_split/Tundra Swan (Bewicks)/xc510612_left_start_0_0.wav
# get 201 of 2272 = richfield_birds_split/European Herring Gull/xc579848_left_start_0_0.wav
# get 301 of 2272 = richfield_birds_split/Tundra Swan (Bewicks)/xc280868_left_start_0_0.wav
# get 401 of 2272 = richfield_birds_split/Common Snipe/xc618307_left_start_0_30.wav
# get 501 of 2272 = richfield_birds_split/Tundra Swan/xc344607_left_start_0_15.wav
# get 601 of 2272 = richfield_birds_split/Tundra Swan (Bewicks)/xc295467_left_start_0_15.wav
# get 701 of 2272 = richfield_birds_split/Rook/xc631334_left_start_11_30.wav
# get 801 of 2272 = richfield_birds_split/Mute Swan/xc640267_left_start_0_30.wav
# get 901 of 2272 = richfield_birds_split/Meadow Pipit/xc651319_start_1_0.wav
# get 1001 of 2272 = richfield_birds_split/Common Snipe/xc631066_left_start_1_0.wav
# get 1101 of 2272 = richfield_birds_split/Northern Lapwing/xc676107_left_start_0_15.wav
# get 1201 of 2272 = richfield_birds_split/Rook/xc631334_left_start_19_15.wav
# get 1301 of 2272 = richfield_birds_split/European Robin/xc671507_left_start_0_0.wav
# get 1401 of 2272 = richfield_birds_split/Rook/xc463805_left_start_1_15.wav
# get 1501 of 2272 = richfield_birds_split/Tundra Swan (Bewicks)/xc615229_left_start_0_15.wav
# get 1601 of 2272 = richfield_birds_split/European Herring Gull/xc623834_start_0_0.wav
# get 1701 of 2272 = richfield_birds_split/Tundra Swan (Bewicks)/xc102851_start_1_30.wav
# get 1801 of 2272 = richfield_birds_split/Mute Swan/xc640260_left_start_1_45.wav
# get 1901 of 2272 = richfield_birds_split/Tundra Swan/xc128225_start_2_15.wav
# get 2001 of 2272 = richfield_birds_split/Northern Lapwing/xc656613_start_0_15.wav
# get 2101 of 2272 = richfield_birds_split/Rook/xc631334_left_start_10_15.wav
# get 2201 of 2272 = richfield_birds_split/Northern Lapwing/xc671033_left_start_0_0.wav
# calculated 2272 feature vectors
# get 1 of 284 = richfield_birds_split/Common Buzzard/xc555949_start_0_30.wav
# get 101 of 284 = richfield_birds_split/Common Buzzard/xc678169_left_start_2_45.wav
# get 201 of 284 = richfield_birds_split/Meadow Pipit/xc666827_left_start_0_0.wav
# calculated 284 feature vectors
# get 1 of 284 = richfield_birds_split/Common Buzzard/xc627882_left_start_0_15.wav
# get 101 of 284 = richfield_birds_split/Eurasian Curlew/xc642986_left_start_0_0.wav
# get 201 of 284 = richfield_birds_split/Mute Swan/xc680939_left_start_0_0.wav
# calculated 284 feature vectors
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-72e54d406bc4> in <module>
#     118     pca_embed = PCA(n_components=5).fit(train_mfcc)
#     119
# --> 120     pca_embed_train = pca_embed.embedding_
#     121
#     122     scaler = MinMaxScaler()
#
# AttributeError: 'PCA' object has no attribute 'embedding_'

# %%
def main_model_run_loaded(filenames, index,
                   train_ds, val_ds, test_ds,
                   tmp_vgg_trainX, tmp_vgg_valX, tmp_vgg_testX,
                   train_mfcc, val_mfcc, test_mfcc,
                   umap_embed_train, umap_embed_val, umap_embed_test,
                   pca_embed_train, pca_embed_val, pca_embed_test,
                   vgg19        = False,
                   vgg19_concat = False,
                   resnet50     = False,
                   resnet50_concat = False,
                   smallcnn = False,
                   concat   = False,
                   concat2  = False,
                   concat3  = False,
                   concat4  = False,
                   vgg_mfcc = False,
                   vgg_umap = False,
                   vgg_pca  = False,
                   smallcnn_mfcc = False):
    print("Index: ", index)
    
    
    
    
    #concat_shape     = X_train_mult[0].shape[1:]
    #vgg_concat_shape = X_train_mult_vgg[0].shape[1:]
    
    for spec, _ in train_ds.take(1):
        input_shape = spec.shape
    for spec, _ in train_ds_vgg.take(1):
        input_shape_vgg = spec.shape
        #print(tf.math.reduce_std(spec[:,:,0]))
        #print(tf.math.reduce_std(spec[:,:,1]))
        #print(tf.math.reduce_std(spec[:,:,2]))
        
    train_ds = train_ds.batch(batch_size)
    val_ds   = val_ds.batch(batch_size)
    test_ds  = test_ds.batch(batch_size)
    train_ds = train_ds.cache().prefetch(AUTOTUNE)
    val_ds   = val_ds.cache().prefetch(AUTOTUNE)
    test_ds  = test_ds.cache().prefetch(AUTOTUNE)
    
    if data_dir.startswith("C:"):
        sv_dir = '_'.join(data_dir.split(os.path.sep)[1:-2])
    else:
        sv_dir = data_dir
    filename_idx = datetime.now().strftime("%Y%m%d-%H%M%S").replace('-', '_')+'_'+sv_dir.replace('/','_')+'_'+str(index)
    results_folder = 'results'
    if not os.path.isdir(results_folder):
        os.mkdir(results_folder)
    
    train.to_csv(results_folder+'/'+filename_idx+'_filenames_train.csv')
    val.to_csv(results_folder+'/'+filename_idx+'_filenames_val.csv')
    test.to_csv(results_folder+'/'+filename_idx+'_filenames_test.csv')
    #np.save('results/'+filename_idx+'_filenames.npy', filenames.numpy())
    
    #this will save the model performing best on val accuracy
    def best_model_cp():
        checkpoint = tf.keras.callbacks.ModelCheckpoint(
            "best_model",
            monitor = "val_accuracy",
            mode    = "max",
            save_best_only = True,
            save_weights_only = True)
        return checkpoint
    
    ## Load and run models
    
    #VGG19
    if vgg19:
        print("VGG19")
        model = preload_vgg19(tmp_vgg_trainX.shape[1:])
        model_name   = 'vgg19'
        filename_run = filename_idx+'_'+model_name
        print(model.summary())
        history = model.fit(tmp_vgg_trainX, y_train,
                            validation_data = (tmp_vgg_valX, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, tmp_vgg_testX, y_test, model_name, filename_run, index)
    
    
    #VGG19_concat
    if vgg19_concat:
        print("VGG19_concat")
        tmp_X_train_mult_vgg = [vgg_model.predict(xt) for xt in X_train_mult_vgg]
        tmp_X_val_mult_vgg   = [vgg_model.predict(xt) for xt in X_val_mult_vgg]
        tmp_X_test_mult_vgg  = [vgg_model.predict(xt) for xt in X_test_mult_vgg]
        #model    = load_vgg19_concat(vgg_concat_shape, num_channels)
        model_name   = 'vgg19_concat'
        filename_run = filename_idx+'_'+model_name
        model = preload_vgg19_concat(tmp_X_train_mult_vgg[0].shape[1:], num_channels)
        print(model.summary())
        history = model.fit(tmp_X_train_mult_vgg, y_train,
                            validation_data = (tmp_X_val_mult_vgg, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, tmp_X_test_mult_vgg, y_test, model_name, filename_run, index)


    #ResNet50
    if resnet50:
        print("ResNet50")
        model = load_resnet50(input_shape_vgg)
        model_name   = 'resnet50'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(train_ds,
                            validation_data = val_ds,
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, test_ds, y_test, model_name, filename_run, index)
    
    #ResNet50_concat
    if resnet50_concat:
        print("ResNet50_concat")
        model    = load_resnet50_concat(vgg_concat_shape, num_channels)
        model_name   = 'resnet50_concat'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(X_train_vgg, y_train,
                            validation_data = (X_val_vgg, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, X_test_vgg, y_test, model_name, filename_run, index)

    #small_cnn
    if smallcnn:
        print("Small CNN")
        model  = main_cnn(input_shape, num_classes)
        model_name   = 'smallcnn'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(train_ds,
                            validation_data = val_ds,
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, test_ds, y_test, model_name, filename_run, index)
    
    #concat
    if concat:
        print("Concat")
        model        = concat_model(concat_shape, num_channels, num_classes)
        model_name   = 'concat'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(X_train_mult, y_train,
                            validation_data = (X_val_mult, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, X_test_mult, y_test, model_name, filename_run, index)

    #concat2
    if concat2:
        print("Concat2")
        model     = concat_model2(concat_shape, num_channels, num_classes)
        model_name   = 'concat2'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(X_train_mult, y_train,
                            validation_data = (X_val_mult, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, X_test_mult, y_test, model_name, filename_run, index)
    
    #concat3
    if concat3:
        print("Concat3")
        model     = concat_model3(concat_shape, num_channels, num_classes)
        model_name   = 'concat3'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(X_train_mult, y_train,
                            validation_data = (X_val_mult, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, X_test_mult, y_test, model_name, filename_run, index)
    
    #concat4
    if concat4:
        print("Concat4")
        model     = concat_model4(concat_shape, num_channels, num_classes)
        model_name   = 'concat4'
        filename_run = filename_idx+'_'+model_name

        history = model.fit(X_train_mult, y_train,
                            validation_data = (X_val_mult, y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, X_test_mult, y_test, model_name, filename_run, index)

    if vgg_mfcc:
        print("VGG MFCC")
        
        model        = preload_vgg19_mfcc(tmp_vgg_trainX.shape[1:], train_mfcc.shape[-1])
        #model        = concat_model4(concat_shape, num_channels, num_classes)
        model_name   = 'vgg_mfcc'
        filename_run = filename_idx+'_'+model_name

        history = model.fit([tmp_vgg_trainX, train_mfcc], y_train,
                            validation_data = ([tmp_vgg_valX, val_mfcc], y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, [tmp_vgg_testX, test_mfcc], y_test, model_name, filename_run, index)
        
    if vgg_umap:
        print("VGG MFCC Umap")
        
        model        = preload_vgg19_mfcc_umap(tmp_vgg_trainX.shape[1:], umap_embed_train.shape[-1])
        #model        = concat_model4(concat_shape, num_channels, num_classes)
        model_name   = 'vgg_mfcc_umap'
        filename_run = filename_idx+'_'+model_name

        history = model.fit([tmp_vgg_trainX, umap_embed_train], y_train,
                            validation_data = ([tmp_vgg_valX, umap_embed_val], y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, [tmp_vgg_testX, umap_embed_test], y_test, model_name, filename_run, index)
        
    if vgg_pca:
        print("VGG MFCC PCA")
        
        model        = preload_vgg19_mfcc_umap(tmp_vgg_trainX.shape[1:], pca_embed_train.shape[-1])
        #model        = concat_model4(concat_shape, num_channels, num_classes)
        model_name   = 'vgg_mfcc_pca'
        filename_run = filename_idx+'_'+model_name

        history = model.fit([tmp_vgg_trainX, pca_embed_train], y_train,
                            validation_data = ([tmp_vgg_valX, pca_embed_val], y_val),
                            callbacks       = [best_model_cp()],
                            epochs          = EPOCHS,
                            batch_size      = batch_size,
                            verbose         = 1)

        pd.DataFrame(history.history).to_csv(results_folder+'/'+filename_run+'_model_history.csv')

        model.load_weights("best_model")

        save_results(model, [tmp_vgg_testX, pca_embed_test], y_test, model_name, filename_run, index)
           
    #if smallcnn_mfcc:

# %%
for i in range(1,5+1):
    main_model_run_loaded(filenames, i,
                          train_ds, val_ds, test_ds,
                   tmp_vgg_trainX, tmp_vgg_valX, tmp_vgg_testX,
                   train_mfcc, val_mfcc, test_mfcc,
                   umap_embed_train, umap_embed_val, umap_embed_test,
                   pca_embed_train, pca_embed_val, pca_embed_test,
                   vgg19        = True,
                   #vgg19_concat = True
                   #resnet50     = True,
                   #resnet50_concat = True,
                   #smallcnn     = True,
                   #concat   = True
                  #)
                   #concat2  = True,
                   #concat3  = True,
                   #concat4  = True,
                    vgg_mfcc = True,
                    vgg_umap = True,
                    vgg_pca  = True)#,
                    #smallcnn_mfcc = True)
    print("Time so far:", time.time() - tic)
# Out:
# Index:  1
# VGG19
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          (None, 47104)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               12058880
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_20 (Dense)             (None, 12)                780
# =================================================================
# Total params: 12,076,108
# Trainable params: 12,076,108
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 71/71 [==============================] - 2s 32ms/step - loss: 2.1573 - accuracy: 0.3046 - val_loss: 1.5776 - val_accuracy: 0.5423
# Epoch 2/50
# 71/71 [==============================] - 2s 29ms/step - loss: 1.6336 - accuracy: 0.4661 - val_loss: 1.3272 - val_accuracy: 0.5739
# Epoch 3/50
# 71/71 [==============================] - 2s 29ms/step - loss: 1.4033 - accuracy: 0.5462 - val_loss: 1.1354 - val_accuracy: 0.6690
# Epoch 4/50
# 71/71 [==============================] - 2s 29ms/step - loss: 1.2634 - accuracy: 0.6021 - val_loss: 1.1093 - val_accuracy: 0.6408
# Epoch 5/50
# 71/71 [==============================] - 2s 28ms/step - loss: 1.1613 - accuracy: 0.6281 - val_loss: 1.0211 - val_accuracy: 0.6620
# Epoch 6/50
# 71/71 [==============================] - 2s 29ms/step - loss: 1.0730 - accuracy: 0.6593 - val_loss: 0.9565 - val_accuracy: 0.7218
# Epoch 7/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.9857 - accuracy: 0.6910 - val_loss: 0.8937 - val_accuracy: 0.7324
# Epoch 8/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.9191 - accuracy: 0.7148 - val_loss: 0.8609 - val_accuracy: 0.7465
# Epoch 9/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.8532 - accuracy: 0.7196 - val_loss: 0.8447 - val_accuracy: 0.7289
# Epoch 10/50
# 71/71 [==============================] - 3s 41ms/step - loss: 0.7922 - accuracy: 0.7496 - val_loss: 0.8058 - val_accuracy: 0.7430
# Epoch 11/50
# 71/71 [==============================] - 3s 39ms/step - loss: 0.7387 - accuracy: 0.7658 - val_loss: 0.8124 - val_accuracy: 0.7394
# Epoch 12/50
# 71/71 [==============================] - 3s 37ms/step - loss: 0
50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1185 - accuracy: 0.9692 - val_loss: 0.6472 - val_accuracy: 0.8345
# VGG MFCC Umap
# Epoch 1/50
# 71/71 [==============================] - 3s 35ms/step - loss: 2.5816 - accuracy: 0.2777 - val_loss: 1.6727 - val_accuracy: 0.5035
# Epoch 2/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.8427 - accuracy: 0.4168 - val_loss: 1.3552 - val_accuracy: 0.5563
# Epoch 3/50
# 71/71 [==============================] - 2s 35ms/step - loss: 1.5598 - accuracy: 0.5167 - val_loss: 1.2797 - val_accuracy: 0.5880
# Epoch 4/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.3843 - accuracy: 0.5528 - val_loss: 1.1533 - val_accuracy: 0.6268
# Epoch 5/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.2012 - accuracy: 0.6039 - val_loss: 1.0464 - val_accuracy: 0.6690
# Epoch 6/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.1132 - accuracy: 0.6316 - val_loss: 0.9803 - val_accuracy: 0.6901
# Epoch 7/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.0504 - accuracy: 0.6607 - val_loss: 0.9847 - val_accuracy: 0.7007
# Epoch 8/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.9590 - accuracy: 0.6906 - val_loss: 0.9563 - val_accuracy: 0.6972
# Epoch 9/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.8965 - accuracy: 0.7051 - val_loss: 0.8945 - val_accuracy: 0.7183
# Epoch 10/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.8232 - accuracy: 0.7240 - val_loss: 0.8716 - val_accuracy: 0.7042
# Epoch 11/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.7723 - accuracy: 0.7438 - val_loss: 0.8271 - val_accuracy: 0.7500
# Epoch 12/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.7048 - accuracy: 0.7680 - val_loss: 0.8641 - val_accuracy: 0.7113
# Epoch 13/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.6808 - accuracy: 0.7768 - val_loss: 0.8897 - val_accuracy: 0.7183
# Epoch 14/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.6141 - accuracy: 0.8006 - val_loss: 0.7697 - val_accuracy: 0.7570
# Epoch 15/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.6003 - accuracy: 0.7989 - val_loss: 0.7991 - val_accuracy: 0.7394
# Epoch 16/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.5694 - accuracy: 0.8187 - val_loss: 0.7612 - val_accuracy: 0.7852
# Epoch 17/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.5204 - accuracy: 0.8354 - val_loss: 0.7127 - val_accuracy: 0.7923
# Epoch 18/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.5074 - accuracy: 0.8393 - val_loss: 0.7451 - val_accuracy: 0.7641
# Epoch 19/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.4952 - accuracy: 0.8354 - val_loss: 0.6884 - val_accuracy: 0.8063
# Epoch 20/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.4563 - accuracy: 0.8486 - val_loss: 0.7846 - val_accuracy: 0.7746
# Epoch 21/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.4494 - accuracy: 0.8561 - val_loss: 0.7296 - val_accuracy: 0.7817
# Epoch 22/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.4005 - accuracy: 0.8710 - val_loss: 0.6969 - val_accuracy: 0.7958
# Epoch 23/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.3856 - accuracy: 0.8741 - val_loss: 0.6892 - val_accuracy: 0.8063
# Epoch 24/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.3487 - accuracy: 0.8957 - val_loss: 0.7077 - val_accuracy: 0.7887
# Epoch 25/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.3665 - accuracy: 0.8820 - val_loss: 0.6937 - val_accuracy: 0.7887
# Epoch 26/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.3496 - accuracy: 0.8842 - val_loss: 0.6653 - val_accuracy: 0.8063
# Epoch 27/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.3170 - accuracy: 0.8957 - val_loss: 0.6851 - val_accuracy: 0.7782
# Epoch 28/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.3105 - accuracy: 0.8988 - val_loss: 0.7047 - val_accuracy: 0.7958
# Epoch 29/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2857 - accuracy: 0.9115 - val_loss: 0.6621 - val_accuracy: 0.7958
# Epoch 30/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2922 - accuracy: 0.9023 - val_loss: 0.6985 - val_accuracy: 0.8063
# Epoch 31/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2688 - accuracy: 0.9186 - val_loss: 0.7057 - val_accuracy: 0.8099
# Epoch 32/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2628 - accuracy: 0.9208 - val_loss: 0.7202 - val_accuracy: 0.7887
# Epoch 33/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2534 - accuracy: 0.9186 - val_loss: 0.6961 - val_accuracy: 0.7993
# Epoch 34/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2363 - accuracy: 0.9234 - val_loss: 0.6755 - val_accuracy: 0.8134
# Epoch 35/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2327 - accuracy: 0.9265 - val_loss: 0.7199 - val_accuracy: 0.8063
# Epoch 36/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2040 - accuracy: 0.9410 - val_loss: 0.7146 - val_accuracy: 0.8028
# Epoch 37/50
# 71/71 [==============================] - 3s 35ms/step - loss: 0.2026 - accuracy: 0.9410 - val_loss: 0.6966 - val_accuracy: 0.8028
# Epoch 38/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.2007 - accuracy: 0.9344 - val_loss: 0.7281 - val_accuracy: 0.8169
# Epoch 39/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1946 - accuracy: 0.9393 - val_loss: 0.7107 - val_accuracy: 0.7993
# Epoch 40/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1900 - accuracy: 0.9415 - val_loss: 0.6928 - val_accuracy: 0.8310
# Epoch 41/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1821 - accuracy: 0.9419 - val_loss: 0.7302 - val_accuracy: 0.8063
# Epoch 42/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1776 - accuracy: 0.9494 - val_loss: 0.7517 - val_accuracy: 0.8134
# Epoch 43/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1775 - accuracy: 0.9432 - val_loss: 0.7065 - val_accuracy: 0.8204
# Epoch 44/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1558 - accuracy: 0.9516 - val_loss: 0.7271 - val_accuracy: 0.8134
# Epoch 45/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1404 - accuracy: 0.9595 - val_loss: 0.7044 - val_accuracy: 0.8134
# Epoch 46/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1485 - accuracy: 0.9538 - val_loss: 0.6836 - val_accuracy: 0.8204
# Epoch 47/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1277 - accuracy: 0.9657 - val_loss: 0.7271 - val_accuracy: 0.8169
# Epoch 48/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1482 - accuracy: 0.9529 - val_loss: 0.7880 - val_accuracy: 0.8275
# Epoch 49/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1367 - accuracy: 0.9657 - val_loss: 0.7162 - val_accuracy: 0.8204
# Epoch 50/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1220 - accuracy: 0.9648 - val_loss: 0.6968 - val_accuracy: 0.8063
# VGG MFCC PCA
# Epoch 1/50
# 71/71 [==============================] - 3s 37ms/step - loss: 2.1354 - accuracy: 0.3125 - val_loss: 1.6465 - val_accuracy: 0.5176
# Epoch 2/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.6472 - accuracy: 0.4732 - val_loss: 1.4079 - val_accuracy: 0.5810
# Epoch 3/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.4622 - accuracy: 0.5431 - val_loss: 1.2903 - val_accuracy: 0.6479
# Epoch 4/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.3134 - accuracy: 0.5902 - val_loss: 1.1398 - val_accuracy: 0.6585
# Epoch 5/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.2013 - accuracy: 0.6250 - val_loss: 1.0400 - val_accuracy: 0.6796
# Epoch 6/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.0709 - accuracy: 0.6593 - val_loss: 1.0200 - val_accuracy: 0.7148
# Epoch 7/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1
50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2322 - accuracy: 0.9217 - val_loss: 0.7299 - val_accuracy: 0.8275
# Epoch 37/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.2400 - accuracy: 0.9283 - val_loss: 0.6756 - val_accuracy: 0.8310
# Epoch 38/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2236 - accuracy: 0.9322 - val_loss: 0.6429 - val_accuracy: 0.8275
# Epoch 39/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2026 - accuracy: 0.9371 - val_loss: 0.7007 - val_accuracy: 0.8169
# Epoch 40/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1951 - accuracy: 0.9454 - val_loss: 0.7079 - val_accuracy: 0.8239
# Epoch 41/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1844 - accuracy: 0.9450 - val_loss: 0.7662 - val_accuracy: 0.8099
# Epoch 42/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1907 - accuracy: 0.9406 - val_loss: 0.7003 - val_accuracy: 0.8239
# Epoch 43/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1814 - accuracy: 0.9494 - val_loss: 0.6805 - val_accuracy: 0.8134
# Epoch 44/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1795 - accuracy: 0.9476 - val_loss: 0.6415 - val_accuracy: 0.8415
# Epoch 45/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1789 - accuracy: 0.9485 - val_loss: 0.6507 - val_accuracy: 0.8204
# Epoch 46/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1576 - accuracy: 0.9520 - val_loss: 0.6569 - val_accuracy: 0.8169
# Epoch 47/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1596 - accuracy: 0.9529 - val_loss: 0.6591 - val_accuracy: 0.8169
# Epoch 48/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1682 - accuracy: 0.9454 - val_loss: 0.6622 - val_accuracy: 0.8204
# Epoch 49/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1572 - accuracy: 0.9560 - val_loss: 0.6637 - val_accuracy: 0.8169
# Epoch 50/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1447 - accuracy: 0.9604 - val_loss: 0.6473 - val_accuracy: 0.8310
# Time so far: 41333.58153152466
# Index:  2
# VGG19
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_10 (Flatten)         (None, 47104)             0
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               12058880
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_32 (Dense)             (None, 12)                780
# =================================================================
# Total params: 12,076,108
# Trainable params: 12,076,108
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 71/71 [==============================] - 3s 34ms/step - loss: 2.1331 - accuracy: 0.3041 - val_loss: 1.5896 - val_accuracy: 0.5141
# Epoch 2/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.6068 - accuracy: 0.4828 - val_loss: 1.3406 - val_accuracy: 0.5880
# Epoch 3/50
# 71/71 [==============================] - 2s 34ms/step - loss: 1.4272 - accuracy: 0.5383 - val_loss: 1.2406 - val_accuracy: 0.6232
# Epoch 4/50
# 71/71 [==============================] - 2s 35ms/step - loss: 1.2474 - accuracy: 0.5933 - val_loss: 1.1355 - val_accuracy: 0.6655
# Epoch 5/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.1615 - accuracy: 0.6316 - val_loss: 1.0307 - val_accuracy: 0.6866
# Epoch 6/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.0634 - accuracy: 0.6554 - val_loss: 1.0124 - val_accuracy: 0.6796
# Epoch 7/50
# 71/71 [==============================] - 2s 34ms/step - loss: 1.0099 - accuracy: 0.6756 - val_loss: 1.0130 - val_accuracy: 0.6866
# Epoch 8/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.9146 - accuracy: 0.7069 - val_loss: 0.9217 - val_accuracy: 0.7077
# Epoch 9/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.8716 - accuracy: 0.7188 - val_loss: 0.9056 - val_accuracy: 0.7430
# Epoch 10/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.7949 - accuracy: 0.7412 - val_loss: 0.8986 - val_accuracy: 0.7148
# Epoch 11/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.7638 - accuracy: 0.7452 - val_loss: 0.9193 - val_accuracy: 0.7148
# Epoch 12/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.7130 - accuracy: 0.7623 - val_loss: 0.8062 - val_accuracy: 0.7676
# Epoch 13/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0
50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.4117 - accuracy: 0.8684 - val_loss: 0.6761 - val_accuracy: 0.7958
# Epoch 23/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.3858 - accuracy: 0.8816 - val_loss: 0.6450 - val_accuracy: 0.8169
# Epoch 24/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.3637 - accuracy: 0.8869 - val_loss: 0.6574 - val_accuracy: 0.8134
# Epoch 25/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.3621 - accuracy: 0.8851 - val_loss: 0.6717 - val_accuracy: 0.8169
# Epoch 26/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.3271 - accuracy: 0.9023 - val_loss: 0.6666 - val_accuracy: 0.8063
# Epoch 27/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.3017 - accuracy: 0.9076 - val_loss: 0.6440 - val_accuracy: 0.8134
# Epoch 28/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.3021 - accuracy: 0.9067 - val_loss: 0.6799 - val_accuracy: 0.8169
# Epoch 29/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2913 - accuracy: 0.9133 - val_loss: 0.6475 - val_accuracy: 0.7958
# Epoch 30/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2949 - accuracy: 0.9076 - val_loss: 0.6721 - val_accuracy: 0.8169
# Epoch 31/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2643 - accuracy: 0.9195 - val_loss: 0.6650 - val_accuracy: 0.8099
# Epoch 32/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2381 - accuracy: 0.9309 - val_loss: 0.6535 - val_accuracy: 0.8275
# Epoch 33/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2405 - accuracy: 0.9274 - val_loss: 0.6649 - val_accuracy: 0.8239
# Epoch 34/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2383 - accuracy: 0.9300 - val_loss: 0.6607 - val_accuracy: 0.8204
# Epoch 35/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2164 - accuracy: 0.9349 - val_loss: 0.6666 - val_accuracy: 0.8204
# Epoch 36/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2028 - accuracy: 0.9415 - val_loss: 0.6337 - val_accuracy: 0.8275
# Epoch 37/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2144 - accuracy: 0.9357 - val_loss: 0.6832 - val_accuracy: 0.8275
# Epoch 38/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1990 - accuracy: 0.9397 - val_loss: 0.6974 - val_accuracy: 0.8028
# Epoch 39/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1986 - accuracy: 0.9379 - val_loss: 0.6934 - val_accuracy: 0.8204
# Epoch 40/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1936 - accuracy: 0.9410 - val_loss: 0.6383 - val_accuracy: 0.8310
# Epoch 41/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1838 - accuracy: 0.9432 - val_loss: 0.6732 - val_accuracy: 0.8204
# Epoch 42/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1708 - accuracy: 0.9485 - val_loss: 0.6498 - val_accuracy: 0.8415
# Epoch 43/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1678 - accuracy: 0.9498 - val_loss: 0.6488 - val_accuracy: 0.8345
# Epoch 44/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1593 - accuracy: 0.9503 - val_loss: 0.6332 - val_accuracy: 0.8310
# Epoch 45/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1528 - accuracy: 0.9533 - val_loss: 0.6615 - val_accuracy: 0.8380
# Epoch 46/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1496 - accuracy: 0.9586 - val_loss: 0.7108 - val_accuracy: 0.8099
# Epoch 47/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1276 - accuracy: 0.9608 - val_loss: 0.6824 - val_accuracy: 0.8310
# Epoch 48/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1312 - accuracy: 0.9648 - val_loss: 0.6783 - val_accuracy: 0.8345
# Epoch 49/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1448 - accuracy: 0.9569 - val_loss: 0.6597 - val_accuracy: 0.8204
# Epoch 50/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.
50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.1713 - accuracy: 0.9481 - val_loss: 0.6719 - val_accuracy: 0.8239
# Epoch 43/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.1695 - accuracy: 0.9485 - val_loss: 0.6841 - val_accuracy: 0.8275
# Epoch 44/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1602 - accuracy: 0.9542 - val_loss: 0.7088 - val_accuracy: 0.8169
# Epoch 45/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.1763 - accuracy: 0.9481 - val_loss: 0.7026 - val_accuracy: 0.8099
# Epoch 46/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.1434 - accuracy: 0.9582 - val_loss: 0.6721 - val_accuracy: 0.8310
# Epoch 47/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.1613 - accuracy: 0.9529 - val_loss: 0.6953 - val_accuracy: 0.8345
# Epoch 48/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.1492 - accuracy: 0.9577 - val_loss: 0.6836 - val_accuracy: 0.8204
# Epoch 49/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.1578 - accuracy: 0.9551 - val_loss: 0.6870 - val_accuracy: 0.8451
# Epoch 50/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1346 - accuracy: 0.9617 - val_loss: 0.6546 - val_accuracy: 0.8275
# VGG MFCC Umap
# Epoch 1/50
# 71/71 [==============================] - 3s 34ms/step - loss: 2.3066 - accuracy: 0.2989 - val_loss: 1.5881 - val_accuracy: 0.5035
# Epoch 2/50
# 71/71 [==============================] - 2s 33ms/step - loss: 1.6649 - accuracy: 0.4802 - val_loss: 1.3602 - val_accuracy: 0.5423
# Epoch 3/50
# 71/71 [==============================] - 2s 35ms/step - loss: 1.4005 - accuracy: 0.5475 - val_loss: 1.2384 - val_accuracy: 0.6268
# Epoch 4/50
# 71/71 [==============================] - 2s 35ms/step - loss: 1.2838 - accuracy: 0.5779 - val_loss: 1.0961 - val_accuracy: 0.6690
# Epoch 5/50
# 71/71 [==============================] - 2s 35ms/step - loss: 1.1513 - accuracy: 0.6272 - val_loss: 1.0031 - val_accuracy: 0.7289
# Epoch 6/50
# 71/71 [==============================] - 2s 34ms/step - loss: 1.0404 - accuracy: 0.6540 - val_loss: 0.9802 - val_accuracy: 0.6972
# Epoch 7/50
# 71/71 [==============================] - 3s 36ms/step - loss: 0.9634 - accuracy: 0.6827 - val_loss: 0.8959 - val_accuracy: 0.7535
# Epoch 8/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.9027 - accuracy: 0.7025 - val_loss: 0.8907 - val_accuracy: 0.7359
# Epoch 9/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.8509 - accuracy: 0.7201 - val_loss: 0.8506 - val_accuracy: 0.7394
# Epoch 10/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.7767 - accuracy: 0.7460 - val_loss: 0.8444 - val_accuracy: 0.7570
# Epoch 11/50
# 71/71 [==============================] - 2s 31ms/step - loss: 0.7276 - accuracy: 0.7667 - val_loss: 0.7995 - val_accuracy: 0.7641
# Epoch 12/50
# 71/71 [==============================] - 2s 31ms/step - loss: 0.6771 - accuracy: 0.7857 - val_loss: 0.8475 - val_accuracy: 0.7465
# Epoch 13/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.6726 - accuracy: 0.7790 - val_loss: 0.9282 - val_accuracy: 0.7289
# Epoch 14/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.6156 - accuracy: 0.7967 - val_loss: 0.7754 - val_accuracy: 0.7782
# Epoch 15/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.5955 - accuracy: 0.8063 - val_loss: 0.7420 - val_accuracy: 0.7606
# Epoch 16/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.5372 - accuracy: 0.8367 - val_loss: 0.7675 - val_accuracy: 0.7641
# Epoch 17/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.5348 - accuracy: 0.8226 - val_loss: 0.7575 - val_accuracy: 0.7817
# Epoch 18/50
# 71/71 [==============================] - 2s 31ms/step - loss: 0.4912 - accuracy: 0.8451 - val_loss: 0.7409 - val_accuracy: 0.7782
# Epoch 19/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.4575 - accuracy: 0.8446 - val_loss: 0.7003 - val_accuracy: 0.7852
# Epoch 20/50
# 71/71 [==============================] - 2s 31ms/step - loss: 0.4555 - accuracy: 0.8517 - val_loss: 0.6686 - val_accuracy: 0.7887
# Epoch 21/50
# 71/71 [==============================] - 2s 31ms/step - loss: 0.4045 - accuracy: 0.8675 - val_loss: 0.7377 - val_accuracy: 0.7887
# Epoch 22/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.4035 - accuracy: 0.8684 - val_loss: 0.7182 - val_accuracy: 0.7993
# Epoch 23/50
# 71/71 [==============================] - 2s 31ms/step - loss: 0.3826 - accuracy: 0.8772 - val_loss: 0.7196 - val_accuracy: 0.7852
# Epoch 24/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.3979 - accuracy: 0.8702 - val_loss: 0.7235 - val_accuracy: 0.8028
# Epoch 25/50
# 71/71 [==============================] - 2s 31ms/step - loss: 0.3431 - accuracy: 0.8908 - val_loss: 0.6975 - val_accuracy: 0.8028
# Epoch 26/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.3451 - accuracy: 0.8908 - val_loss: 0.7192 - val_accuracy: 0.8063
# Epoch 27/50
# 71/71 [==============================] - 2s 31ms/step - loss: 0.3109 - accuracy: 0.9023 - val_loss: 0.7130 - val_accuracy: 0.8169
# Epoch 28/50
# 71/71 [==============================] - 3s 36ms/step - loss: 0.3332 - accuracy: 0.8886 - val_loss: 0.7026 - val_accuracy: 0.8099
# Epoch 29/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2912 - accuracy: 0.9098 - val_loss: 0.7039 - val_accuracy: 0.8204
# Epoch 30/50
# 71/71 [==============================] - 3s 36ms/step - loss: 0.2866 - accuracy: 0.9155 - val_loss: 0.6993 - val_accuracy: 0.8099
# Epoch 31/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.2830 - accuracy: 0.9107 - val_loss: 0.6623 - val_accuracy: 0.8063
# Epoch 32/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2585 - accuracy: 0.9151 - val_loss: 0.7223 - val_accuracy: 0.8099
# Epoch 33/50
# 71/71 [==============================] - 3s 37ms/step - loss: 0.2613 - accuracy: 0.9155 - val_loss: 0.6837 - val_accuracy: 0.8063
# Epoch 34/50
# 71/71 [==============================] - 3s 35ms/step - loss: 0.2610 - accuracy: 0.9133 - val_loss: 0.7147 - val_accuracy: 0.8028
# Epoch 35/50
# 71/71 [==============================] - 3s 36ms/step - loss: 0.2321 - accuracy: 0.9247 - val_loss: 0.6590 - val_accuracy: 0.8134
# Epoch 36/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2228 - accuracy: 0.9291 - val_loss: 0.6907 - val_accuracy: 0.8063
# Epoch 37/50
# 71/71 [==============================] - 3s 36ms/step - loss: 0.2222 - accuracy: 0.9318 - val_loss: 0.6660 - val_accuracy: 0.8169
# Epoch 38/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2099 - accuracy: 0.9362 - val_loss: 0.6854 - val_accuracy: 0.8415
# Epoch 39/50
# 71/71 [==============================] - 2s 31ms/step - loss: 0.2188 - accuracy: 0.9309 - val_loss: 0.7461 - val_accuracy: 0.8169
# Epoch 40/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.1828 - accuracy: 0.9401 - val_loss: 0.6843 - val_accuracy: 0.8204
# Epoch 41/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.1829 - accuracy: 0.9410 - val_loss: 0.7072 - val_accuracy: 0.8310
# Epoch 42/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.1664 - accuracy: 0.9489 - val_loss: 0.7385 - val_accuracy: 0.8345
# Epoch 43/50
# 71/71 [==============================] - 3s 36ms/step - loss: 0.1872 - accuracy: 0.9441 - val_loss: 0.6731 - val_accuracy: 0.8275
# Epoch 44/50
# 71/71 [==============================] - 3s 37ms/step - loss: 0.1512 - accuracy: 0.9582 - val_loss: 0.7057 - val_accuracy: 0.8310
# Epoch 45/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.1602 - accuracy: 0.9573 - val_loss: 0.7183 - val_accuracy: 0.8169
# Epoch 46/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.1622 - accuracy: 0.9494 - val_loss: 0.7466 - val_accuracy: 0.8239
# Epoch 47/50
# 71/71 [==============================] - 3s 37ms/step - loss: 0.1256 - accuracy: 0.9630 - val_loss: 0.7356 - val_accuracy: 0.8239
# Epoch 48/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.1446 - accuracy: 0.9555 - val_loss: 0.7575 - val_accuracy: 0.8204
# Epoch 49/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.
50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.3691 - accuracy: 0.8825 - val_loss: 0.6777 - val_accuracy: 0.8134
# Epoch 26/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.3384 - accuracy: 0.8900 - val_loss: 0.6854 - val_accuracy: 0.8204
# Epoch 27/50
# 71/71 [==============================] - 2s 32ms/step - loss: 0.3380 - accuracy: 0.8957 - val_loss: 0.6558 - val_accuracy: 0.8169
# Epoch 28/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.3252 - accuracy: 0.8939 - val_loss: 0.6494 - val_accuracy: 0.8275
# Epoch 29/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.3173 - accuracy: 0.8939 - val_loss: 0.6878 - val_accuracy: 0.7887
# Epoch 30/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2983 - accuracy: 0.9071 - val_loss: 0.6507 - val_accuracy: 0.8204
# Epoch 31/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2931 - accuracy: 0.9032 - val_loss: 0.6687 - val_accuracy: 0.8275
# Epoch 32/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.2719 - accuracy: 0.9120 - val_loss: 0.6920 - val_accuracy: 0.8134
# Epoch 33/50
# 71/71 [==============================] - 2s 35ms/step - loss: 0.2581 - accuracy: 0.9151 - val_loss: 0.6946 - val_accuracy: 0.8275
# Epoch 34/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2631 - accuracy: 0.9203 - val_loss: 0.6448 - val_accuracy: 0.8239
# Epoch 35/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2428 - accuracy: 0.9234 - val_loss: 0.7204 - val_accuracy: 0.7993
# Epoch 36/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2317 - accuracy: 0.9221 - val_loss: 0.7045 - val_accuracy: 0.7923
# Epoch 37/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2289 - accuracy: 0.9247 - val_loss: 0.6755 - val_accuracy: 0.8099
# Epoch 38/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.2186 - accuracy: 0.9366 - val_loss: 0.6538 - val_accuracy: 0.8134
# Epoch 39/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.2235 - accuracy: 0.9296 - val_loss: 0.6916 - val_accuracy: 0.8134
# Epoch 40/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1855 - accuracy: 0.9441 - val_loss: 0.6995 - val_accuracy: 0.8204
# Epoch 41/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1868 - accuracy: 0.9481 - val_loss: 0.6638 - val_accuracy: 0.8239
# Epoch 42/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1806 - accuracy: 0.9467 - val_loss: 0.7007 - val_accuracy: 0.7993
# Epoch 43/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1997 - accuracy: 0.9322 - val_loss: 0.6410 - val_accuracy: 0.8239
# Epoch 44/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1774 - accuracy: 0.9494 - val_loss: 0.6675 - val_accuracy: 0.8275
# Epoch 45/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1701 - accuracy: 0.9450 - val_loss: 0.6387 - val_accuracy: 0.8239
# Epoch 46/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1781 - accuracy: 0.9362 - val_loss: 0.6730 - val_accuracy: 0.8204
# Epoch 47/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1510 - accuracy: 0.9516 - val_loss: 0.6620 - val_accuracy: 0.8134
# Epoch 48/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1708 - accuracy: 0.9459 - val_loss: 0.7201 - val_accuracy: 0.8239
# Epoch 49/50
# 71/71 [==============================] - 2s 33ms/step - loss: 0.1610 - accuracy: 0.9476 - val_loss: 0.6975 - val_accuracy: 0.8204
# Epoch 50/50
# 71/71 [==============================] - 2s 34ms/step - loss: 0.1382 - accuracy: 0.9560 - val_loss: 0.7098 - val_accuracy: 0.8310
# Time so far: 43658.3748562336

# %%
toc = time.time()

# %%
librosa.load('richfield_birds_split/Common Kestrel/xc672833_start_1_30.wav')

# %%
print(toc-tic)

# %%
#print(res_df_t.to_latex(bold_rows = True))

# %%
#!zip -r results.zip results
