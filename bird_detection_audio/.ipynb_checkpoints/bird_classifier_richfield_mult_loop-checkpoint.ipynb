# %% [markdown]
# From https://medium.com/m2mtechconnect/classifying-music-and-speech-with-machine-learning-e036ffab002e

# %%
import numpy as np
import pandas as pd
import os
import pathlib
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import display
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import layers, regularizers, models
#import tensorflow_datasets as tfds
from datetime import datetime

# %%
import time

# %%
import ffmpeg
from pydub import AudioSegment

# %%
from tf_helpers import *

# %%
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, auc
import plotly.figure_factory as ff
from sklearn.preprocessing import OneHotEncoder

# %%
from data_set_params import DataSetParams
from scipy.io import wavfile
params = DataSetParams()

# %%
#data_dir = pathlib.Path('/root/tensorflow_datasets/downloads/extracted/TAR_GZ.opihi.cs.uvic.ca_sound_music_speechbya81rFcWfLSW6ey5cynqyeq2qiePcL-7asMoNO6IQ0.tar.gz/music_speech')
data_dir   = 'richfield_birds'#'dublin_dl_birds_split'#
categories = np.array(tf.io.gfile.listdir(data_dir))
categories = [category for category in categories if 'wav' not in category]
categories
# Out:
# ['Common Buzzard',
#  'Common Kestrel',
#  'Common Snipe',
#  'Eurasian Curlew',
#  'European Herring Gull',
#  'European Robin',
#  'Meadow Pipit',
#  'Mute Swan',
#  'Northern Lapwing',
#  'Rook',
#  'Tundra Swan',
#  'Tundra Swan (Bewicks)']

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = [filename for filename in filenames if 'wav' in filename]
#filenames = tf.random.shuffle(filenames)
#filenames

# %%
num_samples = len(filenames)
print('Number of total examples:', num_samples)
print('Number of categories', len(categories))
#print('Number of examples per label:',
#      len(tf.io.gfile.listdir(str(pathlib.Path(data_dir)/categories[0]))))
print('Example file tensor:', filenames[0])
# Out:
# Number of total examples: 1981
# Number of categories 12
# Example file tensor: richfield_birds\Meadow Pipit\xc476408_left.wav

# %%
AUTOTUNE   = tf.data.experimental.AUTOTUNE
TRAIN_SIZE = 0.8
cutoff     = int(len(filenames) * TRAIN_SIZE)

# %%
choice_list = []
choices_lst = ['Mod', 'AbsRe', 'AbsIm']#, 'AbsAng']
import itertools
for L in range(1,len(choices_lst)+1):
    for subset in itertools.combinations(choices_lst, L):
        choice_list.append(list(subset))

# %%
choice_list
# Out:
# [['Mod'],
#  ['AbsRe'],
#  ['AbsIm'],
#  ['Mod', 'AbsRe'],
#  ['Mod', 'AbsIm'],
#  ['AbsRe', 'AbsIm'],
#  ['Mod', 'AbsRe', 'AbsIm']]

# %% [markdown]
# ## Outline of script needed:
# for i in 1,...,20 iterations
# -  shuffles files
# -  seperates into train/test
# -  For different combinations of Mod (default), AbsRe, AbsIm, AbsArg
#     -  create spectrogram features (X) and labels (y)
#     -  create training and test tensorflow datasets and batch
#     -  train from scratch for 5,10,25,50 epochs
#     -  record history(loss, accuracy), yTrue and yPred,
#     -  save confusion matrices
# -  Also try
#     - work on making the convolution kernel different for each channel, and for the output to be the mean
#     - freeze layers (all but first or last) to fine tune training
#     - Transfer learning from BirdNet

# %%
def main_model_run(filenames, index):
    filenames   = tf.random.shuffle(filenames)
    train_files = filenames[:cutoff]
    test_files  = filenames[cutoff:]
    
    filename_idx = datetime.now().strftime("%Y%m%d-%H%M%S").replace('-', '_')+'_richfield_shallow_net'+str(index)
    
    np.save('filenames'+filename_idx+'.npy', filenames.numpy())
    print("index: ", index)
    for choices in choice_list:
        print('Choices: ', ''.join(choices))
        train_ds = preprocess_dataset(train_files, choices, categories)
        test_ds  = preprocess_dataset(test_files, choices, categories)
        
        for spec, _ in train_ds.take(1):
            input_shape = spec.shape
            
        num_classes = len(categories)
        batch_size = 32
        train_ds   = train_ds.batch(batch_size)
        test_ds    = test_ds.batch(batch_size)
        train_ds   = train_ds.cache().prefetch(AUTOTUNE)
        test_ds    = test_ds.cache().prefetch(AUTOTUNE)
        
        filename_run = filename_idx + ''.join(choices)+'_'
        print(not os.path.isdir('checkpoints/'+filename_run))
        if not os.path.isdir('checkpoints/'+filename_run):
            os.mkdir('checkpoints/'+filename_run)
        
        checkpoint_path = 'checkpoints/'+filename_run+"/cp-{epoch:04d}.ckpt"
        checkpoint_dir = os.path.dirname(checkpoint_path)
        
        cp_callback = tf.keras.callbacks.ModelCheckpoint(
            filepath= checkpoint_path, 
            verbose = 1, 
            save_weights_only = True,
            save_freq = 5*batch_size)
        
        model   = main_cnn(input_shape, num_classes)
        
        model.save_weights(checkpoint_path.format(epoch=0))
        
        EPOCHS  = 10
        history = model.fit(
            train_ds, 
            validation_data = test_ds, 
            callbacks       = [cp_callback],
            epochs          = EPOCHS)
        
        pd.DataFrame(history.history).to_csv('model_history'+filename_run+'.csv')
        
        
        model.save('models/'+filename_run+'.h5')
        y_pred = np.argmax(model.predict(test_ds), axis=-1)
        y_true = [y for _,y in test_ds.unbatch()]
        
        np.save('y_pred'+filename_run+'.npy', y_pred)
        np.save('y_true'+filename_run+'.npy', y_true)
        
        cm = confusion_matrix(y_true, y_pred)
        
        fig = plotly_cm(cm, categories)
        fig.write_html('confusion_matrix'+filename_run+'.html')
        
        pred_lists = model.predict(test_ds)
        pred_df    = pd.DataFrame(pred_lists, columns = categories)
        pred_df_softmax = pred_df.apply(lambda x: np.exp(x - np.max(x))/np.exp(x - np.max(x)).sum(), axis=1)
        
        pred_df_softmax.to_csv('pred_df_softmax'+filename_run+'.csv')

# %%
tic = time.time()

# %%
for i in range(10):
    main_model_run(filenames, i)
    print(time.time()-tic)
# Out:
# index:  0
# Choices:  Mod
# True
# Epoch 1/10
# 50/50 [==============================] - 52s 1s/step - loss: 2.6200 - accuracy: 0.1351 - val_loss: 2.4193 - val_accuracy: 0.2267
# Epoch 2/10
# 50/50 [==============================] - 11s 223ms/step - loss: 2.3792 - accuracy: 0.2298 - val_loss: 2.2815 - val_accuracy: 0.3199
# Epoch 3/10
# 50/50 [==============================] - 12s 243ms/step - loss: 2.2726 - accuracy: 0.3043 - val_loss: 2.1607 - val_accuracy: 0.3929
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 4s - loss: 2.2100 - accuracy: 0.3375
# Epoch 00004: saving model to checkpoints/20220126_115325_richfield_shallow_net0Mod_\cp-0004.ckpt
# 50/50 [==============================] - 12s 239ms/step - loss: 2.1199 - accuracy: 0.3687 - val_loss: 2.0583 - val_accuracy: 0.4156
# Epoch 5/10
# 50/50 [==============================] - 13s 265ms/step - loss: 2.0310 - accuracy: 0.4053 - val_loss: 1.9760 - val_accuracy: 0.4761
# Epoch 6/10
# 50/50 [==============================] - 13s 269ms/step - loss: 1.9406 - accuracy: 0.4179 - val_loss: 1.9119 - val_accuracy: 0.4962
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 7s - loss: 1.8203 - accuracy: 0.4484
# Epoch 00007: saving model to checkpoints/20220126_115325_richfield_shallow_net0Mod_\cp-0007.ckpt
# 50/50 [==============================] - 13s 266ms/step - loss: 1.8596 - accuracy: 0.4331 - val_loss: 1.8560 - val_accuracy: 0.5315
# Epoch 8/10
# 50/50 [==============================] - 13s 255ms/step - loss: 1.7954 - accuracy: 0.4741 - val_loss: 1.7945 - val_accuracy: 0.5340
# Epoch 9/10
# 50/50 [==============================] - 13s 265ms/step - loss: 1.7671 - accuracy: 0.4729 - val_loss: 1.7600 - val_accuracy: 0.5390
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.7093 - accuracy: 0.4885
# Epoch 00010: saving model to checkpoints/20220126_115325_richfield_shallow_net0Mod_\cp-0010.ckpt
# 50/50 [==============================] - 13s 254ms/step - loss: 1.6958 - accuracy: 0.4994 - val_loss: 1.7199 - val_accuracy: 0.5390
# Choices:  AbsRe
# True
# Epoch 1/10
# 50/50 [==============================] - 53s 1s/step - loss: 2.5445 - accuracy: 0.1503 - val_loss: 2.3936 - val_accuracy: 0.2846
# Epoch 2/10
# 50/50 [==============================] - 13s 268ms/step - loss: 2.3575 - accuracy: 0.2431 - val_loss: 2.2507 - val_accuracy: 0.3552
# Epoch 3/10
# 50/50 [==============================] - 13s 266ms/step - loss: 2.1950 - accuracy: 0.3125 - val_loss: 2.1181 - val_accuracy: 0.3879
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 9s - loss: 2.1435 - accuracy: 0.2906
# Epoch 00004: saving model to checkpoints/20220126_115325_richfield_shallow_net0AbsRe_\cp-0004.ckpt
# 50/50 [==============================] - 13s 260ms/step - loss: 2.0809 - accuracy: 0.3415 - val_loss: 2.0355 - val_accuracy: 0.4232
# Epoch 5/10
# 50/50 [==============================] - 13s 257ms/step - loss: 1.9672 - accuracy: 0.3984 - val_loss: 1.9614 - val_accuracy: 0.4635
# Epoch 6/10
# 50/50 [==============================] - 12s 243ms/step - loss: 1.9102 - accuracy: 0.4122 - val_loss: 1.8946 - val_accuracy: 0.4761
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.9374 - accuracy: 0.3875
# Epoch 00007: saving model to checkpoints/20220126_115325_richfield_shallow_net0AbsRe_\cp-0007.ckpt
# 50/50 [==============================] - 12s 244ms/step - loss: 1.8814 - accuracy: 0.4104 - val_loss: 1.8347 - val_accuracy: 0.4660
# Epoch 8/10
# 50/50 [==============================] - 12s 240ms/step - loss: 1.7883 - accuracy: 0.4722 - val_loss: 1.7903 - val_accuracy: 0.4610
# Epoch 9/10
# 50/50 [==============================] - 12s 248ms/step - loss: 1.7033 - accuracy: 0.4779 - val_loss: 1.7398 - val_accuracy: 0.4962
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6756 - accuracy: 0.4781
# Epoch 00010: saving model to checkpoints/20220126_115325_richfield_shallow_net0AbsRe_\cp-0010.ckpt
# 50/50 [==============================] - 13s 258ms/step - loss: 1.6579 - accuracy: 0.4861 - val_loss: 1.7025 - val_accuracy: 0.5038
# Choices:  AbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 54s 1s/step - loss: 2.5876 - accuracy: 0.1395 - val_loss: 2.4493 - val_accuracy: 0.2343
# Epoch 2/10
# 50/50 [==============================] - 12s 249ms/step - loss: 2.3867 - accuracy: 0.2563 - val_loss: 2.2780 - val_accuracy: 0.3955
# Epoch 3/10
# 50/50 [==============================] - 13s 252ms/step - loss: 2.2105 - accuracy: 0.3403 - val_loss: 2.1112 - val_accuracy: 0.3955
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 9s - loss: 2.1216 - accuracy: 0.3531
# Epoch 00004: saving model to checkpoints/20220126_115325_richfield_shallow_net0AbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 13s 261ms/step - loss: 2.1091 - accuracy: 0.3712 - val_loss: 2.0119 - val_accuracy: 0.4408
# Epoch 5/10
# 50/50 [==============================] - 14s 273ms/step - loss: 1.9916 - accuracy: 0.3920 - val_loss: 1.9191 - val_accuracy: 0.4786
# Epoch 6/10
# 50/50 [==============================] - 13s 268ms/step - loss: 1.8946 - accuracy: 0.4249 - val_loss: 1.8714 - val_accuracy: 0.4912
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 7s - loss: 1.8262 - accuracy: 0.4437
# Epoch 00007: saving model to checkpoints/20220126_115325_richfield_shallow_net0AbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 13s 269ms/step - loss: 1.8001 - accuracy: 0.4552 - val_loss: 1.8245 - val_accuracy: 0.4912
# Epoch 8/10
# 50/50 [==============================] - 13s 267ms/step - loss: 1.7608 - accuracy: 0.4678 - val_loss: 1.7864 - val_accuracy: 0.5013
# Epoch 9/10
# 50/50 [==============================] - 13s 270ms/step - loss: 1.6939 - accuracy: 0.4760 - val_loss: 1.7555 - val_accuracy: 0.5013
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6492 - accuracy: 0.4906
# Epoch 00010: saving model to checkpoints/20220126_115325_richfield_shallow_net0AbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 13s 263ms/step - loss: 1.6542 - accuracy: 0.4981 - val_loss: 1.7095 - val_accuracy: 0.5189
# Choices:  ModAbsRe
# True
# Epoch 1/10
# 50/50 [==============================] - 56s 1s/step - loss: 2.6797 - accuracy: 0.1313 - val_loss: 2.4061 - val_accuracy: 0.2872
# Epoch 2/10
# 50/50 [==============================] - 14s 272ms/step - loss: 2.3890 - accuracy: 0.2412 - val_loss: 2.2706 - val_accuracy: 0.3703
# Epoch 3/10
# 50/50 [==============================] - 13s 261ms/step - loss: 2.2765 - accuracy: 0.2992 - val_loss: 2.1392 - val_accuracy: 0.4282
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 10s - loss: 2.1260 - accuracy: 0.3562
# Epoch 00004: saving model to checkpoints/20220126_115325_richfield_shallow_net0ModAbsRe_\cp-0004.ckpt
# 50/50 [==============================] - 14s 282ms/step - loss: 2.1405 - accuracy: 0.3567 - val_loss: 2.0308 - val_accuracy: 0.4509
# Epoch 5/10
# 50/50 [==============================] - 14s 290ms/step - loss: 1.9990 - accuracy: 0.3920 - val_loss: 1.9292 - val_accuracy: 0.4761
# Epoch 6/10
# 50/50 [==============================] - 15s 297ms/step - loss: 1.9267 - accuracy: 0.4009 - val_loss: 1.8423 - val_accuracy: 0.5365
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 8s - loss: 1.8443 - accuracy: 0.4266
# Epoch 00007: saving model to checkpoints/20220126_115325_richfield_shallow_net0ModAbsRe_\cp-0007.ckpt
# 50/50 [==============================] - 15s 309ms/step - loss: 1.8269 - accuracy: 0.4407 - val_loss: 1.7751 - val_accuracy: 0.5340
# Epoch 8/10
# 50/50 [==============================] - 15s 302ms/step - loss: 1.7733 - accuracy: 0.4760 - val_loss: 1.7313 - val_accuracy: 0.5290
# Epoch 9/10
# 50/50 [==============================] - 15s 299ms/step - loss: 1.7161 - accuracy: 0.4956 - val_loss: 1.6905 - val_accuracy: 0.5491
# Epoch 10/10
# 30/50 [=================>............] - ETA: 5s - loss: 1.6382 - accuracy: 0.5156
# Epoch 00010: saving model to checkpoints/20220126_115325_richfield_shallow_net0ModAbsRe_\cp-0010.ckpt
# 50/50 [==============================] - 15s 301ms/step - loss: 1.6490 - accuracy: 0.5044 - val_loss: 1.6549 - val_accuracy: 0.5416
# Choices:  ModAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 56s 1s/step - loss: 2.6351 - accuracy: 0.1376 - val_loss: 2.4082 - val_accuracy: 0.2771
# Epoch 2/10
# 50/50 [==============================] - 14s 288ms/step - loss: 2.3752 - accuracy: 0.2323 - val_loss: 2.2478 - val_accuracy: 0.3728
# Epoch 3/10
# 50/50 [==============================] - 14s 286ms/step - loss: 2.2110 - accuracy: 0.3194 - val_loss: 2.0967 - val_accuracy: 0.4282
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 10s - loss: 2.1184 - accuracy: 0.3344
# Epoch 00004: saving model to checkpoints/20220126_115325_richfield_shallow_net0ModAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 14s 282ms/step - loss: 2.0839 - accuracy: 0.3775 - val_loss: 1.9866 - val_accuracy: 0.4761
# Epoch 5/10
# 50/50 [==============================] - 15s 291ms/step - loss: 2.0023 - accuracy: 0.4116 - val_loss: 1.9184 - val_accuracy: 0.5139
# Epoch 6/10
# 50/50 [==============================] - 15s 293ms/step - loss: 1.8778 - accuracy: 0.4343 - val_loss: 1.8436 - val_accuracy: 0.5315
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 8s - loss: 1.8538 - accuracy: 0.4641
# Epoch 00007: saving model to checkpoints/20220126_115325_richfield_shallow_net0ModAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 15s 293ms/step - loss: 1.8018 - accuracy: 0.4628 - val_loss: 1.7647 - val_accuracy: 0.5441
# Epoch 8/10
# 50/50 [==============================] - 15s 299ms/step - loss: 1.7101 - accuracy: 0.4766 - val_loss: 1.7010 - val_accuracy: 0.5290
# Epoch 9/10
# 50/50 [==============================] - 14s 287ms/step - loss: 1.6807 - accuracy: 0.4956 - val_loss: 1.6668 - val_accuracy: 0.5542
# Epoch 10/10
# 30/50 [=================>............] - ETA: 5s - loss: 1.5967 - accuracy: 0.5094
# Epoch 00010: saving model to checkpoints/20220126_115325_richfield_shallow_net0ModAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 15s 298ms/step - loss: 1.6010 - accuracy: 0.5208 - val_loss: 1.6203 - val_accuracy: 0.5668
# Choices:  AbsReAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 57s 1s/step - loss: 2.5452 - accuracy: 0.1433 - val_loss: 2.4148 - val_accuracy: 0.2418
# Epoch 2/10
# 50/50 [==============================] - 15s 294ms/step - loss: 2.3463 - accuracy: 0.2601 - val_loss: 2.2363 - val_accuracy: 0.3929
# Epoch 3/10
# 50/50 [==============================] - 15s 292ms/step - loss: 2.1940 - accuracy: 0.3157 - val_loss: 2.0926 - val_accuracy: 0.4181
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 10s - loss: 2.1869 - accuracy: 0.3031
# Epoch 00004: saving model to checkpoints/20220126_115325_richfield_shallow_net0AbsReAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 15s 294ms/step - loss: 2.1074 - accuracy: 0.3580 - val_loss: 2.0091 - val_accuracy: 0.4660
# Epoch 5/10
# 50/50 [==============================] - 15s 294ms/step - loss: 1.9677 - accuracy: 0.4053 - val_loss: 1.8983 - val_accuracy: 0.5088
# Epoch 6/10
# 50/50 [==============================] - 15s 295ms/step - loss: 1.8517 - accuracy: 0.4451 - val_loss: 1.8309 - val_accuracy: 0.5214
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 8s - loss: 1.8176 - accuracy: 0.4375
# Epoch 00007: saving model to checkpoints/20220126_115325_richfield_shallow_net0AbsReAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 15s 300ms/step - loss: 1.8263 - accuracy: 0.4426 - val_loss: 1.7783 - val_accuracy: 0.5416
# Epoch 8/10
# 50/50 [==============================] - 15s 298ms/step - loss: 1.7147 - accuracy: 0.4886 - val_loss: 1.7193 - val_accuracy: 0.5542
# Epoch 9/10
# 50/50 [==============================] - 15s 295ms/step - loss: 1.6690 - accuracy: 0.5126 - val_loss: 1.6712 - val_accuracy: 0.5642
# Epoch 10/10
# 30/50 [=================>............] - ETA: 5s - loss: 1.6129 - accuracy: 0.5104
# Epoch 00010: saving model to checkpoints/20220126_115325_richfield_shallow_net0AbsReAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 15s 294ms/step - loss: 1.6393 - accuracy: 0.5044 - val_loss: 1.6324 - val_accuracy: 0.5945
# Choices:  ModAbsReAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 59s 1s/step - loss: 2.5943 - accuracy: 0.1471 - val_loss: 2.4315 - val_accuracy: 0.2872
# Epoch 2/10
# 50/50 [==============================] - 15s 299ms/step - loss: 2.3867 - accuracy: 0.2746 - val_loss: 2.2912 - val_accuracy: 0.3904
# Epoch 3/10
# 50/50 [==============================] - 15s 303ms/step - loss: 2.2396 - accuracy: 0.3289 - val_loss: 2.1835 - val_accuracy: 0.4030
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 11s - loss: 2.1908 - accuracy: 0.3313
# Epoch 00004: saving model to checkpoints/20220126_115325_richfield_shallow_net0ModAbsReAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 15s 304ms/step - loss: 2.1392 - accuracy: 0.3554 - val_loss: 2.1087 - val_accuracy: 0.4181
# Epoch 5/10
# 50/50 [==============================] - 15s 305ms/step - loss: 2.0424 - accuracy: 0.3832 - val_loss: 2.0261 - val_accuracy: 0.4836
# Epoch 6/10
# 50/50 [==============================] - 15s 306ms/step - loss: 1.9442 - accuracy: 0.4198 - val_loss: 1.9426 - val_accuracy: 0.4987
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 8s - loss: 1.8456 - accuracy: 0.4547
# Epoch 00007: saving model to checkpoints/20220126_115325_richfield_shallow_net0ModAbsReAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 15s 304ms/step - loss: 1.8404 - accuracy: 0.4501 - val_loss: 1.8720 - val_accuracy: 0.5315
# Epoch 8/10
# 50/50 [==============================] - 15s 305ms/step - loss: 1.8036 - accuracy: 0.4615 - val_loss: 1.8369 - val_accuracy: 0.5239
# Epoch 9/10
# 50/50 [==============================] - 15s 308ms/step - loss: 1.7079 - accuracy: 0.4855 - val_loss: 1.7976 - val_accuracy: 0.5416
# Epoch 10/10
# 30/50 [=================>............] - ETA: 5s - loss: 1.7037 - accuracy: 0.5094
# Epoch 00010: saving model to checkpoints/20220126_115325_richfield_shallow_net0ModAbsReAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 15s 300ms/step - loss: 1.7047 - accuracy: 0.5114 - val_loss: 1.7486 - val_accuracy: 0.5693
# 1315.1471862792969
# index:  1
# Choices:  Mod
# True
# Epoch 1/10
# 50/50 [==============================] - 58s 1s/step - loss: 2.6109 - accuracy: 0.1439 - val_loss: 2.3946 - val_accuracy: 0.3023
# Epoch 2/10
# 50/50 [==============================] - 12s 243ms/step - loss: 2.3835 - accuracy: 0.2620 - val_loss: 2.2267 - val_accuracy: 0.3728
# Epoch 3/10
# 50/50 [==============================] - 12s 244ms/step - loss: 2.2529 - accuracy: 0.3119 - val_loss: 2.1010 - val_accuracy: 0.4181
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.1812 - accuracy: 0.3406
# Epoch 00004: saving model to checkpoints/20220126_121520_richfield_shallow_net1Mod_\cp-0004.ckpt
# 50/50 [==============================] - 12s 244ms/step - loss: 2.1689 - accuracy: 0.3359 - val_loss: 2.0118 - val_accuracy: 0.4786
# Epoch 5/10
# 50/50 [==============================] - 12s 244ms/step - loss: 2.0433 - accuracy: 0.3782 - val_loss: 1.9326 - val_accuracy: 0.4987
# Epoch 6/10
# 50/50 [==============================] - 13s 256ms/step - loss: 1.9791 - accuracy: 0.4110 - val_loss: 1.8653 - val_accuracy: 0.5088
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.8640 - accuracy: 0.4547
# Epoch 00007: saving model to checkpoints/20220126_121520_richfield_shallow_net1Mod_\cp-0007.ckpt
# 50/50 [==============================] - 12s 246ms/step - loss: 1.8974 - accuracy: 0.4413 - val_loss: 1.8058 - val_accuracy: 0.5038
# Epoch 8/10
# 50/50 [==============================] - 13s 251ms/step - loss: 1.8650 - accuracy: 0.4438 - val_loss: 1.7815 - val_accuracy: 0.5340
# Epoch 9/10
# 50/50 [==============================] - 12s 247ms/step - loss: 1.7440 - accuracy: 0.4886 - val_loss: 1.7233 - val_accuracy: 0.5365
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.7344 - accuracy: 0.4938
# Epoch 00010: saving model to checkpoints/20220126_121520_richfield_shallow_net1Mod_\cp-0010.ckpt
# 50/50 [==============================] - 13s 252ms/step - loss: 1.7311 - accuracy: 0.4855 - val_loss: 1.6901 - val_accuracy: 0.5113
# Choices:  AbsRe
# True
# Epoch 1/10
# 50/50 [==============================] - 56s 1s/step - loss: 2.5610 - accuracy: 0.1345 - val_loss: 2.4330 - val_accuracy: 0.2418
# Epoch 2/10
# 50/50 [==============================] - 14s 284ms/step - loss: 2.3781 - accuracy: 0.2374 - val_loss: 2.2496 - val_accuracy: 0.3778
# Epoch 3/10
# 50/50 [==============================] - 14s 278ms/step - loss: 2.2020 - accuracy: 0.3131 - val_loss: 2.0810 - val_accuracy: 0.4156
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 10s - loss: 2.1452 - accuracy: 0.3656
# Epoch 00004: saving model to checkpoints/20220126_121520_richfield_shallow_net1AbsRe_\cp-0004.ckpt
# 50/50 [==============================] - 14s 279ms/step - loss: 2.0863 - accuracy: 0.3674 - val_loss: 1.9632 - val_accuracy: 0.4484
# Epoch 5/10
# 50/50 [==============================] - 14s 281ms/step - loss: 1.9433 - accuracy: 0.3965 - val_loss: 1.8855 - val_accuracy: 0.4635
# Epoch 6/10
# 50/50 [==============================] - 14s 281ms/step - loss: 1.8743 - accuracy: 0.4261 - val_loss: 1.8472 - val_accuracy: 0.4534
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 7s - loss: 1.7843 - accuracy: 0.4453
# Epoch 00007: saving model to checkpoints/20220126_121520_richfield_shallow_net1AbsRe_\cp-0007.ckpt
# 50/50 [==============================] - 14s 277ms/step - loss: 1.7982 - accuracy: 0.4501 - val_loss: 1.7947 - val_accuracy: 0.4660
# Epoch 8/10
# 50/50 [==============================] - 14s 279ms/step - loss: 1.6979 - accuracy: 0.4823 - val_loss: 1.7482 - val_accuracy: 0.4811
# Epoch 9/10
# 50/50 [==============================] - 14s 280ms/step - loss: 1.6807 - accuracy: 0.4798 - val_loss: 1.7117 - val_accuracy: 0.4861
# Epoch 10/10
# 30/50 [=================>............] - ETA: 5s - loss: 1.6035 - accuracy: 0.5208
# Epoch 00010: saving model to checkpoints/20220126_121520_richfield_shallow_net1AbsRe_\cp-0010.ckpt
# 50/50 [==============================] - 14s 279ms/step - loss: 1.6090 - accuracy: 0.5152 - val_loss: 1.6689 - val_accuracy: 0.5189
# Choices:  AbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 57s 1s/step - loss: 2.5907 - accuracy: 0.1414 - val_loss: 2.4816 - val_accuracy: 0.2343
# Epoch 2/10
# 50/50 [==============================] - 14s 279ms/step - loss: 2.4401 - accuracy: 0.2203 - val_loss: 2.3418 - val_accuracy: 0.3300
# Epoch 3/10
# 50/50 [==============================] - 14s 275ms/step - loss: 2.2859 - accuracy: 0.3062 - val_loss: 2.1762 - val_accuracy: 0.4030
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 10s - loss: 2.2314 - accuracy: 0.3531
# Epoch 00004: saving model to checkpoints/20220126_121520_richfield_shallow_net1AbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 14s 280ms/step - loss: 2.1674 - accuracy: 0.3453 - val_loss: 2.0329 - val_accuracy: 0.4811
# Epoch 5/10
# 50/50 [==============================] - 14s 280ms/step - loss: 2.0475 - accuracy: 0.3895 - val_loss: 1.9429 - val_accuracy: 0.4584
# Epoch 6/10
# 50/50 [==============================] - 14s 278ms/step - loss: 1.9466 - accuracy: 0.3990 - val_loss: 1.8684 - val_accuracy: 0.4761
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 7s - loss: 1.8631 - accuracy: 0.4219
# Epoch 00007: saving model to checkpoints/20220126_121520_richfield_shallow_net1AbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 13s 251ms/step - loss: 1.8394 - accuracy: 0.4438 - val_loss: 1.8138 - val_accuracy: 0.5013
# Epoch 8/10
# 50/50 [==============================] - 12s 243ms/step - loss: 1.7825 - accuracy: 0.4653 - val_loss: 1.7735 - val_accuracy: 0.5013
# Epoch 9/10
# 50/50 [==============================] - 12s 246ms/step - loss: 1.7548 - accuracy: 0.4754 - val_loss: 1.7436 - val_accuracy: 0.5214
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6872 - accuracy: 0.4865
# Epoch 00010: saving model to checkpoints/20220126_121520_richfield_shallow_net1AbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 12s 246ms/step - loss: 1.6832 - accuracy: 0.4804 - val_loss: 1.7091 - val_accuracy: 0.5390
# Choices:  ModAbsRe
# True
# Epoch 1/10
# 50/50 [==============================] - 49s 972ms/step - loss: 2.5971 - accuracy: 0.1452 - val_loss: 2.3989 - val_accuracy: 0.2594
# Epoch 2/10
# 50/50 [==============================] - 11s 226ms/step - loss: 2.3687 - accuracy: 0.2405 - val_loss: 2.2314 - val_accuracy: 0.3804
# Epoch 3/10
# 50/50 [==============================] - 12s 231ms/step - loss: 2.2377 - accuracy: 0.3056 - val_loss: 2.0937 - val_accuracy: 0.4484
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 9s - loss: 2.1197 - accuracy: 0.3625
# Epoch 00004: saving model to checkpoints/20220126_121520_richfield_shallow_net1ModAbsRe_\cp-0004.ckpt
# 50/50 [==============================] - 12s 235ms/step - loss: 2.0894 - accuracy: 0.3592 - val_loss: 1.9723 - val_accuracy: 0.4660
# Epoch 5/10
# 50/50 [==============================] - 12s 233ms/step - loss: 1.9812 - accuracy: 0.3756 - val_loss: 1.8887 - val_accuracy: 0.4761
# Epoch 6/10
# 50/50 [==============================] - 11s 228ms/step - loss: 1.9126 - accuracy: 0.4091 - val_loss: 1.8152 - val_accuracy: 0.4962
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.7721 - accuracy: 0.4641
# Epoch 00007: saving model to checkpoints/20220126_121520_richfield_shallow_net1ModAbsRe_\cp-0007.ckpt
# 50/50 [==============================] - 12s 233ms/step - loss: 1.7860 - accuracy: 0.4628 - val_loss: 1.7446 - val_accuracy: 0.4887
# Epoch 8/10
# 50/50 [==============================] - 11s 222ms/step - loss: 1.7347 - accuracy: 0.4583 - val_loss: 1.6992 - val_accuracy: 0.5063
# Epoch 9/10
# 50/50 [==============================] - 11s 223ms/step - loss: 1.6326 - accuracy: 0.4918 - val_loss: 1.6507 - val_accuracy: 0.5441
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6327 - accuracy: 0.5031
# Epoch 00010: saving model to checkpoints/20220126_121520_richfield_shallow_net1ModAbsRe_\cp-0010.ckpt
# 50/50 [==============================] - 12s 231ms/step - loss: 1.6337 - accuracy: 0.4943 - val_loss: 1.6328 - val_accuracy: 0.5441
# Choices:  ModAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 47s 938ms/step - loss: 2.6104 - accuracy: 0.1439 - val_loss: 2.4095 - val_accuracy: 0.2846
# Epoch 2/10
# 50/50 [==============================] - 11s 222ms/step - loss: 2.3851 - accuracy: 0.2279 - val_loss: 2.2495 - val_accuracy: 0.4081
# Epoch 3/10
# 50/50 [==============================] - 11s 225ms/step - loss: 2.2375 - accuracy: 0.2860 - val_loss: 2.0928 - val_accuracy: 0.4610
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.1683 - accuracy: 0.3063
# Epoch 00004: saving model to checkpoints/20220126_121520_richfield_shallow_net1ModAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 12s 237ms/step - loss: 2.1164 - accuracy: 0.3586 - val_loss: 1.9740 - val_accuracy: 0.4811
# Epoch 5/10
# 50/50 [==============================] - 11s 224ms/step - loss: 2.0132 - accuracy: 0.3725 - val_loss: 1.8893 - val_accuracy: 0.4962
# Epoch 6/10
# 50/50 [==============================] - 11s 225ms/step - loss: 1.9043 - accuracy: 0.4280 - val_loss: 1.8297 - val_accuracy: 0.4962
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.7641 - accuracy: 0.4703
# Epoch 00007: saving model to checkpoints/20220126_121520_richfield_shallow_net1ModAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 12s 232ms/step - loss: 1.7973 - accuracy: 0.4476 - val_loss: 1.7522 - val_accuracy: 0.5290
# Epoch 8/10
# 50/50 [==============================] - 11s 221ms/step - loss: 1.7347 - accuracy: 0.4817 - val_loss: 1.7140 - val_accuracy: 0.5441
# Epoch 9/10
# 50/50 [==============================] - 11s 223ms/step - loss: 1.6507 - accuracy: 0.4956 - val_loss: 1.6984 - val_accuracy: 0.5315
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6479 - accuracy: 0.5052
# Epoch 00010: saving model to checkpoints/20220126_121520_richfield_shallow_net1ModAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 12s 239ms/step - loss: 1.6306 - accuracy: 0.5101 - val_loss: 1.6514 - val_accuracy: 0.5441
# Choices:  AbsReAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 46s 920ms/step - loss: 2.6014 - accuracy: 0.1420 - val_loss: 2.4225 - val_accuracy: 0.2897
# Epoch 2/10
# 50/50 [==============================] - 12s 235ms/step - loss: 2.3951 - accuracy: 0.2355 - val_loss: 2.2654 - val_accuracy: 0.3929
# Epoch 3/10
# 50/50 [==============================] - 11s 230ms/step - loss: 2.2688 - accuracy: 0.3049 - val_loss: 2.1487 - val_accuracy: 0.4509
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.1518 - accuracy: 0.3500
# Epoch 00004: saving model to checkpoints/20220126_121520_richfield_shallow_net1AbsReAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 12s 242ms/step - loss: 2.1732 - accuracy: 0.3396 - val_loss: 2.0440 - val_accuracy: 0.4710
# Epoch 5/10
# 50/50 [==============================] - 12s 231ms/step - loss: 2.0769 - accuracy: 0.3775 - val_loss: 1.9553 - val_accuracy: 0.4912
# Epoch 6/10
# 50/50 [==============================] - 12s 235ms/step - loss: 1.9686 - accuracy: 0.3946 - val_loss: 1.8778 - val_accuracy: 0.5013
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.8646 - accuracy: 0.4469
# Epoch 00007: saving model to checkpoints/20220126_121520_richfield_shallow_net1AbsReAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 12s 233ms/step - loss: 1.8716 - accuracy: 0.4495 - val_loss: 1.8423 - val_accuracy: 0.4937
# Epoch 8/10
# 50/50 [==============================] - 11s 230ms/step - loss: 1.8255 - accuracy: 0.4520 - val_loss: 1.7786 - val_accuracy: 0.5113
# Epoch 9/10
# 50/50 [==============================] - 11s 223ms/step - loss: 1.7550 - accuracy: 0.4634 - val_loss: 1.7267 - val_accuracy: 0.5013
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.7011 - accuracy: 0.4698
# Epoch 00010: saving model to checkpoints/20220126_121520_richfield_shallow_net1AbsReAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 12s 232ms/step - loss: 1.6978 - accuracy: 0.4798 - val_loss: 1.7052 - val_accuracy: 0.5315
# Choices:  ModAbsReAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 48s 945ms/step - loss: 2.7627 - accuracy: 0.1130 - val_loss: 2.4236 - val_accuracy: 0.2720
# Epoch 2/10
# 50/50 [==============================] - 12s 236ms/step - loss: 2.4163 - accuracy: 0.2159 - val_loss: 2.2531 - val_accuracy: 0.3627
# Epoch 3/10
# 50/50 [==============================] - 12s 235ms/step - loss: 2.3203 - accuracy: 0.2633 - val_loss: 2.1299 - val_accuracy: 0.3879
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.2405 - accuracy: 0.2844
# Epoch 00004: saving model to checkpoints/20220126_121520_richfield_shallow_net1ModAbsReAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 12s 248ms/step - loss: 2.1981 - accuracy: 0.3163 - val_loss: 2.0287 - val_accuracy: 0.4358
# Epoch 5/10
# 50/50 [==============================] - 12s 231ms/step - loss: 2.0705 - accuracy: 0.3485 - val_loss: 1.9389 - val_accuracy: 0.4484
# Epoch 6/10
# 50/50 [==============================] - 12s 232ms/step - loss: 2.0279 - accuracy: 0.3750 - val_loss: 1.8821 - val_accuracy: 0.4660
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.9009 - accuracy: 0.4172
# Epoch 00007: saving model to checkpoints/20220126_121520_richfield_shallow_net1ModAbsReAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 12s 232ms/step - loss: 1.9429 - accuracy: 0.3946 - val_loss: 1.8299 - val_accuracy: 0.5063
# Epoch 8/10
# 50/50 [==============================] - 11s 229ms/step - loss: 1.8461 - accuracy: 0.4242 - val_loss: 1.7791 - val_accuracy: 0.4861
# Epoch 9/10
# 50/50 [==============================] - 11s 227ms/step - loss: 1.7773 - accuracy: 0.4520 - val_loss: 1.7336 - val_accuracy: 0.5038
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.7210 - accuracy: 0.4896
# Epoch 00010: saving model to checkpoints/20220126_121520_richfield_shallow_net1ModAbsReAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 12s 245ms/step - loss: 1.7395 - accuracy: 0.4766 - val_loss: 1.6815 - val_accuracy: 0.5214
# 2480.6629836559296
# index:  2
# Choices:  Mod
# True
# Epoch 1/10
# 50/50 [==============================] - 47s 940ms/step - loss: 2.6510 - accuracy: 0.1376 - val_loss: 2.4157 - val_accuracy: 0.2217
# Epoch 2/10
# 50/50 [==============================] - 11s 228ms/step - loss: 2.3745 - accuracy: 0.2424 - val_loss: 2.2419 - val_accuracy: 0.3476
# Epoch 3/10
# 50/50 [==============================] - 12s 231ms/step - loss: 2.2112 - accuracy: 0.3277 - val_loss: 2.1046 - val_accuracy: 0.3879
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.0176 - accuracy: 0.3938
# Epoch 00004: saving model to checkpoints/20220126_123446_richfield_shallow_net2Mod_\cp-0004.ckpt
# 50/50 [==============================] - 12s 233ms/step - loss: 2.1299 - accuracy: 0.3725 - val_loss: 2.0329 - val_accuracy: 0.4282
# Epoch 5/10
# 50/50 [==============================] - 12s 234ms/step - loss: 1.9910 - accuracy: 0.4072 - val_loss: 1.9520 - val_accuracy: 0.4458
# Epoch 6/10
# 50/50 [==============================] - 12s 236ms/step - loss: 1.9747 - accuracy: 0.4085 - val_loss: 1.8880 - val_accuracy: 0.4962- ETA: 3s
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.8398 - accuracy: 0.4891
# Epoch 00007: saving model to checkpoints/20220126_123446_richfield_shallow_net2Mod_\cp-0007.ckpt
# 50/50 [==============================] - 11s 226ms/step - loss: 1.8876 - accuracy: 0.4476 - val_loss: 1.8600 - val_accuracy: 0.4987
# Epoch 8/10
# 50/50 [==============================] - 10s 210ms/step - loss: 1.8309 - accuracy: 0.4482 - val_loss: 1.7914 - val_accuracy: 0.5264
# Epoch 9/10
# 50/50 [==============================] - 11s 217ms/step - loss: 1.7562 - accuracy: 0.4867 - val_loss: 1.7715 - val_accuracy: 0.5315
# Epoch 10/10
# 30/50 [=================>............] - ETA: 3s - loss: 1.6978 - accuracy: 0.5052
# Epoch 00010: saving model to checkpoints/20220126_123446_richfield_shallow_net2Mod_\cp-0010.ckpt
# 50/50 [==============================] - 10s 210ms/step - loss: 1.6800 - accuracy: 0.5120 - val_loss: 1.7208 - val_accuracy: 0.5592
# Choices:  AbsRe
# True
# Epoch 1/10
# 50/50 [==============================] - 45s 886ms/step - loss: 2.5891 - accuracy: 0.1427 - val_loss: 2.4135 - val_accuracy: 0.2519
# Epoch 2/10
# 50/50 [==============================] - 11s 215ms/step - loss: 2.4023 - accuracy: 0.2367 - val_loss: 2.2642 - val_accuracy: 0.3678
# Epoch 3/10
# 50/50 [==============================] - 11s 212ms/step - loss: 2.2614 - accuracy: 0.3119 - val_loss: 2.1402 - val_accuracy: 0.3778
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 7s - loss: 2.1482 - accuracy: 0.3406
# Epoch 00004: saving model to checkpoints/20220126_123446_richfield_shallow_net2AbsRe_\cp-0004.ckpt
# 50/50 [==============================] - 11s 218ms/step - loss: 2.1451 - accuracy: 0.3529 - val_loss: 2.0443 - val_accuracy: 0.3955
# Epoch 5/10
# 50/50 [==============================] - 11s 211ms/step - loss: 2.0536 - accuracy: 0.4066 - val_loss: 1.9594 - val_accuracy: 0.4232
# Epoch 6/10
# 50/50 [==============================] - 11s 216ms/step - loss: 1.9690 - accuracy: 0.4173 - val_loss: 1.8971 - val_accuracy: 0.4559
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 5s - loss: 1.8405 - accuracy: 0.4672
# Epoch 00007: saving model to checkpoints/20220126_123446_richfield_shallow_net2AbsRe_\cp-0007.ckpt
# 50/50 [==============================] - 11s 212ms/step - loss: 1.8758 - accuracy: 0.4350 - val_loss: 1.8308 - val_accuracy: 0.4786
# Epoch 8/10
# 50/50 [==============================] - 11s 219ms/step - loss: 1.8357 - accuracy: 0.4482 - val_loss: 1.8025 - val_accuracy: 0.4786
# Epoch 9/10
# 50/50 [==============================] - 9s 191ms/step - loss: 1.7944 - accuracy: 0.4785 - val_loss: 1.7547 - val_accuracy: 0.5290
# Epoch 10/10
# 30/50 [=================>............] - ETA: 3s - loss: 1.7131 - accuracy: 0.4969
# Epoch 00010: saving model to checkpoints/20220126_123446_richfield_shallow_net2AbsRe_\cp-0010.ckpt
# 50/50 [==============================] - 11s 210ms/step - loss: 1.7326 - accuracy: 0.4968 - val_loss: 1.7220 - val_accuracy: 0.5466
# Choices:  AbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 48s 946ms/step - loss: 2.5922 - accuracy: 0.1402 - val_loss: 2.4381 - val_accuracy: 0.2217
# Epoch 2/10
# 50/50 [==============================] - 11s 218ms/step - loss: 2.4037 - accuracy: 0.2336 - val_loss: 2.2800 - val_accuracy: 0.3300
# Epoch 3/10
# 50/50 [==============================] - 11s 227ms/step - loss: 2.2168 - accuracy: 0.3093 - val_loss: 2.1352 - val_accuracy: 0.3703
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.1301 - accuracy: 0.3906
# Epoch 00004: saving model to checkpoints/20220126_123446_richfield_shallow_net2AbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 11s 224ms/step - loss: 2.1458 - accuracy: 0.3378 - val_loss: 2.0362 - val_accuracy: 0.4383
# Epoch 5/10
# 50/50 [==============================] - 11s 215ms/step - loss: 2.0613 - accuracy: 0.3864 - val_loss: 1.9709 - val_accuracy: 0.4232
# Epoch 6/10
# 50/50 [==============================] - 11s 218ms/step - loss: 1.9605 - accuracy: 0.4066 - val_loss: 1.9104 - val_accuracy: 0.4836
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 5s - loss: 1.8982 - accuracy: 0.4500
# Epoch 00007: saving model to checkpoints/20220126_123446_richfield_shallow_net2AbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 11s 216ms/step - loss: 1.9170 - accuracy: 0.4343 - val_loss: 1.8487 - val_accuracy: 0.4962
# Epoch 8/10
# 50/50 [==============================] - 11s 216ms/step - loss: 1.8451 - accuracy: 0.4463 - val_loss: 1.8197 - val_accuracy: 0.5239
# Epoch 9/10
# 50/50 [==============================] - 11s 212ms/step - loss: 1.7893 - accuracy: 0.4659 - val_loss: 1.7707 - val_accuracy: 0.5642
# Epoch 10/10
# 30/50 [=================>............] - ETA: 3s - loss: 1.7268 - accuracy: 0.4875
# Epoch 00010: saving model to checkpoints/20220126_123446_richfield_shallow_net2AbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 11s 215ms/step - loss: 1.7246 - accuracy: 0.4893 - val_loss: 1.7201 - val_accuracy: 0.5819
# Choices:  ModAbsRe
# True
# Epoch 1/10
# 50/50 [==============================] - 47s 941ms/step - loss: 2.6080 - accuracy: 0.1477 - val_loss: 2.3929 - val_accuracy: 0.2972
# Epoch 2/10
# 50/50 [==============================] - 11s 227ms/step - loss: 2.3654 - accuracy: 0.2519 - val_loss: 2.2202 - val_accuracy: 0.3678
# Epoch 3/10
# 50/50 [==============================] - 11s 227ms/step - loss: 2.1850 - accuracy: 0.3359 - val_loss: 2.0752 - val_accuracy: 0.4584
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.0462 - accuracy: 0.3688
# Epoch 00004: saving model to checkpoints/20220126_123446_richfield_shallow_net2ModAbsRe_\cp-0004.ckpt
# 50/50 [==============================] - 12s 236ms/step - loss: 2.0920 - accuracy: 0.3567 - val_loss: 1.9661 - val_accuracy: 0.4811
# Epoch 5/10
# 50/50 [==============================] - 11s 225ms/step - loss: 1.9954 - accuracy: 0.3908 - val_loss: 1.8907 - val_accuracy: 0.4811
# Epoch 6/10
# 50/50 [==============================] - 11s 229ms/step - loss: 1.8891 - accuracy: 0.4261 - val_loss: 1.8070 - val_accuracy: 0.5264
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.8243 - accuracy: 0.4563
# Epoch 00007: saving model to checkpoints/20220126_123446_richfield_shallow_net2ModAbsRe_\cp-0007.ckpt
# 50/50 [==============================] - 12s 230ms/step - loss: 1.8307 - accuracy: 0.4520 - val_loss: 1.7403 - val_accuracy: 0.5365
# Epoch 8/10
# 50/50 [==============================] - 11s 229ms/step - loss: 1.7480 - accuracy: 0.4741 - val_loss: 1.6991 - val_accuracy: 0.5139
# Epoch 9/10
# 50/50 [==============================] - 11s 227ms/step - loss: 1.6918 - accuracy: 0.4842 - val_loss: 1.6653 - val_accuracy: 0.5592
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6212 - accuracy: 0.4979
# Epoch 00010: saving model to checkpoints/20220126_123446_richfield_shallow_net2ModAbsRe_\cp-0010.ckpt
# 50/50 [==============================] - 11s 229ms/step - loss: 1.6157 - accuracy: 0.5000 - val_loss: 1.6379 - val_accuracy: 0.5491
# Choices:  ModAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 46s 905ms/step - loss: 2.6465 - accuracy: 0.1256 - val_loss: 2.4307 - val_accuracy: 0.2494
# Epoch 2/10
# 50/50 [==============================] - 11s 226ms/step - loss: 2.3923 - accuracy: 0.2380 - val_loss: 2.2525 - val_accuracy: 0.3728
# Epoch 3/10
# 50/50 [==============================] - 11s 223ms/step - loss: 2.2328 - accuracy: 0.3068 - val_loss: 2.1008 - val_accuracy: 0.4232
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.1831 - accuracy: 0.3156
# Epoch 00004: saving model to checkpoints/20220126_123446_richfield_shallow_net2ModAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 12s 234ms/step - loss: 2.1189 - accuracy: 0.3542 - val_loss: 1.9931 - val_accuracy: 0.4307
# Epoch 5/10
# 50/50 [==============================] - 11s 224ms/step - loss: 2.0576 - accuracy: 0.3977 - val_loss: 1.9307 - val_accuracy: 0.4584
# Epoch 6/10
# 50/50 [==============================] - 12s 234ms/step - loss: 1.9934 - accuracy: 0.4028 - val_loss: 1.8690 - val_accuracy: 0.4987
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.8823 - accuracy: 0.4313
# Epoch 00007: saving model to checkpoints/20220126_123446_richfield_shallow_net2ModAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 11s 223ms/step - loss: 1.8845 - accuracy: 0.4318 - val_loss: 1.7951 - val_accuracy: 0.4861
# Epoch 8/10
# 50/50 [==============================] - 11s 227ms/step - loss: 1.8348 - accuracy: 0.4545 - val_loss: 1.7484 - val_accuracy: 0.5239
# Epoch 9/10
# 50/50 [==============================] - 11s 228ms/step - loss: 1.7336 - accuracy: 0.4937 - val_loss: 1.6992 - val_accuracy: 0.5365
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6745 - accuracy: 0.5031
# Epoch 00010: saving model to checkpoints/20220126_123446_richfield_shallow_net2ModAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 11s 228ms/step - loss: 1.6708 - accuracy: 0.4924 - val_loss: 1.6733 - val_accuracy: 0.5542
# Choices:  AbsReAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 46s 915ms/step - loss: 2.5773 - accuracy: 0.1301 - val_loss: 2.3682 - val_accuracy: 0.2947
# Epoch 2/10
# 50/50 [==============================] - 11s 227ms/step - loss: 2.3548 - accuracy: 0.2500 - val_loss: 2.2079 - val_accuracy: 0.3652
# Epoch 3/10
# 50/50 [==============================] - 11s 228ms/step - loss: 2.2253 - accuracy: 0.3138 - val_loss: 2.0880 - val_accuracy: 0.4005
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.1015 - accuracy: 0.3719
# Epoch 00004: saving model to checkpoints/20220126_123446_richfield_shallow_net2AbsReAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 12s 233ms/step - loss: 2.1063 - accuracy: 0.3554 - val_loss: 1.9822 - val_accuracy: 0.4307
# Epoch 5/10
# 50/50 [==============================] - 11s 226ms/step - loss: 2.0227 - accuracy: 0.3838 - val_loss: 1.8968 - val_accuracy: 0.4484
# Epoch 6/10
# 50/50 [==============================] - 11s 226ms/step - loss: 1.9031 - accuracy: 0.4091 - val_loss: 1.8022 - val_accuracy: 0.5013
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.8175 - accuracy: 0.4594
# Epoch 00007: saving model to checkpoints/20220126_123446_richfield_shallow_net2AbsReAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 12s 231ms/step - loss: 1.8309 - accuracy: 0.4501 - val_loss: 1.7627 - val_accuracy: 0.5340
# Epoch 8/10
# 50/50 [==============================] - 11s 223ms/step - loss: 1.7521 - accuracy: 0.4653 - val_loss: 1.7183 - val_accuracy: 0.5340
# Epoch 9/10
# 50/50 [==============================] - 11s 220ms/step - loss: 1.7222 - accuracy: 0.4912 - val_loss: 1.6871 - val_accuracy: 0.5642
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6083 - accuracy: 0.5260
# Epoch 00010: saving model to checkpoints/20220126_123446_richfield_shallow_net2AbsReAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 12s 231ms/step - loss: 1.6347 - accuracy: 0.5082 - val_loss: 1.6550 - val_accuracy: 0.5466
# Choices:  ModAbsReAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 48s 961ms/step - loss: 2.6554 - accuracy: 0.1307 - val_loss: 2.4201 - val_accuracy: 0.2217
# Epoch 2/10
# 50/50 [==============================] - 11s 229ms/step - loss: 2.4469 - accuracy: 0.2109 - val_loss: 2.3004 - val_accuracy: 0.2922
# Epoch 3/10
# 50/50 [==============================] - 12s 233ms/step - loss: 2.3146 - accuracy: 0.2948 - val_loss: 2.1783 - val_accuracy: 0.3829
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.1787 - accuracy: 0.3656
# Epoch 00004: saving model to checkpoints/20220126_123446_richfield_shallow_net2ModAbsReAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 12s 233ms/step - loss: 2.2004 - accuracy: 0.3283 - val_loss: 2.0552 - val_accuracy: 0.4257
# Epoch 5/10
# 50/50 [==============================] - 12s 233ms/step - loss: 2.0779 - accuracy: 0.3946 - val_loss: 1.9502 - val_accuracy: 0.4458
# Epoch 6/10
# 50/50 [==============================] - 12s 234ms/step - loss: 1.9636 - accuracy: 0.4085 - val_loss: 1.8696 - val_accuracy: 0.4433
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.7991 - accuracy: 0.4406
# Epoch 00007: saving model to checkpoints/20220126_123446_richfield_shallow_net2ModAbsReAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 12s 231ms/step - loss: 1.8465 - accuracy: 0.4343 - val_loss: 1.7901 - val_accuracy: 0.4811
# Epoch 8/10
# 50/50 [==============================] - 12s 234ms/step - loss: 1.7940 - accuracy: 0.4533 - val_loss: 1.7319 - val_accuracy: 0.5088
# Epoch 9/10
# 50/50 [==============================] - 12s 235ms/step - loss: 1.7246 - accuracy: 0.4842 - val_loss: 1.6912 - val_accuracy: 0.5516
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6522 - accuracy: 0.5083
# Epoch 00010: saving model to checkpoints/20220126_123446_richfield_shallow_net2ModAbsReAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 12s 231ms/step - loss: 1.6430 - accuracy: 0.5051 - val_loss: 1.6466 - val_accuracy: 0.5592
# 3555.7659125328064
# index:  3
# Choices:  Mod
# True
# Epoch 1/10
# 50/50 [==============================] - 48s 950ms/step - loss: 2.5973 - accuracy: 0.1578 - val_loss: 2.3691 - val_accuracy: 0.2821
# Epoch 2/10
# 50/50 [==============================] - 12s 240ms/step - loss: 2.3648 - accuracy: 0.2614 - val_loss: 2.2274 - val_accuracy: 0.3577
# Epoch 3/10
# 50/50 [==============================] - 11s 229ms/step - loss: 2.1992 - accuracy: 0.3213 - val_loss: 2.0959 - val_accuracy: 0.4030
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.1396 - accuracy: 0.3469
# Epoch 00004: saving model to checkpoints/20220126_125241_richfield_shallow_net3Mod_\cp-0004.ckpt
# 50/50 [==============================] - 12s 233ms/step - loss: 2.1071 - accuracy: 0.3617 - val_loss: 2.0140 - val_accuracy: 0.4383
# Epoch 5/10
# 50/50 [==============================] - 11s 230ms/step - loss: 2.0319 - accuracy: 0.3902 - val_loss: 1.9235 - val_accuracy: 0.4610
# Epoch 6/10
# 50/50 [==============================] - 11s 226ms/step - loss: 1.9027 - accuracy: 0.4110 - val_loss: 1.8362 - val_accuracy: 0.4836
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 5s - loss: 1.8872 - accuracy: 0.4281
# Epoch 00007: saving model to checkpoints/20220126_125241_richfield_shallow_net3Mod_\cp-0007.ckpt
# 50/50 [==============================] - 11s 217ms/step - loss: 1.8684 - accuracy: 0.4242 - val_loss: 1.7978 - val_accuracy: 0.4912
# Epoch 8/10
# 50/50 [==============================] - 11s 214ms/step - loss: 1.7719 - accuracy: 0.4571 - val_loss: 1.7280 - val_accuracy: 0.5189
# Epoch 9/10
# 50/50 [==============================] - 11s 215ms/step - loss: 1.7425 - accuracy: 0.4735 - val_loss: 1.6774 - val_accuracy: 0.5416
# Epoch 10/10
# 30/50 [=================>............] - ETA: 3s - loss: 1.6743 - accuracy: 0.4938
# Epoch 00010: saving model to checkpoints/20220126_125241_richfield_shallow_net3Mod_\cp-0010.ckpt
# 50/50 [==============================] - 11s 214ms/step - loss: 1.6487 - accuracy: 0.5088 - val_loss: 1.6558 - val_accuracy: 0.5516
# Choices:  AbsRe
# True
# Epoch 1/10
# 50/50 [==============================] - 45s 892ms/step - loss: 2.5873 - accuracy: 0.1408 - val_loss: 2.4175 - val_accuracy: 0.2746
# Epoch 2/10
# 50/50 [==============================] - 11s 214ms/step - loss: 2.4020 - accuracy: 0.2210 - val_loss: 2.2689 - val_accuracy: 0.3476
# Epoch 3/10
# 50/50 [==============================] - 11s 216ms/step - loss: 2.2510 - accuracy: 0.3024 - val_loss: 2.1435 - val_accuracy: 0.3804
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 7s - loss: 2.2152 - accuracy: 0.3125
# Epoch 00004: saving model to checkpoints/20220126_125241_richfield_shallow_net3AbsRe_\cp-0004.ckpt
# 50/50 [==============================] - 11s 221ms/step - loss: 2.1549 - accuracy: 0.3365 - val_loss: 2.0416 - val_accuracy: 0.4055
# Epoch 5/10
# 50/50 [==============================] - 11s 214ms/step - loss: 2.0385 - accuracy: 0.3744 - val_loss: 1.9399 - val_accuracy: 0.4484
# Epoch 6/10
# 50/50 [==============================] - 11s 213ms/step - loss: 1.9541 - accuracy: 0.4066 - val_loss: 1.8576 - val_accuracy: 0.4660
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 5s - loss: 1.9057 - accuracy: 0.4141
# Epoch 00007: saving model to checkpoints/20220126_125241_richfield_shallow_net3AbsRe_\cp-0007.ckpt
# 50/50 [==============================] - 10s 210ms/step - loss: 1.8855 - accuracy: 0.4104 - val_loss: 1.8065 - val_accuracy: 0.4736
# Epoch 8/10
# 50/50 [==============================] - 11s 215ms/step - loss: 1.8367 - accuracy: 0.4381 - val_loss: 1.7485 - val_accuracy: 0.5013
# Epoch 9/10
# 50/50 [==============================] - 11s 214ms/step - loss: 1.7582 - accuracy: 0.4697 - val_loss: 1.6933 - val_accuracy: 0.5139
# Epoch 10/10
# 30/50 [=================>............] - ETA: 3s - loss: 1.7484 - accuracy: 0.4688
# Epoch 00010: saving model to checkpoints/20220126_125241_richfield_shallow_net3AbsRe_\cp-0010.ckpt
# 50/50 [==============================] - 10s 209ms/step - loss: 1.7160 - accuracy: 0.4754 - val_loss: 1.6548 - val_accuracy: 0.5416
# Choices:  AbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 44s 873ms/step - loss: 2.5725 - accuracy: 0.1446 - val_loss: 2.4103 - val_accuracy: 0.3023
# Epoch 2/10
# 50/50 [==============================] - 11s 217ms/step - loss: 2.3760 - accuracy: 0.2538 - val_loss: 2.2343 - val_accuracy: 0.3980
# Epoch 3/10
# 50/50 [==============================] - 11s 213ms/step - loss: 2.1841 - accuracy: 0.3289 - val_loss: 2.0752 - val_accuracy: 0.4106
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 7s - loss: 2.1730 - accuracy: 0.3344
# Epoch 00004: saving model to checkpoints/20220126_125241_richfield_shallow_net3AbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 11s 215ms/step - loss: 2.0819 - accuracy: 0.3573 - val_loss: 1.9675 - val_accuracy: 0.4358
# Epoch 5/10
# 50/50 [==============================] - 11s 213ms/step - loss: 1.9704 - accuracy: 0.3889 - val_loss: 1.8720 - val_accuracy: 0.4736
# Epoch 6/10
# 50/50 [==============================] - 11s 212ms/step - loss: 1.9123 - accuracy: 0.4167 - val_loss: 1.8032 - val_accuracy: 0.5290
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.8303 - accuracy: 0.4516
# Epoch 00007: saving model to checkpoints/20220126_125241_richfield_shallow_net3AbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 11s 224ms/step - loss: 1.8150 - accuracy: 0.4552 - val_loss: 1.7388 - val_accuracy: 0.5214
# Epoch 8/10
# 50/50 [==============================] - 10s 209ms/step - loss: 1.7562 - accuracy: 0.4665 - val_loss: 1.6902 - val_accuracy: 0.5264
# Epoch 9/10
# 50/50 [==============================] - 10s 209ms/step - loss: 1.7045 - accuracy: 0.4691 - val_loss: 1.6382 - val_accuracy: 0.5466
# Epoch 10/10
# ...
# Epoch 2/10
# 50/50 [==============================] - 16s 322ms/step - loss: 2.3836 - accuracy: 0.2481 - val_loss: 2.2540 - val_accuracy: 0.2846
# Epoch 3/10
# 50/50 [==============================] - 16s 330ms/step - loss: 2.2557 - accuracy: 0.2891 - val_loss: 2.1380 - val_accuracy: 0.3577
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 12s - loss: 2.2140 - accuracy: 0.3000
# Epoch 00004: saving model to checkpoints/20220126_150517_richfield_shallow_net8ModAbsReAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 17s 333ms/step - loss: 2.1919 - accuracy: 0.3043 - val_loss: 2.0560 - val_accuracy: 0.3854
# Epoch 5/10
# 50/50 [==============================] - 16s 323ms/step - loss: 2.0851 - accuracy: 0.3699 - val_loss: 1.9850 - val_accuracy: 0.4232
# Epoch 6/10
# 50/50 [==============================] - 16s 325ms/step - loss: 2.0124 - accuracy: 0.3977 - val_loss: 1.9286 - val_accuracy: 0.4257
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 9s - loss: 2.0306 - accuracy: 0.3938
# Epoch 00007: saving model to checkpoints/20220126_150517_richfield_shallow_net8ModAbsReAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 16s 326ms/step - loss: 1.9603 - accuracy: 0.4242 - val_loss: 1.8830 - val_accuracy: 0.4433
# Epoch 8/10
# 50/50 [==============================] - 16s 325ms/step - loss: 1.8522 - accuracy: 0.4520 - val_loss: 1.8176 - val_accuracy: 0.4736
# Epoch 9/10
# 50/50 [==============================] - 16s 324ms/step - loss: 1.7928 - accuracy: 0.4489 - val_loss: 1.7579 - val_accuracy: 0.4937
# Epoch 10/10
# 30/50 [=================>............] - ETA: 5s - loss: 1.7554 - accuracy: 0.4729
# Epoch 00010: saving model to checkpoints/20220126_150517_richfield_shallow_net8ModAbsReAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 16s 325ms/step - loss: 1.7463 - accuracy: 0.4804 - val_loss: 1.7293 - val_accuracy: 0.5164
# 12949.11121749878
# index:  9
# Choices:  Mod
# True
# Epoch 1/10
# 50/50 [==============================] - 59s 1s/step - loss: 2.5881 - accuracy: 0.1540 - val_loss: 2.4462 - val_accuracy: 0.2519
# Epoch 2/10
# 50/50 [==============================] - 15s 294ms/step - loss: 2.3919 - accuracy: 0.2437 - val_loss: 2.2854 - val_accuracy: 0.3476
# Epoch 3/10
# 50/50 [==============================] - 15s 291ms/step - loss: 2.2368 - accuracy: 0.3043 - val_loss: 2.1327 - val_accuracy: 0.3980
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 10s - loss: 2.2058 - accuracy: 0.3406
# Epoch 00004: saving model to checkpoints/20220126_152914_richfield_shallow_net9Mod_\cp-0004.ckpt
# 50/50 [==============================] - 15s 293ms/step - loss: 2.1404 - accuracy: 0.3466 - val_loss: 2.0208 - val_accuracy: 0.4610
# Epoch 5/10
# 50/50 [==============================] - 15s 293ms/step - loss: 2.0078 - accuracy: 0.4072 - val_loss: 1.9232 - val_accuracy: 0.4811
# Epoch 6/10
# 50/50 [==============================] - 14s 290ms/step - loss: 1.9250 - accuracy: 0.4261 - val_loss: 1.8409 - val_accuracy: 0.4912
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 7s - loss: 1.8651 - accuracy: 0.4500
# Epoch 00007: saving model to checkpoints/20220126_152914_richfield_shallow_net9Mod_\cp-0007.ckpt
# 50/50 [==============================] - 14s 290ms/step - loss: 1.8306 - accuracy: 0.4533 - val_loss: 1.7693 - val_accuracy: 0.5214
# Epoch 8/10
# 50/50 [==============================] - 15s 292ms/step - loss: 1.7450 - accuracy: 0.4912 - val_loss: 1.7094 - val_accuracy: 0.5315
# Epoch 9/10
# 50/50 [==============================] - 15s 292ms/step - loss: 1.6698 - accuracy: 0.4981 - val_loss: 1.6335 - val_accuracy: 0.5390
# Epoch 10/10
# 30/50 [=================>............] - ETA: 5s - loss: 1.6323 - accuracy: 0.5104
# Epoch 00010: saving model to checkpoints/20220126_152914_richfield_shallow_net9Mod_\cp-0010.ckpt
# 50/50 [==============================] - 15s 297ms/step - loss: 1.6153 - accuracy: 0.5139 - val_loss: 1.5867 - val_accuracy: 0.5516
# Choices:  AbsRe
# True
# Epoch 1/10
# 50/50 [==============================] - 58s 1s/step - loss: 2.5413 - accuracy: 0.1597 - val_loss: 2.4003 - val_accuracy: 0.2796
# Epoch 2/10
# 50/50 [==============================] - 15s 291ms/step - loss: 2.3521 - accuracy: 0.2449 - val_loss: 2.2266 - val_accuracy: 0.3602
# Epoch 3/10
# 50/50 [==============================] - 15s 292ms/step - loss: 2.1985 - accuracy: 0.3245 - val_loss: 2.0683 - val_accuracy: 0.4207
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 10s - loss: 2.1412 - accuracy: 0.3313
# Epoch 00004: saving model to checkpoints/20220126_152914_richfield_shallow_net9AbsRe_\cp-0004.ckpt
# 50/50 [==============================] - 15s 294ms/step - loss: 2.0684 - accuracy: 0.3674 - val_loss: 1.9410 - val_accuracy: 0.4610
# Epoch 5/10
# 50/50 [==============================] - 15s 291ms/step - loss: 1.9661 - accuracy: 0.4009 - val_loss: 1.8450 - val_accuracy: 0.4912
# Epoch 6/10
# 50/50 [==============================] - 15s 293ms/step - loss: 1.8763 - accuracy: 0.4249 - val_loss: 1.7627 - val_accuracy: 0.5088
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 8s - loss: 1.7991 - accuracy: 0.4313
# Epoch 00007: saving model to checkpoints/20220126_152914_richfield_shallow_net9AbsRe_\cp-0007.ckpt
# 50/50 [==============================] - 15s 297ms/step - loss: 1.7858 - accuracy: 0.4388 - val_loss: 1.6976 - val_accuracy: 0.5164
# Epoch 8/10
# 50/50 [==============================] - 15s 294ms/step - loss: 1.7231 - accuracy: 0.4741 - val_loss: 1.6509 - val_accuracy: 0.5365
# Epoch 9/10
# 50/50 [==============================] - 15s 293ms/step - loss: 1.6599 - accuracy: 0.5006 - val_loss: 1.6171 - val_accuracy: 0.5340
# Epoch 10/10
# 30/50 [=================>............] - ETA: 5s - loss: 1.6411 - accuracy: 0.5198
# Epoch 00010: saving model to checkpoints/20220126_152914_richfield_shallow_net9AbsRe_\cp-0010.ckpt
# 50/50 [==============================] - 15s 296ms/step - loss: 1.5932 - accuracy: 0.5316 - val_loss: 1.5811 - val_accuracy: 0.5466
# Choices:  AbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 59s 1s/step - loss: 2.5381 - accuracy: 0.1566 - val_loss: 2.4048 - val_accuracy: 0.2771
# Epoch 2/10
# 50/50 [==============================] - 14s 289ms/step - loss: 2.3668 - accuracy: 0.2481 - val_loss: 2.2198 - val_accuracy: 0.3829
# Epoch 3/10
# 50/50 [==============================] - 15s 296ms/step - loss: 2.2379 - accuracy: 0.3093 - val_loss: 2.0925 - val_accuracy: 0.4106
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 10s - loss: 2.2198 - accuracy: 0.2906
# Epoch 00004: saving model to checkpoints/20220126_152914_richfield_shallow_net9AbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 15s 294ms/step - loss: 2.1168 - accuracy: 0.3617 - val_loss: 2.0046 - val_accuracy: 0.4509
# Epoch 5/10
# 50/50 [==============================] - 15s 294ms/step - loss: 2.0294 - accuracy: 0.3883 - val_loss: 1.9384 - val_accuracy: 0.4710
# Epoch 6/10
# 50/50 [==============================] - 14s 289ms/step - loss: 1.9334 - accuracy: 0.4104 - val_loss: 1.8737 - val_accuracy: 0.4987
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 8s - loss: 1.9457 - accuracy: 0.4031
# Epoch 00007: saving model to checkpoints/20220126_152914_richfield_shallow_net9AbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 15s 295ms/step - loss: 1.8902 - accuracy: 0.4306 - val_loss: 1.8207 - val_accuracy: 0.5038
# Epoch 8/10
# 50/50 [==============================] - 15s 296ms/step - loss: 1.8079 - accuracy: 0.4577 - val_loss: 1.7660 - val_accuracy: 0.5214
# Epoch 9/10
# 50/50 [==============================] - 15s 294ms/step - loss: 1.7446 - accuracy: 0.4804 - val_loss: 1.7288 - val_accuracy: 0.5239
# Epoch 10/10
# 30/50 [=================>............] - ETA: 5s - loss: 1.7497 - accuracy: 0.4635
# Epoch 00010: saving model to checkpoints/20220126_152914_richfield_shallow_net9AbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 15s 295ms/step - loss: 1.7212 - accuracy: 0.4798 - val_loss: 1.6942 - val_accuracy: 0.5340
# Choices:  ModAbsRe
# True
# Epoch 1/10
# 50/50 [==============================] - 42s 839ms/step - loss: 2.5720 - accuracy: 0.1509 - val_loss: 2.3844 - val_accuracy: 0.2594
# Epoch 2/10
# 50/50 [==============================] - 12s 232ms/step - loss: 2.3532 - accuracy: 0.2525 - val_loss: 2.2414 - val_accuracy: 0.3174
# Epoch 3/10
# 50/50 [==============================] - 12s 235ms/step - loss: 2.2239 - accuracy: 0.2980 - val_loss: 2.1129 - val_accuracy: 0.4030
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.2056 - accuracy: 0.3438
# Epoch 00004: saving model to checkpoints/20220126_152914_richfield_shallow_net9ModAbsRe_\cp-0004.ckpt
# 50/50 [==============================] - 12s 249ms/step - loss: 2.1167 - accuracy: 0.3403 - val_loss: 2.0146 - val_accuracy: 0.4332
# Epoch 5/10
# 50/50 [==============================] - 12s 236ms/step - loss: 2.0411 - accuracy: 0.3763 - val_loss: 1.9336 - val_accuracy: 0.4458
# Epoch 6/10
# 50/50 [==============================] - 12s 237ms/step - loss: 1.9182 - accuracy: 0.4192 - val_loss: 1.8551 - val_accuracy: 0.4987
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.9792 - accuracy: 0.4062
# Epoch 00007: saving model to checkpoints/20220126_152914_richfield_shallow_net9ModAbsRe_\cp-0007.ckpt
# 50/50 [==============================] - 12s 241ms/step - loss: 1.9005 - accuracy: 0.4242 - val_loss: 1.8005 - val_accuracy: 0.4937
# Epoch 8/10
# 50/50 [==============================] - 13s 258ms/step - loss: 1.8065 - accuracy: 0.4577 - val_loss: 1.7409 - val_accuracy: 0.5063
# Epoch 9/10
# 50/50 [==============================] - 13s 251ms/step - loss: 1.7578 - accuracy: 0.4697 - val_loss: 1.6965 - val_accuracy: 0.5164
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.7777 - accuracy: 0.4729
# Epoch 00010: saving model to checkpoints/20220126_152914_richfield_shallow_net9ModAbsRe_\cp-0010.ckpt
# 50/50 [==============================] - 13s 258ms/step - loss: 1.7471 - accuracy: 0.4830 - val_loss: 1.6694 - val_accuracy: 0.5063
# Choices:  ModAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 47s 924ms/step - loss: 2.5664 - accuracy: 0.1338 - val_loss: 2.3729 - val_accuracy: 0.2594
# Epoch 2/10
# 50/50 [==============================] - 11s 226ms/step - loss: 2.3500 - accuracy: 0.2449 - val_loss: 2.2037 - val_accuracy: 0.3451
# Epoch 3/10
# 50/50 [==============================] - 11s 228ms/step - loss: 2.1938 - accuracy: 0.3251 - val_loss: 2.0605 - val_accuracy: 0.3829
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.1901 - accuracy: 0.3187
# Epoch 00004: saving model to checkpoints/20220126_152914_richfield_shallow_net9ModAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 11s 229ms/step - loss: 2.0698 - accuracy: 0.3744 - val_loss: 1.9669 - val_accuracy: 0.4207
# Epoch 5/10
# 50/50 [==============================] - 13s 258ms/step - loss: 2.0323 - accuracy: 0.3883 - val_loss: 1.9077 - val_accuracy: 0.4332
# Epoch 6/10
# 50/50 [==============================] - 13s 261ms/step - loss: 1.9085 - accuracy: 0.4331 - val_loss: 1.8327 - val_accuracy: 0.4685
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.8573 - accuracy: 0.4359
# Epoch 00007: saving model to checkpoints/20220126_152914_richfield_shallow_net9ModAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 12s 245ms/step - loss: 1.8671 - accuracy: 0.4299 - val_loss: 1.7862 - val_accuracy: 0.4635
# Epoch 8/10
# 50/50 [==============================] - 12s 233ms/step - loss: 1.7864 - accuracy: 0.4665 - val_loss: 1.7384 - val_accuracy: 0.5189
# Epoch 9/10
# 50/50 [==============================] - 11s 222ms/step - loss: 1.7163 - accuracy: 0.4931 - val_loss: 1.6821 - val_accuracy: 0.5088
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6937 - accuracy: 0.4969
# Epoch 00010: saving model to checkpoints/20220126_152914_richfield_shallow_net9ModAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 12s 231ms/step - loss: 1.6508 - accuracy: 0.5107 - val_loss: 1.6240 - val_accuracy: 0.5365
# Choices:  AbsReAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 47s 929ms/step - loss: 2.5841 - accuracy: 0.1540 - val_loss: 2.3299 - val_accuracy: 0.3073
# Epoch 2/10
# 50/50 [==============================] - 12s 250ms/step - loss: 2.3505 - accuracy: 0.2538 - val_loss: 2.1845 - val_accuracy: 0.3426
# Epoch 3/10
# 50/50 [==============================] - 12s 249ms/step - loss: 2.1965 - accuracy: 0.3251 - val_loss: 2.0475 - val_accuracy: 0.4257
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 9s - loss: 2.1833 - accuracy: 0.3406
# Epoch 00004: saving model to checkpoints/20220126_152914_richfield_shallow_net9AbsReAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 12s 241ms/step - loss: 2.1023 - accuracy: 0.3567 - val_loss: 1.9525 - val_accuracy: 0.4257
# Epoch 5/10
# 50/50 [==============================] - 12s 233ms/step - loss: 1.9914 - accuracy: 0.4034 - val_loss: 1.8593 - val_accuracy: 0.4685
# Epoch 6/10
# 50/50 [==============================] - 12s 231ms/step - loss: 1.8938 - accuracy: 0.4337 - val_loss: 1.7694 - val_accuracy: 0.4937
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.9075 - accuracy: 0.3922
# Epoch 00007: saving model to checkpoints/20220126_152914_richfield_shallow_net9AbsReAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 11s 229ms/step - loss: 1.8577 - accuracy: 0.4141 - val_loss: 1.7153 - val_accuracy: 0.5088
# Epoch 8/10
# 50/50 [==============================] - 11s 222ms/step - loss: 1.7583 - accuracy: 0.4665 - val_loss: 1.6582 - val_accuracy: 0.5139
# Epoch 9/10
# 50/50 [==============================] - 11s 220ms/step - loss: 1.6758 - accuracy: 0.4779 - val_loss: 1.6052 - val_accuracy: 0.5365
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6264 - accuracy: 0.5167
# Epoch 00010: saving model to checkpoints/20220126_152914_richfield_shallow_net9AbsReAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 11s 221ms/step - loss: 1.6081 - accuracy: 0.5227 - val_loss: 1.5589 - val_accuracy: 0.5290
# Choices:  ModAbsReAbsIm
# True
# Epoch 1/10
# 50/50 [==============================] - 48s 949ms/step - loss: 2.6570 - accuracy: 0.1319 - val_loss: 2.3998 - val_accuracy: 0.2494
# Epoch 2/10
# 50/50 [==============================] - 12s 237ms/step - loss: 2.3803 - accuracy: 0.2311 - val_loss: 2.2171 - val_accuracy: 0.3980
# Epoch 3/10
# 50/50 [==============================] - 12s 234ms/step - loss: 2.2351 - accuracy: 0.3125 - val_loss: 2.0598 - val_accuracy: 0.4156
# Epoch 4/10
# 10/50 [=====>........................] - ETA: 8s - loss: 2.1887 - accuracy: 0.3281
# Epoch 00004: saving model to checkpoints/20220126_152914_richfield_shallow_net9ModAbsReAbsIm_\cp-0004.ckpt
# 50/50 [==============================] - 12s 239ms/step - loss: 2.1048 - accuracy: 0.3485 - val_loss: 1.9505 - val_accuracy: 0.4736
# Epoch 5/10
# 50/50 [==============================] - 12s 235ms/step - loss: 1.9840 - accuracy: 0.4047 - val_loss: 1.8647 - val_accuracy: 0.4761
# Epoch 6/10
# 50/50 [==============================] - 12s 236ms/step - loss: 1.9097 - accuracy: 0.4318 - val_loss: 1.7841 - val_accuracy: 0.5164
# Epoch 7/10
# 20/50 [===========>..................] - ETA: 6s - loss: 1.9277 - accuracy: 0.4219
# Epoch 00007: saving model to checkpoints/20220126_152914_richfield_shallow_net9ModAbsReAbsIm_\cp-0007.ckpt
# 50/50 [==============================] - 11s 230ms/step - loss: 1.9044 - accuracy: 0.4249 - val_loss: 1.7504 - val_accuracy: 0.5390
# Epoch 8/10
# 50/50 [==============================] - 11s 226ms/step - loss: 1.7498 - accuracy: 0.4527 - val_loss: 1.6704 - val_accuracy: 0.5491
# Epoch 9/10
# 50/50 [==============================] - 12s 233ms/step - loss: 1.7125 - accuracy: 0.4735 - val_loss: 1.6244 - val_accuracy: 0.5516
# Epoch 10/10
# 30/50 [=================>............] - ETA: 4s - loss: 1.6720 - accuracy: 0.4646
# Epoch 00010: saving model to checkpoints/20220126_152914_richfield_shallow_net9ModAbsReAbsIm_\cp-0010.ckpt
# 50/50 [==============================] - 12s 233ms/step - loss: 1.6373 - accuracy: 0.4931 - val_loss: 1.5911 - val_accuracy: 0.5693
# 14171.332018852234

# %%
toc = time.time()

# %%
print(toc-tic)
# Out:
# 14171.345379590988

# %% [markdown]
# # Multi-channel work

# %%
categories
# Out:
# ['Common Buzzard',
#  'Common Kestrel',
#  'Common Snipe',
#  'Eurasian Curlew',
#  'European Herring Gull',
#  'European Robin',
#  'Meadow Pipit',
#  'Mute Swan',
#  'Northern Lapwing',
#  'Rook',
#  'Tundra Swan',
#  'Tundra Swan (Bewicks)']

# %%
tmp_ds = preprocess_dataset(filenames[:30], choices=['Mod', 'AbsRe', 'AbsIm', 'AbsAng'], categories=categories)

# %%
for spec, lab in tmp_ds.take(1):
    spec = spec
    lab = lab

# %%
filenames[0]
# Out:
# 'richfield_birds\\Meadow Pipit\\xc476408_left.wav'

# %%
categories[lab]
# Out:
# 'Meadow Pipit'

# %%
#plt.imshow(np.log(spec[:50,:100,0]))

# %%
#plt.imshow(np.log(spec[:50,:100,1]))

# %%
#plt.imshow(np.log(spec[:50,:100,2]))

# %%
#plt.imshow(np.log(np.mean(spec[:50,:100,1:3], axis=2)))
#spec[:50,:100,1:3].shape

# %%
#plt.imshow(np.log(spec[:50,:100,3]))

# %%
def spec_normalize(x):
        return tf.divide(
        tf.subtract(
            x, tf.reduce_min(x)
        ), 
        tf.subtract(
            tf.reduce_max(x), 
            tf.reduce_min(x)
        )
    )
#spec_normalize(spec)

# %%
#spec[:,:,3]
