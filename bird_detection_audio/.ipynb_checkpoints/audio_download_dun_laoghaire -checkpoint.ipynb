# %%
import requests
import os
import json
import pandas as pd
from tqdm import tqdm

# %%
base_folder = 'dublin_dl_birds'

# %%
def xeno_download(search_string, abbrev_string = None, top_n = 250, ssp = None, not_ssp = None):
    folder_sv = base_folder+'/'+search_string
    find_bracket = (search_string.find(' ('))
    if (ssp is not None) & (find_bracket == -1):
        folder_sv = folder_sv + ' ('+ssp.capitalize()+')'
    folder_sv = folder_sv +'/'
    if not os.path.isdir(folder_sv):
        os.mkdir(folder_sv)
    if abbrev_string is None:
        if ssp is not None:
            abbrev_string = (search_string+ssp).replace(' ', '_').lower()
        else:
            abbrev_string = search_string.replace(' ', '_').lower()
    if find_bracket != -1:
        search_string = search_string[:find_bracket]
    search_str = search_string.replace(' ', '%20').lower()
    if ssp is not None:
        url = 'https://www.xeno-canto.org/api/2/recordings?query=ssp:'+ssp
    else:
        url = 'https://www.xeno-canto.org/api/2/recordings?query='+search_str
    doc = requests.get(url)
    with open(abbrev_string+'-query.json', 'wb') as f:
        f.write(doc.content)
    
    # Get the json entries from your downloaded json
    jsonFile = open(abbrev_string+'-query.json', 'r')
    values = json.load(jsonFile)
    jsonFile.close()

    # Create a pandas dataframe of records & convert to .csv file
    record_df = pd.DataFrame(values['recordings'])
    #record_df.to_csv('xc-'+abbrev_string+'.csv', index=False)
    record_df = record_df[record_df.en.str.startswith(search_string)]
    if not_ssp is not None:
        record_df = record_df[record_df.ssp != not_ssp]
    #return record_df
    record_df_uk_ire = record_df[[rc in ['Ireland', 'United Kingdom'] for rc in record_df.cnt]]
    if len(record_df_uk_ire) >= top_n:
        record_df = record_df_uk_ire.iloc[:top_n]
    else:
        record_df_else = record_df[[rc not in ['Ireland', 'United Kingdom'] for rc in record_df.cnt]]
        record_df = record_df_uk_ire.append(record_df_else.iloc[:(top_n-len(record_df_uk_ire))])
    return record_df
    # Make wget input file
    #url_list = []
    #for file in record_df['file'].tolist():
    #    url_list.append('https:{}'.format(file))
    #with open('xc-'+abbrev_string+'-urls.txt', 'w+') as f:
    #    for item in url_list:
    #        f.write("{}\n".format(item))
            
    #txt_file = open('xc-'+abbrev_string+'-urls.txt', 'r')
    #url_list = [s.replace('\n', '') for s in txt_file.readlines()]
    #
    #url_list = url_list[:top_n]
    # 
    #for url_i in url_list:
    #    filename_sv = folder_sv+'xc'+url_i.split('/')[3]+'.mp3'
    #    if filename_sv in os.listdir(folder_sv):
    #        continue
    #    doc = requests.get(url_i)
    #    with open(filename_sv, 'wb') as f:
    #        f.write(doc.content)

# %%
species_df = pd.read_excel('species list ireland - dun laoghaire.xlsx')

# %%
species_df.loc[species_df.ssp.isna(),'ssp'] = None
species_df = species_df[species_df.use_train == 1]
species_df
# Out:
#                species  num_recordings           folder_label  ssp  use_train
# 0   Mediterranean Gull             NaN     Mediterranean Gull  NaN          1
# 1               Gannet             NaN        Northern Gannet  NaN          1
# 6           Grey Heron             NaN             Grey Heron  NaN          1
# 7             Starling             NaN        Common Starling  NaN          1
# 8         Herring Gull             NaN  European Herring Gull  NaN          1
# 12          Black Bird             NaN       Common Blackbird  NaN          1
# 13               Robin             NaN         European Robin  NaN          1
# 14           Great Tit             NaN              Great Tit  NaN          1
# 15            Blue Tit             NaN      Eurasian Blue Tit  NaN          1
# 16            Coal Tit             NaN               Coal Tit  NaN          1
# 17           Chaffinch             NaN       Common Chaffinch  NaN          1
# 18              Magpie             NaN        Eurasian Magpie  NaN          1
# 19           Goldfinch             NaN     European Goldfinch  NaN          1
# 20       House Sparrow             NaN          House Sparrow  NaN          1
# 21          Greenfinch             NaN    European Greenfinch  NaN          1

# %%
df_tmp = xeno_download('Mediterranean Gull', top_n = 500)

# %%
df_tmp
# Out:
#          id          gen              sp ssp                  en  \
# 1    657691  Ichthyaetus  melanocephalus      Mediterranean Gull
# 2    657690  Ichthyaetus  melanocephalus      Mediterranean Gull
# 19   447331  Ichthyaetus  melanocephalus      Mediterranean Gull
# 23   309809  Ichthyaetus  melanocephalus      Mediterranean Gull
# 32   186610  Ichthyaetus  melanocephalus      Mediterranean Gull
# 37   667916  Ichthyaetus  melanocephalus      Mediterranean Gull
# 38   666928  Ichthyaetus  melanocephalus      Mediterranean Gull
# 64   531754  Ichthyaetus  melanocephalus      Mediterranean Gull
# 73   433298  Ichthyaetus  melanocephalus      Mediterranean Gull
# 76   404557  Ichthyaetus  melanocephalus      Mediterranean Gull
# 77   403055  Ichthyaetus  melanocephalus      Mediterranean Gull
# 79   375353  Ichthyaetus  melanocephalus      Mediterranean Gull
# 88   186608  Ichthyaetus  melanocephalus      Mediterranean Gull
# 92    92775  Ichthyaetus  melanocephalus      Mediterranean Gull
# 103  637750  Ichthyaetus  melanocephalus      Mediterranean Gull
# 109  621622  Ichthyaetus  melanocephalus      Mediterranean Gull
# 110  578418  Ichthyaetus  melanocephalus      Mediterranean Gull
# 111  578250  Ichthyaetus  melanocephalus      Mediterranean Gull
# 124  522507  Ichthyaetus  melanocephalus      Mediterranean Gull
# 125  500323  Ichthyaetus  melanocephalus      Mediterranean Gull
# 126  500321  Ichthyaetus  melanocephalus      Mediterranean Gull
# 127  500319  Ichthyaetus  melanocephalus      Mediterranean Gull
# 128  500318  Ichthyaetus  melanocephalus      Mediterranean Gull
# 129  500317  Ichthyaetus  melanocephalus      Mediterranean Gull
# 135  403841  Ichthyaetus  melanocephalus      Mediterranean Gull
# 138  314677  Ichthyaetus  melanocephalus      Mediterranean Gull
# 143  176436  Ichthyaetus  melanocephalus      Mediterranean Gull
# 147   44271  Ichthyaetus  melanocephalus      Mediterranean Gull
# 148  637310  Ichthyaetus  melanocephalus      Mediterranean Gull
# 161  294499  Ichthyaetus  melanocephalus      Mediterranean Gull
# 162  666608  Ichthyaetus  melanocephalus      Mediterranean Gull
# 163  638804  Ichthyaetus  melanocephalus      Mediterranean Gull
#
#                        rec             cnt  \
# 1            Frank Lambert  United Kingdom
# 2            Frank Lambert  United Kingdom
# 19   David Darrell-Lambert  United Kingdom
# 23              Gary Elton  United Kingdom
# 32            Patrik Åberg  United Kingdom
# 37   Irish Wildlife Sounds         Ireland
# 38   Irish Wildlife Sounds         Ireland
# 64           Andrew Harrop  United Kingdom
# 73            Harry Hussey         Ireland
# 76            Harry Hussey         Ireland
# 77          Fraser Simpson  United Kingdom
# 79           GABRIEL LEITE  United Kingdom
# 88            Patrik Åberg  United Kingdom
# 92          Alexander Lees  United Kingdom
# 103          Jon Sparshott  United Kingdom
# 109            Chris Batty  United Kingdom
# 110           Harry Hussey         Ireland
# 111            Arjun Dutta  United Kingdom
# 124            Chris Batty  United Kingdom
# 125            Chris Batty  United Kingdom
# 126            Chris Batty  United Kingdom
# 127            Chris Batty  United Kingdom
# 128            Chris Batty  United Kingdom
# 129            Chris Batty  United Kingdom
# 135           Harry Hussey         Ireland
# 138          Craig Brookes  United Kingdom
# 143                david m  United Kingdom
# 147          Stuart Fisher  United Kingdom
# 148          Jon Sparshott  United Kingdom
# 161            Chris Batty  United Kingdom
# 162          Jon Sparshott  United Kingdom
# 163          Jon Sparshott  United Kingdom
#
#                                                    loc      lat      lng  ...  \
# 1                   Gramborough Hill, Norfolk, England  52.9542   1.1037  ...
# 2                   Gramborough Hill, Norfolk, England  52.9542   1.1037  ...
# 19                                     Medway, England  51.4679   0.4878  ...
# 23   King's Lynn and West Norfolk District (near  H...  52.9492   0.4971  ...
# 32   Pannel Sewer, Rye Harbour NR, East Sussex, Eng...  50.9053   0.6828  ...
# 37   Ireland (near  Tacumshane), Wexford, County We...  52.1977  -6.3925  ...
# 38   Ireland (near  Tacumshane), Wexford, County We...  52.1977  -6.3925  ...
# 64                                      Titchwell RSPB   52.964    0.605  ...
# 73                        Cork, Cork City, County Cork  51.9012  -8.4791  ...
# 76                         Rostellan Lake, County Cork  51.8457  -8.1901  ...
# 77                      Southend Pier, Southend-on-Sea  51.5155   0.7215  ...
# 79   Pagham Harbour, nr Church Norton, West Sussex,...  50.7537  -0.7641  ...
# 88   Pannel Sewer, Rye Harbour NR, East Sussex, Eng...  50.9053   0.6828  ...
# 92                    Great Yarmouth Seafront, Norfolk   52.606    1.738  ...
# 103  Carpenters Farm (near  Brading Marsh), Isle of...  50.6913  -1.1269  ...
# 109       Knott End-on-Sea, Fylde, Lancashire, England  53.9299  -2.9833  ...
# 110                    Cork Lough, Cork city, Co. Cork  51.8861  -8.4881  ...
# 111  Great Britain (near  Wallington), Greater Lond...  51.3532  -0.1461  ...
# 124       Knott End-on-Sea, Fylde, Lancashire, England  53.9299  -2.9833  ...
# 125       Knott End-on-Sea, Fylde, Lancashire, England  53.9299  -2.9833  ...
# 126       Knott End-on-Sea, Fylde, Lancashire, England  53.9299  -2.9833  ...
# 127       Knott End-on-Sea, Fylde, Lancashire, England  53.9299  -2.9833  ...
# 128       Knott End-on-Sea, Fylde, Lancashire, England  53.9299  -2.9833  ...
# 129       Knott End-on-Sea, Fylde, Lancashire, England  53.9299  -2.9833  ...
# 135                          Lough Aderra, County Cork  51.9141   -8.087  ...
# 138                         Rochester, Medway, England  51.3735   0.4982  ...
# 143  Fareham District (near  Warsash), Hampshire, E...  50.8404   -1.304  ...
# 147               St. James's Park, Westminter, London  51.5031  -0.1334  ...
# 148  Carpenters Farm (near  Brading Marsh), Isle of...  50.6913  -1.1269  ...
# 161     Leighton Moss, Silverdale, Lancashire, England  54.1673   -2.801  ...
# 162                 Ryde Sands, Isle of Wight, England  50.7311  -1.1499  ...
# 163                      Niton, Isle of Wight, England  50.5796  -1.2984  ...
#
#                                               lic  q length   time  \
# 1    //creativecommons.org/licenses/by-nc-nd/4.0/  A   0:15  07:07
# 2    //creativecommons.org/licenses/by-nc-nd/4.0/  A   0:33  07:06
# 19   //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:10  14:00
# 23   //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:18  07:00
# 32   //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:07  06:27
# 37   //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:06  13:00
# 38   //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:14  18:00
# 64   //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:11  09:30
# 73   //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:47  15:45
# 76   //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:10  14:00
# 77   //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:26  13:00
# 79   //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:12  13:30
# 88   //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:15  05:34
# 92   //creativecommons.org/licenses/by-nc-nd/2.5/  B   0:32  13:00
# 103  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:22  09:00
# 109  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:44  06:21
# 110  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:03  19:06
# 111  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:47  00:04
# 124  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:08  12:49
# 125  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:33  06:24
# 126  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:57  05:57
# 127  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:21  01:34
# 128  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:05  06:04
# 129  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:06  06:21
# 135  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:15  15:00
# 138  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:04  18:00
# 143  //creativecommons.org/licenses/by-nc-nd/4.0/  C   0:22  08:40
# 147  //creativecommons.org/licenses/by-nc-nd/2.5/  C   0:18  13:30
# 148  //creativecommons.org/licenses/by-nc-sa/4.0/  D   0:39  09:30
# 161  //creativecommons.org/licenses/by-nc-sa/4.0/  D   0:39  16:00
# 162  //creativecommons.org/licenses/by-nc-sa/4.0/  E   0:09  07:30
# 163  //creativecommons.org/licenses/by-nc-sa/4.0/  E   0:26  23:45
#
#            date    uploaded  \
# 1    2021-06-05  2021-06-19
# 2    2021-06-05  2021-06-19
# 19   2018-04-17  2018-12-25
# 23   2016-03-29  2016-04-01
# 32   2014-06-07  2014-07-13
# 37   2021-05-25  2021-08-12
# 38   2021-06-23  2021-08-07
# 64   2020-03-04  2020-03-04
# 73   2018-09-06  2018-09-06
# 76   2018-03-05  2018-03-05
# 77   2018-02-17  2018-02-19
# 79   2017-06-13  2017-06-13
# 88   2014-06-07  2014-07-13
# 92   2012-01-10  2012-01-12
# 103  2021-04-09  2021-04-10
# 109  2020-03-12  2021-02-14
# 110  2020-07-21  2020-07-23
# 111  2020-07-20  2020-07-22
# 124  2019-03-01  2020-01-27
# 125  2018-03-14  2019-10-01
# 126  2017-03-15  2019-10-01
# 127  2017-03-15  2019-10-01
# 128  2016-03-16  2019-10-01
# 129  2016-03-11  2019-10-01
# 135  2018-02-27  2018-02-27
# 138  2016-04-27  2016-05-02
# 143  2004-03-30  2014-04-28
# 147  2010-02-13  2010-02-13
# 148  2021-04-09  2021-04-09
# 161  2011-04-18  2015-12-11
# 162  2021-08-06  2021-08-06
# 163  2021-04-08  2021-04-13
#
#                                                   also  \
# 1                                                   []
# 2                                                   []
# 19                                                  []
# 23               [Passer domesticus, Anthus pratensis]
# 32                        [Chroicocephalus ridibundus]
# 37   [Sterna hirundo, Thalasseus sandvicensis, Ster...
# 38                                                  []
# 64                                                  []
# 73                        [Chroicocephalus ridibundus]
# 76                                [Erithacus rubecula]
# 77                                                  []
# 79                                                  []
# 88   [Chroicocephalus ridibundus, Haematopus ostral...
# 92                                  [Larus argentatus]
# 103  [Turdus merula, Troglodytes troglodytes, Chroi...
# 109  [Larus argentatus, Turdus merula, Anthus prate...
# 110                       [Chroicocephalus ridibundus]
# 111                                                 []
# 124                             [Emberiza schoeniclus]
# 125  [Prunella modularis, Motacilla alba, Larus can...
# 126  [Fringilla coelebs, Anthus pratensis, Coloeus ...
# 127                                 [Larus argentatus]
# 128                                 [Numenius arquata]
# 129                               [Prunella modularis]
# 135                       [Chroicocephalus ridibundus]
# 138                                                 []
# 143                                                 []
# 147                       [Chroicocephalus ridibundus]
# 148  [Troglodytes troglodytes, Phylloscopus collybi...
# 161                       [Chroicocephalus ridibundus]
# 162                       [Chroicocephalus ridibundus]
# 163                                                 []
#
#                                                    rmk bird-seen playback-used
# 1                                                            yes            no
# 2                                                            yes            no
# 19                                                           yes            no
# 23       filtered slightly to remove background noise.       yes            no
# 32                                                           yes            no
# 37                                                           yes            no
# 38                                                           yes            no
# 64   Flight calls from birds flying inland from col...       yes            no
# 73   Calls given by a 1CY Mediterranean Gull toward...       yes            no
# 76               Call from a bird as it left the lake.       yes            no
# 77   Single note calls from adults and immatures pe...       yes            no
# 79                                                           yes            no
# 88                                                           yes            no
# 92                                squabbling for bread   unknown       unknown
# 103                                                          yes            no
# 109  Recorded using a Sony PCM-M10 digital audio re...        no            no
# 110  A single call from a 3CY Mediterranean Gull am...       yes            no
# 111  Modified using High Pass Filter due to heavy t...        no            no
# 124  Recorded using a Sony PCM-M10 digital audio re...        no            no
# 125  Recorded using a Sony PCM-M10 digital audio re...        no            no
# 126  Recorded using a Sony PCM-M10 digital audio re...        no            no
# 127  Recorded using a Sony PCM-M10 digital audio re...        no            no
# 128  Recorded using a Sony PCM-M10 digital audio re...        no            no
# 129  Recorded using a Sony PCM-M10 digital audio re...        no            no
# 135  Calls given from a mixed flock of Mediterranea...       yes            no
# 138                                                          yes            no
# 143  Med gull pair  ... high pass filter used ... p...       yes            no
# 147  Calls of a 1st winter bird. At the beginning o...   unknown       unknown
# 148                                                          yes            no
# 161  Recorded using a Sony HDR-CX105 camcorder. Edi...       yes            no
# 162  Interacting with another juvenile med gull. Wi...       yes            no
# 163             NFCs. 00:11. 00:24. Passive. Noc. Amp.        no            no
#
# [32 rows x 26 columns]

# %%
for indx, row in tqdm(species_df.iterrows()):
    print(row.folder_label)
    xeno_download(row.folder_label, top_n = 500, ssp = row.ssp)
# Out:
# 0it [00:00, ?it/s]
# Common Buzzard
# 1it [00:52, 52.77s/it]
# Common Kestrel
# 2it [01:43, 51.81s/it]
# Eurasian Curlew
# 3it [02:32, 50.45s/it]
# Mute Swan
# 4it [03:24, 51.06s/it]
# Tundra Swan (Bewicks)
# 5it [03:25, 33.08s/it]
# Common Snipe
# 6it [04:11, 37.45s/it]
# Meadow Pipit
# 7it [04:57, 40.21s/it]
# European Herring Gull
# 8it [05:53, 45.28s/it]
# European Robin
# 9it [06:46, 47.47s/it]
# Rook
# 10it [07:43, 50.51s/it]
# Northern Lapwing
# 11it [08:32, 46.55s/it]

# %%
xeno_download('Tundra Swan (Bewicks)', top_n = 100, ssp = 'bewickii')
# Out:
# 11
# Tundra Swan
# tundra%20swan

# %%
xeno_download('Tundra Swan', top_n = 100, not_ssp = 'bewickii')

# %%
#xeno_download('Common Buzzard', 'common_buzzard', top_n = 100)

# %%
#xeno_download('Common Kestrel', 'common_kestrel', top_n = 100)

# %%
#xeno_download('Eurasian Curlew', 'eurasian_curlew', top_n = 100)

# %%
#xeno_download('Mute Swan', 'mute_swan', top_n = 100)

# %%
#xeno_download('Common Snipe', 'common_snipe', top_n = 100)

# %%
#xeno_download('Meadow Pipit', 'meadow_pipit', top_n = 100)

# %%
#xeno_download('European Herring Gull', 'european_herring_gull', top_n = 100)

# %%
#xeno_download('European Robin', 'european_robin', top_n = 100)

# %%
#xeno_download('Rook', 'rook', top_n = 100)

# %%
#xeno_download('Northern Lapwing', 'northern_lapwing', top_n = 100)

# %%
import ffmpeg
from pydub import AudioSegment

# %%
wav_check = 'birds'
labels = os.listdir(wav_check)
#print(labels)
for lab in labels:
    for sound_f in os.listdir(os.path.join(wav_check,lab)):
        pre, ext = os.path.splitext(os.path.join(wav_check,lab,sound_f))
        #print(ext)
        if ext == '.wav':
            continue
        s_temp   = AudioSegment.from_file(pre+ext)
        mono_audios = s_temp.split_to_mono()
        if len(mono_audios) >=2:
            mono_audios[0].export(pre+'_left.wav', format="wav")
            mono_audios[1].export(pre+'_right.wav', format="wav")
        else:
            mono_audios[0].export(pre+'.wav', format="wav")

# %%
import re
wav_check = 'birds'
labels = os.listdir(wav_check)
for lab in labels:
    dirname = wav_check+'/'+lab
    for sound_f in os.listdir(dirname):
        if re.search('.wav', sound_f) == None:
            os.remove(os.path.join(dirname, sound_f))

# %%
birds = os.listdir('birds')
count = 0
count_wav = 0
count_list = []
print('Bird audio files')
for bird in birds:
    bird_list = os.listdir(os.path.join('birds', bird))
    bird_count = len(bird_list)
    print('\t', bird, ':\t\t', bird_count, sep = '')
    bird_count_wav = len([s for s in bird_list if s.endswith('wav')])
    print('  of which .wav files:', bird_count_wav)
    count += bird_count
    count_wav += bird_count_wav
    count_list.append(bird_count)
print('Total: ', count)
print('Total .wav: ', count_wav)
# Out:
# Bird audio files
# 	Common Buzzard:		166
#   of which .wav files: 166
# 	Common Kestrel:		165
#   of which .wav files: 165
# 	Common Snipe:		179
#   of which .wav files: 179
# 	Eurasian Curlew:		146
#   of which .wav files: 146
# 	European Herring Gull:		174
#   of which .wav files: 174
# 	European Robin:		184
#   of which .wav files: 184
# 	Meadow Pipit:		170
#   of which .wav files: 170
# 	Mute Swan:		177
#   of which .wav files: 177
# 	Northern Lapwing:		182
#   of which .wav files: 182
# 	Rook:		175
#   of which .wav files: 175
# 	Tundra Swan:		133
#   of which .wav files: 133
# 	Tundra Swan (Bewicks):		130
#   of which .wav files: 130
# Total:  1981
# Total .wav:  1981
