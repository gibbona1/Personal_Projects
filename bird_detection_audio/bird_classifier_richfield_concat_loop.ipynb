# %% [markdown]
# From https://medium.com/m2mtechconnect/classifying-music-and-speech-with-machine-learning-e036ffab002e

# %%
import numpy as np
import pandas as pd
import os
import pathlib
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import display
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import layers, regularizers, models
from sklearn.model_selection import train_test_split
#import tensorflow_datasets as tfds
from datetime import datetime

# %%
import time

# %%
import ffmpeg
from pydub import AudioSegment

# %%
from tf_helpers import *

# %%
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, auc
import plotly.figure_factory as ff
from sklearn.preprocessing import OneHotEncoder

# %%
from data_set_params import DataSetParams
from scipy.io import wavfile
params = DataSetParams()

# %%
#data_dir = pathlib.Path('/root/tensorflow_datasets/downloads/extracted/TAR_GZ.opihi.cs.uvic.ca_sound_music_speechbya81rFcWfLSW6ey5cynqyeq2qiePcL-7asMoNO6IQ0.tar.gz/music_speech')
data_dir   = 'richfield_birds_split'#'dublin_dl_birds_split'#
categories = np.array(tf.io.gfile.listdir(data_dir))
categories = [category for category in categories if 'wav' not in category]
categories
# Out:
# ['Common Buzzard',
#  'Common Kestrel',
#  'Common Snipe',
#  'Eurasian Curlew',
#  'European Herring Gull',
#  'European Robin',
#  'Meadow Pipit',
#  'Mute Swan',
#  'Northern Lapwing',
#  'Rook',
#  'Tundra Swan',
#  'Tundra Swan (Bewicks)']

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = [filename for filename in filenames if 'wav' in filename]
#filenames = tf.random.shuffle(filenames)
#filenames

# %%
num_samples = len(filenames)
print('Number of total examples:', num_samples)
print('Number of categories', len(categories))
#print('Number of examples per label:',
#      len(tf.io.gfile.listdir(str(pathlib.Path(data_dir)/categories[0]))))
print('Example file tensor:', filenames[0])
# Out:
# Number of total examples: 2840
# Number of categories 12
# Example file tensor: richfield_birds_split\Common Snipe\xc618120_left_start_0_0.wav

# %%
AUTOTUNE   = tf.data.experimental.AUTOTUNE
TRAIN_SIZE = 0.8
cutoff     = int(len(filenames) * TRAIN_SIZE)

# %%
choice_list = []
choices_lst = ['Mod', 'AbsRe', 'AbsIm', 'AbsAng']
import itertools
for L in range(1,len(choices_lst)+1):
    for subset in itertools.combinations(choices_lst, L):
        choice_list.append(list(subset))

# %%
#choice_list = choice_list[:4]

# %%
#choice_list = choice_list[4:]

# %%
choice_list = [x for x in choice_list if 'Mod' in x]

# %%
def find_sub_list(sl,l):
    results=[]
    sll=len(sl)
    for i,e in enumerate(l):
        for j in range(sll):
            if sl[j] == l[i]:
                results.append(i)

    return results

# %% [markdown]
# ## Outline of script needed:
# for i in 1,...,20 iterations
# -  shuffles files
# -  seperates into train/test
# -  For different combinations of Mod (default), AbsRe, AbsIm, AbsArg
#     -  create spectrogram features (X) and labels (y)
#     -  create training and test tensorflow datasets and batch
#     -  train from scratch for 5,10,25,50 epochs
#     -  record history(loss, accuracy), yTrue and yPred,
#     -  save confusion matrices
# -  Also try
#     - work on making the convolution kernel different for each channel, and for the output to be the mean
#     - freeze layers (all but first or last) to fine tune training
#     - Transfer learning from BirdNet

# %%
def main_model_run(filenames, index):
    filenames   = tf.random.shuffle(filenames)
    
    all_labs = [get_label(y).numpy().decode() for y in filenames]
    filename_df = pd.DataFrame({'name': filenames.numpy(),
                                'label': all_labs})
    
    train, test = train_test_split(filename_df, test_size=0.2, stratify=filename_df[['label']])
    train_files = tf.random.shuffle(train['name'])
    test_files  = tf.random.shuffle(test['name'])
    #train_files = filenames[:cutoff]
    #test_files  = filenames[cutoff:]
    
    choices_all = ['Mod', 'AbsRe', 'AbsIm', 'AbsAng']

    def concat_xy(ds):
            x_tmp  = [x for x,y in ds]
            x_tmp  = tf.stack(x_tmp)
            xs_tmp = tf.unstack(x_tmp, axis=-1)
            xs_tmp = [tf.expand_dims(x_ind, axis=-1) for x_ind in xs_tmp]
            y      = np.array([y for x,y in ds])
            return xs_tmp, y
    
    train_ds = preprocess_dataset(train_files, choices_all, categories)
    test_ds  = preprocess_dataset(test_files, choices_all, categories)
    
    print('Getting data')
    X_train_all, y_train = concat_xy(train_ds)
    X_test_all, y_test   = concat_xy(test_ds)
    print("Done")
    
    filename_idx = datetime.now().strftime("%Y%m%d-%H%M%S").replace('-', '_')+'_'+data_dir+'_concat'+str(index)
    
    np.save('filenames/'+'filenames'+filename_idx+'.npy', filenames.numpy())
    print("index: ", index)
    for choices in choice_list:
        print('Choices: ', ''.join(choices))
        
        sub_idx  = find_sub_list(choices, choices_all)
        X_train = [X_train_all[idx] for idx in sub_idx]
        X_test  = [X_test_all[idx] for idx in sub_idx]
        #y_train = [y_train_all[idx] for idx in sub_idx]
        #y_test  = [y_test_all[idx] for idx in sub_idx]
        
        input_shape = X_train[0].shape[1:]
            
        num_channels = len(X_train)
        num_classes  = len(categories)
        
        filename_run = filename_idx + ''.join(choices)+'_'
        #print(not os.path.isdir('checkpoints/'+filename_run))
        #if not os.path.isdir('checkpoints/'+filename_run):
        #    os.mkdir('checkpoints/'+filename_run)
        
        #checkpoint_path = 'checkpoints/'+filename_run+"/cp-{epoch:04d}.ckpt"
        #checkpoint_dir = os.path.dirname(checkpoint_path)
        
        #cp_callback = tf.keras.callbacks.ModelCheckpoint(
        #    filepath= checkpoint_path, 
        #    verbose = 1, 
        #    save_weights_only = True,
        #    save_freq = 5*batch_size)
        
        #model   = main_cnn(input_shape, num_classes)
        model = concat_model(input_shape, num_channels, num_classes)
        
        #model.save_weights(checkpoint_path.format(epoch=0))
        
        EPOCHS  = 10
        history = model.fit(X_train, y_train,
                            validation_data = (X_test, y_test),
                            #callbacks       = [cp_callback],
                            epochs          = EPOCHS,
                            batch_size      = 32)
        
        pd.DataFrame(history.history).to_csv('model_history/'+'model_history'+filename_run+'.csv')
        
        
        model.save('models/'+filename_run+'.h5')
        y_pred = np.argmax(model.predict(X_test), axis=-1)
        y_true = y_test
        
        np.save('y_pred/'+'y_pred'+filename_run+'.npy', y_pred)
        np.save('y_true/'+'y_true'+filename_run+'.npy', y_true)
        
        #cm = confusion_matrix(y_true, y_pred)
        
        #fig = plotly_cm(cm, categories)
        #fig.write_html('confusion_matrix/'+'confusion_matrix'+filename_run+'.html')
        
        #pred_lists = model.predict(test_ds)
        #pred_df    = pd.DataFrame(pred_lists, columns = categories)
        #pred_df_softmax = pred_df.apply(lambda x: np.exp(x - np.max(x))/np.exp(x - np.max(x)).sum(), axis=1)
        
        #pred_df_softmax.to_csv('pred_df_softmax/'+'pred_df_softmax'+filename_run+'.csv')

# %%
for i in range(9,10):
    print(i)
# Out:
# 9

# %%
tic = time.time()

# %%
for i in range(6):
    main_model_run(filenames, i)
    print(time.time()-tic)
# Out:
# Getting data
# Done
# index:  0
# Choices:  Mod
# Epoch 1/10
# 71/71 [==============================] - 12s 162ms/step - loss: 2.4274 - accuracy: 0.2364 - val_loss: 2.1636 - val_accuracy: 0.3715
# Epoch 2/10
# 71/71 [==============================] - 11s 159ms/step - loss: 2.1179 - accuracy: 0.3504 - val_loss: 1.8988 - val_accuracy: 0.4331
# Epoch 3/10
# 71/71 [==============================] - 11s 158ms/step - loss: 1.9321 - accuracy: 0.4199 - val_loss: 1.7568 - val_accuracy: 0.4754
# Epoch 4/10
# 71/71 [==============================] - 11s 161ms/step - loss: 1.7866 - accuracy: 0.4577 - val_loss: 1.6764 - val_accuracy: 0.5088
# Epoch 5/10
# 71/71 [==============================] - 12s 165ms/step - loss: 1.6894 - accuracy: 0.4780 - val_loss: 1.6088 - val_accuracy: 0.5211
# Epoch 6/10
# 71/71 [==============================] - 12s 166ms/step - loss: 1.6292 - accuracy: 0.5154 - val_loss: 1.5677 - val_accuracy: 0.5440
# Epoch 7/10
# 71/71 [==============================] - 12s 166ms/step - loss: 1.5243 - accuracy: 0.5352 - val_loss: 1.5378 - val_accuracy: 0.5563
# Epoch 8/10
# 71/71 [==============================] - 12s 172ms/step - loss: 1.4902 - accuracy: 0.5638 - val_loss: 1.5072 - val_accuracy: 0.5634
# Epoch 9/10
# 71/71 [==============================] - 12s 169ms/step - loss: 1.4588 - accuracy: 0.5687 - val_loss: 1.4880 - val_accuracy: 0.5704
# Epoch 10/10
# 71/71 [==============================] - 12s 172ms/step - loss: 1.4013 - accuracy: 0.5819 - val_loss: 1.4728 - val_accuracy: 0.5827
# Choices:  ModAbsRe
# Epoch 1/10
# 71/71 [==============================] - 23s 321ms/step - loss: 2.3380 - accuracy: 0.2667 - val_loss: 2.0377 - val_accuracy: 0.4472
# Epoch 2/10
# 71/71 [==============================] - 24s 333ms/step - loss: 1.9970 - accuracy: 0.4168 - val_loss: 1.8157 - val_accuracy: 0.4613
# Epoch 3/10
# 71/71 [==============================] - 24s 333ms/step - loss: 1.7811 - accuracy: 0.4727 - val_loss: 1.6995 - val_accuracy: 0.5000
# Epoch 4/10
# 71/71 [==============================] - 24s 334ms/step - loss: 1.6579 - accuracy: 0.5106 - val_loss: 1.6310 - val_accuracy: 0.5423
# Epoch 5/10
# 71/71 [==============================] - 24s 334ms/step - loss: 1.5767 - accuracy: 0.5409 - val_loss: 1.5739 - val_accuracy: 0.5704
# Epoch 6/10
# 71/71 [==============================] - 25s 347ms/step - loss: 1.4950 - accuracy: 0.5660 - val_loss: 1.5194 - val_accuracy: 0.5792
# Epoch 7/10
# 71/71 [==============================] - 24s 335ms/step - loss: 1.4108 - accuracy: 0.5938 - val_loss: 1.4869 - val_accuracy: 0.5968
# Epoch 2/10
# 71/71 [==============================] - 24s 345ms/step - loss: 2.0685 - accuracy: 0.3737 - val_loss: 1.7692 - val_accuracy: 0.5000
# Epoch 3/10
# 71/71 [==============================] - 24s 339ms/step - loss: 1.8783 - accuracy: 0.4300 - val_loss: 1.6310 - val_accuracy: 0.5317
# Epoch 4/10
# 71/71 [==============================] - 24s 338ms/step - loss: 1.7230 - accuracy: 0.4798 - val_loss: 1.5301 - val_accuracy: 0.5792
# Epoch 5/10
# 71/71 [==============================] - 24s 338ms/step - loss: 1.6281 - accuracy: 0.5079 - val_loss: 1.4539 - val_accuracy: 0.6004
# Epoch 6/10
# 71/71 [==============================] - 24s 338ms/step - loss: 1.5576 - accuracy: 0.5414 - val_loss: 1.4056 - val_accuracy: 0.6039
# Epoch 7/10
# 71/71 [==============================] - 24s 340ms/step - loss: 1.4898 - accuracy: 0.5506 - val_loss: 1.3911 - val_accuracy: 0.6056
# Epoch 8/10
# 71/71 [==============================] - 24s 342ms/step - loss: 1.4486 - accuracy: 0.5748 - val_loss: 1.3563 - val_accuracy: 0.6215
# Epoch 9/10
# 71/71 [==============================] - 24s 342ms/step - loss: 1.3539 - accuracy: 0.6109 - val_loss: 1.3476 - val_accuracy: 0.6303
# Epoch 10/10
# 71/71 [==============================] - 24s 338ms/step - loss: 1.3037 - accuracy: 0.6369 - val_loss: 1.2956 - val_accuracy: 0.6356
# Choices:  ModAbsIm
# Epoch 1/10
# 71/71 [==============================] - 25s 343ms/step - loss: 2.3506 - accuracy: 0.2650 - val_loss: 2.0469 - val_accuracy: 0.4278
# Epoch 2/10
# 71/71 [==============================] - 26s 367ms/step - loss: 1.9847 - accuracy: 0.3996 - val_loss: 1.7497 - val_accuracy: 0.4912
# Epoch 3/10
# 71/71 [==============================] - 26s 368ms/step - loss: 1.8067 - accuracy: 0.4494 - val_loss: 1.6085 - val_accuracy: 0.5599
# Epoch 4/10
# 71/71 [==============================] - 26s 370ms/step - loss: 1.6861 - accuracy: 0.4987 - val_loss: 1.5396 - val_accuracy: 0.5827
# Epoch 5/10
# 71/71 [==============================] - 26s 367ms/step - loss: 1.5805 - accuracy: 0.5453 - val_loss: 1.4547 - val_accuracy: 0.5792
# Epoch 6/10
# 71/71 [==============================] - 26s 367ms/step - loss: 1.5268 - accuracy: 0.5585 - val_loss: 1.4287 - val_accuracy: 0.5898
# Epoch 7/10
# 71/71 [==============================] - 27s 376ms/step - loss: 1.4391 - accuracy: 0.5779 - val_loss: 1.3915 - val_accuracy: 0.6039
# Epoch 8/10
# 71/71 [==============================] - 26s 373ms/step - loss: 1.3775 - accuracy: 0.6012 - val_loss: 1.3786 - val_accuracy: 0.6250
# Epoch 9/10
# 71/71 [==============================] - 26s 369ms/step - loss: 1.3090 - accuracy: 0.6140 - val_loss: 1.3392 - val_accuracy: 0.6180
# Epoch 10/10
# 71/71 [==============================] - 26s 368ms/step - loss: 1.2544 - accuracy: 0.6408 - val_loss: 1.3366 - val_accuracy: 0.6250
# Choices:  ModAbsAng
# Epoch 1/10
# 71/71 [==============================] - 26s 367ms/step - loss: 2.4809 - accuracy: 0.1910 - val_loss: 2.2450 - val_accuracy: 0.2817
# Epoch 2/10
# 71/71 [==============================] - 26s 362ms/step - loss: 2.1873 - accuracy: 0.3050 - val_loss: 1.9675 - val_accuracy: 0.4542
# Epoch 3/10
# 71/71 [==============================] - 26s 360ms/step - loss: 2.0082 - accuracy: 0.3746 - val_loss: 1.7870 - val_accuracy: 0.4842
# Epoch 4/10
# 71/71 [==============================] - 26s 361ms/step - loss: 1.8649 - accuracy: 0.4230 - val_loss: 1.6434 - val_accuracy: 0.5352
# Epoch 5/10
# 71/71 [==============================] - 26s 364ms/step - loss: 1.7516 - accuracy: 0.4732 - val_loss: 1.5583 - val_accuracy: 0.5634
# Epoch 6/10
# 71/71 [==============================] - 26s 362ms/step - loss: 1.6595 - accuracy: 0.5013 - val_loss: 1.4818 - val_accuracy: 0.5863
# Epoch 7/10
# 71/71 [==============================] - 26s 362ms/step - loss: 1.5805 - accuracy: 0.5308 - val_loss: 1.4229 - val_accuracy: 0.5863
# Epoch 8/10
# 71/71 [==============================] - 25s 359ms/step - loss: 1.5149 - accuracy: 0.5550 - val_loss: 1.3830 - val_accuracy: 0.6162
# Epoch 9/10
# 71/71 [==============================] - 25s 358ms/step - loss: 1.4594 - accuracy: 0.5638 - val_loss: 1.3530 - val_accuracy: 0.6338
# Epoch 10/10
# 71/71 [==============================] - 25s 359ms/step - loss: 1.3955 - accuracy: 0.5915 - val_loss: 1.3160 - val_accuracy: 0.6162
# Choices:  ModAbsReAbsIm
# Epoch 1/10
# 71/71 [==============================] - 39s 540ms/step - loss: 2.3151 - accuracy: 0.2870 - val_loss: 1.9339 - val_accuracy: 0.4683
# Epoch 2/10
# 71/71 [==============================] - 39s 551ms/step - loss: 1.9258 - accuracy: 0.4234 - val_loss: 1.6687 - val_accuracy: 0.5194
# Epoch 3/10
# 71/71 [==============================] - 38s 538ms/step - loss: 1.7209 - accuracy: 0.4850 - val_loss: 1.5437 - val_accuracy: 0.5651
# Epoch 4/10
# 71/71 [==============================] - 38s 539ms/step - loss: 1.6269 - accuracy: 0.5154 - val_loss: 1.4778 - val_accuracy: 0.5687
# Epoch 5/10
# 71/71 [==============================] - 38s 531ms/step - loss: 1.5433 - accuracy: 0.5511 - val_loss: 1.4389 - val_accuracy: 0.5880
# Epoch 6/10
# 71/71 [==============================] - 37s 526ms/step - loss: 1.4556 - accuracy: 0.5770 - val_loss: 1.4122 - val_accuracy: 0.5880
# Epoch 7/10
# 71/71 [==============================] - 37s 525ms/step - loss: 1.4004 - accuracy: 0.5885 - val_loss: 1.3612 - val_accuracy: 0.6250
# Epoch 8/10
# 71/71 [==============================] - 37s 521ms/step - loss: 1.3349 - accuracy: 0.6162 - val_loss: 1.3179 - val_accuracy: 0.6215
# Epoch 9/10
# 71/71 [==============================] - 37s 522ms/step - loss: 1.2635 - accuracy: 0.6347 - val_loss: 1.3312 - val_accuracy: 0.6232
# Epoch 10/10
# 71/71 [==============================] - 37s 523ms/step - loss: 1.2182 - accuracy: 0.6395 - val_loss: 1.3148 - val_accuracy: 0.6356
# Choices:  ModAbsReAbsAng
# Epoch 1/10
# 71/71 [==============================] - 37s 519ms/step - loss: 2.4030 - accuracy: 0.2055 - val_loss: 2.0283 - val_accuracy: 0.4419
# Epoch 2/10
# 71/71 [==============================] - 37s 518ms/step - loss: 2.0102 - accuracy: 0.3829 - val_loss: 1.7235 - val_accuracy: 0.5000
# Epoch 3/10
# 71/71 [==============================] - 36s 513ms/step - loss: 1.7963 - accuracy: 0.4608 - val_loss: 1.5471 - val_accuracy: 0.5739
# Epoch 4/10
# 71/71 [==============================] - 37s 515ms/step - loss: 1.6150 - accuracy: 0.5440 - val_loss: 1.4422 - val_accuracy: 0.6039
# Epoch 5/10
# 71/71 [==============================] - 36s 512ms/step - loss: 1.5242 - accuracy: 0.5607 - val_loss: 1.3960 - val_accuracy: 0.6021
# Epoch 6/10
# 71/71 [==============================] - 36s 511ms/step - loss: 1.4407 - accuracy: 0.5805 - val_loss: 1.3493 - val_accuracy: 0.6180
# Epoch 7/10
# 71/71 [==============================] - 36s 510ms/step - loss: 1.3527 - accuracy: 0.6127 - val_loss: 1.3180 - val_accuracy: 0.6602
# Epoch 8/10
# 71/71 [==============================] - 37s 514ms/step - loss: 1.2998 - accuracy: 0.6378 - val_loss: 1.2896 - val_accuracy: 0.6496
# Epoch 9/10
# 71/71 [==============================] - 36s 513ms/step - loss: 1.2137 - accuracy: 0.6607 - val_loss: 1.2555 - val_accuracy: 0.6620
# Epoch 10/10
# 71/71 [==============================] - 36s 512ms/step - loss: 1.1701 - accuracy: 0.6796 - val_loss: 1.2385 - val_accuracy: 0.6761
# Choices:  ModAbsImAbsAng
# Epoch 1/10
# 71/71 [==============================] - 37s 520ms/step - loss: 2.5317 - accuracy: 0.1730 - val_loss: 2.2427 - val_accuracy: 0.3239
# Epoch 2/10
# 71/71 [==============================] - 36s 509ms/step - loss: 2.2226 - accuracy: 0.2848 - val_loss: 1.9300 - val_accuracy: 0.4754
# Epoch 3/10
# 71/71 [==============================] - 36s 511ms/step - loss: 1.9752 - accuracy: 0.3798 - val_loss: 1.7199 - val_accuracy: 0.5511
# Epoch 4/10
# 71/71 [==============================] - 36s 507ms/step - loss: 1.7951 - accuracy: 0.4472 - val_loss: 1.5766 - val_accuracy: 0.5405
# Epoch 5/10
# 71/71 [==============================] - 36s 508ms/step - loss: 1.6638 - accuracy: 0.5097 - val_loss: 1.4756 - val_accuracy: 0.6162
# Epoch 6/10
# 71/71 [==============================] - 36s 509ms/step - loss: 1.5238 - accuracy: 0.5467 - val_loss: 1.4224 - val_accuracy: 0.6092
# Epoch 7/10
# 71/71 [==============================] - 36s 513ms/step - loss: 1.4764 - accuracy: 0.5691 - val_loss: 1.3868 - val_accuracy: 0.6444
# Epoch 8/10
# 71/71 [==============================] - 37s 526ms/step - loss: 1.3948 - accuracy: 0.5938 - val_loss: 1.3222 - val_accuracy: 0.6408
# Epoch 9/10
# 71/71 [==============================] - 37s 528ms/step - loss: 1.2999 - accuracy: 0.6184 - val_loss: 1.2903 - val_accuracy: 0.6602
# Epoch 10/10
# 71/71 [==============================] - 38s 541ms/step - loss: 1.2352 - accuracy: 0.6488 - val_loss: 1.2637 - val_accuracy: 0.6585
# Choices:  ModAbsReAbsImAbsAng
# Epoch 1/10
# 71/71 [==============================] - 50s 695ms/step - loss: 2.4185 - accuracy: 0.2165 - val_loss: 2.0768 - val_accuracy: 0.3768
# Epoch 2/10
# 71/71 [==============================] - 48s 675ms/step - loss: 2.0697 - accuracy: 0.3451 - val_loss: 1.8066 - val_accuracy: 0.4982
# Epoch 3/10
# 71/71 [==============================] - 48s 671ms/step - loss: 1.8431 - accuracy: 0.4344 - val_loss: 1.6274 - val_accuracy: 0.5493
# Epoch 4/10
# 71/71 [==============================] - 47s 669ms/step - loss: 1.6899 - accuracy: 0.4943 - val_loss: 1.5305 - val_accuracy: 0.5634
# Epoch 5/10
# 71/71 [==============================] - 49s 688ms/step - loss: 1.5808 - accuracy: 0.5268 - val_loss: 1.4717 - val_accuracy: 0.6021
# Epoch 6/10
# 71/71 [==============================] - 48s 679ms/step - loss: 1.4874 - accuracy: 0.5647 - val_loss: 1.4067 - val_accuracy: 0.5986
# Epoch 7/10
# 71/71 [==============================] - 50s 701ms/step - loss: 1.4025 - accuracy: 0.5854 - val_loss: 1.3532 - val_accuracy: 0.6444
# Epoch 8/10
# 71/71 [==============================] - 48s 672ms/step - loss: 1.2991 - accuracy: 0.6180 - val_loss: 1.3136 - val_accuracy: 0.6461
# Epoch 9/10
# 71/71 [==============================] - 48s 672ms/step - loss: 1.2350 - accuracy: 0.6461 - val_loss: 1.2868 - val_accuracy: 0.6461
# Epoch 10/10
# 71/71 [==============================] - 48s 678ms/step - loss: 1.1794 - accuracy: 0.6562 - val_loss: 1.2771 - val_accuracy: 0.6725
# 9107.290979385376
# Getting data
# Done
# index:  3
# Choices:  Mod
# Epoch 1/10
# 56/71 [======================>.......] - ETA: 2s - loss: 2.5679 - accuracy: 0.1752
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-449bec7b6155> in <module>
#       1 for i in range(6):
# ----> 2     main_model_run(filenames, i)
#       3     print(time.time()-tic)
#
# <ipython-input-17-7f521651ba26> in main_model_run(filenames, index)
#      68
#      69         EPOCHS  = 10
# ---> 70         history = model.fit(X_train, y_train,
#      71                             validation_data = (X_test, y_test),
#      72                             #callbacks       = [cp_callback],
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
toc = time.time()

# %%
print(toc-tic)

# %%
train_files = filenames[:cutoff]
test_files  = filenames[cutoff:]

choices_all = ['Mod', 'AbsRe', 'AbsIm', 'AbsAng']

def concat_xy(ds):
        x_tmp  = [x for x,y in ds]
        x_tmp  = tf.stack(x_tmp)
        xs_tmp = tf.unstack(x_tmp, axis=-1)
        xs_tmp = [tf.expand_dims(x_ind, axis=-1) for x_ind in xs_tmp]
        y      = np.array([y for x,y in ds])
        return xs_tmp, y

train_ds = preprocess_dataset(train_files, choices_all, categories)

# %%
#X_train_all, y_train_all = concat_xy(train_ds)

# %%
#y_train_all
