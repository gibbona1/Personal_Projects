# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model
import numpy as np
import pandas as pd
import os

# %%
import matplotlib.pyplot as plt

# %%
#data_dir = pathlib.Path('/root/tensorflow_datasets/downloads/extracted/TAR_GZ.opihi.cs.uvic.ca_sound_music_speechbya81rFcWfLSW6ey5cynqyeq2qiePcL-7asMoNO6IQ0.tar.gz/music_speech')
data_dir   = 'richfield_birds_split'#'dublin_dl_birds_split'#
categories = np.array(tf.io.gfile.listdir(data_dir))
categories = [category for category in categories if 'wav' not in category]
categories
# Out:
# ['Common Buzzard',
#  'Common Kestrel',
#  'Common Snipe',
#  'Eurasian Curlew',
#  'European Herring Gull',
#  'European Robin',
#  'Meadow Pipit',
#  'Mute Swan',
#  'Northern Lapwing',
#  'Rook',
#  'Tundra Swan',
#  'Tundra Swan (Bewicks)']

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)

    # Note: You'll use indexing here instead of tuple unpacking to enable this 
    # to work in a TensorFlow graph.
    return parts[-2]

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
#filenames = tf.io.gfile.glob('birds/*/*')
filenames = [filename for filename in filenames if 'wav' in filename]
filenames = tf.random.shuffle(filenames)

# %%
all_labs = [get_label(y).numpy().decode() for y in filenames]

# %%
filename_df = pd.DataFrame({'name': filenames.numpy(),
                            'label': all_labs
                           })

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(filename_df, test_size=0.2, stratify=filename_df[['label']])

# %%
#TRAIN_SIZE = 0.8

#cutoff = int(len(filenames) * TRAIN_SIZE)
#train_files = filenames[:cutoff]
#test_files  = filenames[cutoff:]
train_files = tf.random.shuffle(train['name'])
test_files  = tf.random.shuffle(test['name'])

print('Training set size:', len(train_files))
print('Validation set size:', len(test_files))
# Out:
# Training set size: 2272
# Validation set size: 568

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
num_labels = len(categories)

# %%
from tf_helpers import *

# %%
choices = ['Mod'] #['AbsRe', 'AbsIm', 'Mod', 'AbsAng']

# %%
train_ds = preprocess_dataset(train_files, choices, categories, req_width=750, single_to_rgb = True, resize = 4)
test_ds  = preprocess_dataset(test_files,  choices, categories, req_width=750, single_to_rgb = True, resize = 4)

# %%
for spec, lab in train_ds.take(1):
    spec = spec
    input_shape = tf.expand_dims(spec[:,:,0], axis=-1).shape
    #input_shape = spec[:,:,0].shape
    print(input_shape)
    print(categories[lab])
# Out:
# (128, 187, 1)
# Meadow Pipit

# %%
spec.shape
tf.shape(spec)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([128, 187,   3])>

# %%
spec.shape
# Out:
# TensorShape([128, 187, 3])

# %%
y_train = np.array([y for x,y in train_ds])
y_test  = np.array([y for x,y in test_ds])

# %%
#x_tmp  = [tf.concat([x,x,x], axis=-1) for x,y in train_ds]
#x_tmp  = tf.stack(x_tmp)
#xs_tmp = tf.unstack(x_tmp, axis=-1)
#xs_tmp = [tf.expand_dims(x_ind, axis=-1) for x_ind in xs_tmp]

# %%
#x_tmp_test  = [tf.concat([x,x,x], axis=-1) for x,y in test_ds]
#x_tmp_test  = tf.stack(x_tmp_test)
#xs_tmp_test = tf.unstack(x_tmp_test, axis=-1)
#xs_tmp_test = [tf.expand_dims(x_ind, axis=-1) for x_ind in xs_tmp_test]

# %%
#num_channels = len(xs_tmp)

# %%
#x_tmp_test.shape[1:]

# %% [markdown]
# ## Load off the shelf models

# %%
#vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=spec.shape)
#vgg_model.trainable = False ## Not trainable weights
#vgg_model.summary()

# %%
#x = vgg_model.output
#x = Flatten()(x) # Flatten dimensions to for use in FC layers
#x = Dense(256, activation='relu')(x)
#x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
#x = Dense(64, activation='relu')(x)
#x = Dense(num_labels, activation='softmax')(x) # Softmax for multiclass
#transfer_vgg_model = Model(inputs=vgg_model.input, outputs=x)
transfer_vgg_model = tf.keras.models.load_model('models/20220223_170126_richfield_birds_split_vgg19.h5')

# %%
transfer_vgg_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 187, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 187, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 187, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 93, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 93, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 93, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 46, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 46, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 46, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 46, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 23, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 23, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 23, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 23, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 11, 512)        0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 11, 512)        2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 11, 512)        2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 11, 512)        2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 5, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 10240)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2621696
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                780
# =================================================================
# Total params: 17,353,612
# Trainable params: 2,638,924
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=spec.shape)
#resnet_model.trainable = False ## Not trainable weights
#resnet_model.summary()

# %%
#x = resnet_model.output
#x = Flatten()(x) # Flatten dimensions to for use in FC layers
#x = Dense(256, activation='relu')(x)
#x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
#x = Dense(64, activation='relu')(x)
#x = Dense(num_labels, activation='softmax')(x) # Softmax for multiclass
#transfer_resnet_model = Model(inputs=resnet_model.input, outputs=x)
transfer_resnet_model = tf.keras.models.load_model('models/20220223_173445_richfield_birds_split_resnet50.h5')

# %%
transfer_resnet_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 187, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 134, 193, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 64, 94, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 64, 94, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 64, 94, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 66, 96, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 32, 47, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 32, 47, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 32, 47, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 32, 47, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 32, 47, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 32, 47, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 32, 47, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 32, 47, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 32, 47, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 32, 47, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 32, 47, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 32, 47, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 32, 47, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 32, 47, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 32, 47, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 32, 47, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 32, 47, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 32, 47, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 32, 47, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 32, 47, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 32, 47, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 32, 47, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 32, 47, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 32, 47, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 32, 47, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 32, 47, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 32, 47, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 32, 47, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 32, 47, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 32, 47, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 32, 47, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 32, 47, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 32, 47, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 16, 24, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 16, 24, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 16, 24, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 16, 24, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 16, 24, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 16, 24, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 16, 24, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 16, 24, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 16, 24, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 16, 24, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 16, 24, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 16, 24, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 16, 24, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 16, 24, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 16, 24, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 16, 24, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 16, 24, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 16, 24, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 16, 24, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 16, 24, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 16, 24, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 16, 24, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 16, 24, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 16, 24, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 16, 24, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 16, 24, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 16, 24, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 16, 24, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 16, 24, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 16, 24, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 16, 24, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 16, 24, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 16, 24, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 16, 24, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 16, 24, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 16, 24, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 16, 24, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 16, 24, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 16, 24, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 16, 24, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 16, 24, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 16, 24, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 8, 12, 256)   131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 8, 12, 256)   0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 8, 12, 256)   590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 8, 12, 256)   0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 8, 12, 1024)  525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 8, 12, 1024)  263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 8, 12, 1024)  4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 8, 12, 1024)  4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 8, 12, 1024)  0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 8, 12, 1024)  0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 8, 12, 256)   262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 8, 12, 256)   0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 8, 12, 256)   590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 8, 12, 256)   0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 8, 12, 1024)  263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 8, 12, 1024)  4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 8, 12, 1024)  0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 8, 12, 1024)  0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 8, 12, 256)   262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 8, 12, 256)   0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 8, 12, 256)   590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 8, 12, 256)   0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 8, 12, 1024)  263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 8, 12, 1024)  4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 8, 12, 1024)  0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 8, 12, 1024)  0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 8, 12, 256)   262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 8, 12, 256)   0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 8, 12, 256)   590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 8, 12, 256)   0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 8, 12, 1024)  263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 8, 12, 1024)  4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 8, 12, 1024)  0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 8, 12, 1024)  0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 8, 12, 256)   262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 8, 12, 256)   0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 8, 12, 256)   590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 8, 12, 256)   0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 8, 12, 1024)  263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 8, 12, 1024)  4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 8, 12, 1024)  0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 8, 12, 1024)  0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 8, 12, 256)   262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 8, 12, 256)   0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 8, 12, 256)   590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 8, 12, 256)   1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 8, 12, 256)   0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 8, 12, 1024)  263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 8, 12, 1024)  4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 8, 12, 1024)  0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 8, 12, 1024)  0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 4, 6, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 4, 6, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 4, 6, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 4, 6, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 4, 6, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 4, 6, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 4, 6, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 4, 6, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 4, 6, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 4, 6, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 4, 6, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 4, 6, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 4, 6, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 4, 6, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 4, 6, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 4, 6, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 4, 6, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 4, 6, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 4, 6, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 4, 6, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 4, 6, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 4, 6, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 4, 6, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 4, 6, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 4, 6, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 4, 6, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 4, 6, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 4, 6, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 4, 6, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 4, 6, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 4, 6, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 4, 6, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 49152)        0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          12583168    flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           16448       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 12)           780         dense_7[0][0]
# ==================================================================================================
# Total params: 36,188,108
# Trainable params: 12,600,396
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
transfer_vgg_model.compile(
        optimizer = optimizers.Adam(learning_rate=0.0001),
        loss      = losses.SparseCategoricalCrossentropy(),
        metrics   = 'accuracy'
        )

# %% [markdown]
# ## Evaluate

# %%
batch_size    = 32
train_ds = train_ds.batch(batch_size)
test_ds  = test_ds.batch(batch_size)
train_ds = train_ds.cache().prefetch(AUTOTUNE)
test_ds  = test_ds.cache().prefetch(AUTOTUNE)

# %%
#vgg_history = transfer_vgg_model.fit(train_ds,
#                    validation_data = test_ds,
#                    epochs          = 15)

# %%
from datetime import datetime

# %%
#transfer_vgg_model.save('models/'+datetime.now().strftime("%Y%m%d-%H%M%S").replace('-', '_')+'_'+data_dir+'_vgg16'+'.h5')

# %%
#metrics = vgg_history2.history
#plt.plot(vgg_history2.epoch, metrics['loss'], metrics['val_loss'])
#plt.legend(['loss', 'val_loss'])
#plt.show()
#plt.plot(vgg_history2.epoch, metrics['accuracy'], metrics['val_accuracy'])
#plt.legend(['accuracy', 'val_accuracy'])
#plt.show()

# %%
transfer_resnet_model.compile(
        optimizer = optimizers.Adam(learning_rate=0.0001),
        loss      = losses.SparseCategoricalCrossentropy(),
        metrics   = 'accuracy'
        )

# %%
#resnet_history = transfer_resnet_model.fit(train_ds,
#                    validation_data = test_ds,
#                    epochs          = 10)

# %%
#transfer_resnet_model.save('models/'+datetime.now().strftime("%Y%m%d-%H%M%S").replace('-', '_')+'_'+data_dir+'_resnet50'+'.h5')

# %%
#metrics = resnet_history.history
#plt.plot(resnet_history.epoch, metrics['loss'], metrics['val_loss'])
#plt.legend(['loss', 'val_loss'])
#plt.show()
#plt.plot(resnet_history.epoch, metrics['accuracy'], metrics['val_accuracy'])
#plt.legend(['accuracy', 'val_accuracy'])
#plt.show()

# %%
#pred_lists = transfer_vgg_model.predict(test_ds)

# %%
y_true = y_test
#y_pred = np.argmax(pred_lists, axis=-1)
#pred_df = pd.DataFrame(pred_lists, columns = categories)
#pred_df_softmax = pred_df.apply(lambda x: np.exp(x - np.max(x))/np.exp(x - np.max(x)).sum(), axis=1)

# %% [markdown]
# ## Generate metrics

# %% [markdown]
# Metics:
# - Top-1 and top-5 accuracy
# - Precision (mAP and cmAP), recall, F1 score
# - Number of (trainable) parameters
# - Single class AUC
# - Softmax data frame

# %%
from sklearn.metrics import accuracy_score, precision_score, f1_score, roc_auc_score, top_k_accuracy_score
from sklearn.preprocessing import OneHotEncoder
from math import prod

# %%
def result_df(model, x_test, y_true, name):
    pred_lists = model.predict(x_test)
    y_pred     = np.argmax(pred_lists, axis=-1)
    pred_df    = pd.DataFrame(pred_lists, columns = categories)
    pred_df_softmax  = pred_df.apply(lambda x: np.exp(x - np.max(x))/np.exp(x - np.max(x)).sum(), axis=1)
    num_trainable    = sum([prod(w.shape) for w in model.trainable_weights])
    num_nontrainable = sum([prod(w.shape) for w in model.non_trainable_weights])
    onehot_data = OneHotEncoder(sparse=False)
    onehot_data = onehot_data.fit_transform(np.array(y_true).reshape(len(y_true),1))
    roc_auc = [0]*num_labels
    for i in range(num_labels):
        roc_auc[i] = roc_auc_score(onehot_data[:, i], pred_df_softmax.to_numpy()[:, i])
    df1 = pd.DataFrame(data={
              'model':     name,
              'top_1_acc': [accuracy_score(y_pred, y_true)],
              'top_5_acc': [top_k_accuracy_score(y_true, pred_df_softmax, k=5)],
              'precision': [precision_score(y_pred, y_true, average = 'weighted')], 
              'f1':        [f1_score(y_pred, y_true, average = 'weighted')], 
              'trainable_params': [num_trainable],
              'nontrainable_params': [num_nontrainable]
             })
    df2 = pd.DataFrame([roc_auc], columns = ['auc_'+categories[i].replace(' ', '') for i in range(num_labels)])
    df  = pd.concat([df1,df2],axis=1)
    return df

# %%
vgg_row = result_df(transfer_vgg_model, test_ds, y_test, 'vgg_19')
vgg_row
# Out:
#     model  top_1_acc  top_5_acc  precision        f1  trainable_params  \
# 0  vgg_19   0.790493   0.987676   0.827645  0.790529           2638924
#
#    nontrainable_params  auc_CommonBuzzard  auc_CommonKestrel  auc_CommonSnipe  \
# 0             14714688           0.974413           0.978928         0.956504
#
#    auc_EurasianCurlew  auc_EuropeanHerringGull  auc_EuropeanRobin  \
# 0            0.988131                 0.986097           0.998946
#
#    auc_MeadowPipit  auc_MuteSwan  auc_NorthernLapwing  auc_Rook  \
# 0         0.977788      0.973034             0.983461  0.998325
#
#    auc_TundraSwan  auc_TundraSwan(Bewicks)
# 0        0.976564                 0.988567

# %%
resnet_row = result_df(transfer_resnet_model, test_ds, y_test, 'resnet_50')
resnet_row
# Out:
#        model  top_1_acc  top_5_acc  precision        f1  trainable_params  \
# 0  resnet_50   0.663732   0.924296   0.703638  0.657282          12600396
#
#    nontrainable_params  auc_CommonBuzzard  auc_CommonKestrel  auc_CommonSnipe  \
# 0             23587712           0.911562           0.961612         0.898361
#
#    auc_EurasianCurlew  auc_EuropeanHerringGull  auc_EuropeanRobin  \
# 0            0.938864                 0.969911           0.991412
#
#    auc_MeadowPipit  auc_MuteSwan  auc_NorthernLapwing  auc_Rook  \
# 0         0.963159      0.934729             0.924497  0.973288
#
#    auc_TundraSwan  auc_TundraSwan(Bewicks)
# 0        0.941609                 0.941398

# %%
#c_model = concat_model(input_shape, num_channels = len(xs_tmp), num_classes = len(categories))

# %%
small_cnn = main_cnn(spec.shape, num_labels)

# %%
smallcnn_history = small_cnn.fit(train_ds,
                    validation_data = test_ds,
                    epochs          = 15)
# Out:
# Epoch 1/15
# 71/71 [==============================] - 35s 480ms/step - loss: 2.5657 - accuracy: 0.1853 - val_loss: 2.3076 - val_accuracy: 0.3310
# Epoch 2/15
# 71/71 [==============================] - 14s 200ms/step - loss: 2.3374 - accuracy: 0.2680 - val_loss: 2.1604 - val_accuracy: 0.3574
# Epoch 3/15
# 71/71 [==============================] - 15s 209ms/step - loss: 2.1897 - accuracy: 0.3116 - val_loss: 2.0333 - val_accuracy: 0.3979
# Epoch 4/15
# 71/71 [==============================] - 15s 214ms/step - loss: 2.0704 - accuracy: 0.3460 - val_loss: 1.9239 - val_accuracy: 0.4137
# Epoch 5/15
# 71/71 [==============================] - 14s 202ms/step - loss: 1.9642 - accuracy: 0.3886 - val_loss: 1.8267 - val_accuracy: 0.4472
# Epoch 6/15
# 71/71 [==============================] - 15s 217ms/step - loss: 1.8737 - accuracy: 0.4221 - val_loss: 1.7415 - val_accuracy: 0.4930
# Epoch 7/15
# 71/71 [==============================] - 16s 230ms/step - loss: 1.8060 - accuracy: 0.4335 - val_loss: 1.6877 - val_accuracy: 0.5158
# Epoch 8/15
# 71/71 [==============================] - 16s 228ms/step - loss: 1.7301 - accuracy: 0.4648 - val_loss: 1.6202 - val_accuracy: 0.5405
# Epoch 9/15
# 71/71 [==============================] - 16s 228ms/step - loss: 1.6724 - accuracy: 0.4864 - val_loss: 1.5612 - val_accuracy: 0.5687
# Epoch 10/15
# 71/71 [==============================] - 17s 233ms/step - loss: 1.6028 - accuracy: 0.5136 - val_loss: 1.5173 - val_accuracy: 0.5634
# Epoch 11/15
# 71/71 [==============================] - 17s 234ms/step - loss: 1.5531 - accuracy: 0.5374 - val_loss: 1.4779 - val_accuracy: 0.5915
# Epoch 12/15
# 71/71 [==============================] - 16s 229ms/step - loss: 1.5221 - accuracy: 0.5414 - val_loss: 1.4599 - val_accuracy: 0.5986
# Epoch 13/15
# 71/71 [==============================] - 16s 223ms/step - loss: 1.4691 - accuracy: 0.5484 - val_loss: 1.4371 - val_accuracy: 0.6215
# Epoch 14/15
# 71/71 [==============================] - 16s 222ms/step - loss: 1.4443 - accuracy: 0.5704 - val_loss: 1.4002 - val_accuracy: 0.6074
# Epoch 15/15
# 71/71 [==============================] - 15s 212ms/step - loss: 1.4062 - accuracy: 0.5889 - val_loss: 1.3678 - val_accuracy: 0.6215

# %%
small_cnn.save('models/'+datetime.now().strftime("%Y%m%d-%H%M%S").replace('-', '_')+'_'+data_dir+'_smallcnn'+'.h5')

# %%
smallcnn_row = result_df(small_cnn, test_ds, y_test, 'small_cnn')
smallcnn_row
# Out:
#        model  top_1_acc  top_5_acc  precision        f1  trainable_params  \
# 0  small_cnn   0.621479   0.931338   0.680576  0.635369            610364
#
#    nontrainable_params  auc_CommonBuzzard  auc_CommonKestrel  auc_CommonSnipe  \
# 0                    0           0.922192           0.898967         0.839076
#
#    auc_EurasianCurlew  auc_EuropeanHerringGull  auc_EuropeanRobin  \
# 0            0.951816                  0.86569            0.95452
#
#    auc_MeadowPipit  auc_MuteSwan  auc_NorthernLapwing  auc_Rook  \
# 0         0.958793      0.920355             0.917077  0.973628
#
#    auc_TundraSwan  auc_TundraSwan(Bewicks)
# 0        0.936643                 0.939139

# %%
choices = ['AbsRe', 'AbsIm', 'Re', 'Im', 'Mod']
train_ds_mult = preprocess_dataset(train_files, choices, categories, req_width=750, resize = 4)
test_ds_mult  = preprocess_dataset(test_files,  choices, categories, req_width=750, resize = 4)

# %%
x_tmp  = [x for x,y in train_ds_mult]
x_tmp  = tf.stack(x_tmp)
xs_tmp = tf.unstack(x_tmp, axis=-1)
xs_tmp = [tf.expand_dims(x_ind, axis=-1) for x_ind in xs_tmp]

x_tmp_test  = [x for x,y in test_ds_mult]
x_tmp_test  = tf.stack(x_tmp_test)
xs_tmp_test = tf.unstack(x_tmp_test, axis=-1)
xs_tmp_test = [tf.expand_dims(x_ind, axis=-1) for x_ind in xs_tmp_test]

y_train = np.array([y for x,y in train_ds_mult])
y_test  = np.array([y for x,y in test_ds_mult])

# %%
num_channels = len(xs_tmp)

# %%
model = concat_model(xs_tmp[0].shape[1:], num_channels = len(xs_tmp), num_classes = len(categories))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 187, 1) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 128, 187, 1) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 128, 187, 1) 0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 128, 187, 1) 0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 128, 187, 1) 0
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 126, 185, 16) 160         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 126, 185, 16) 160         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 126, 185, 16) 160         input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 126, 185, 16) 160         input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 126, 185, 16) 160         input_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 63, 92, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 63, 92, 16)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 63, 92, 16)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 63, 92, 16)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 63, 92, 16)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 61, 90, 16)   2320        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 61, 90, 16)   2320        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 61, 90, 16)   2320        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 61, 90, 16)   2320        max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 61, 90, 16)   2320        max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 30, 45, 16)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 30, 45, 16)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 30, 45, 16)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 30, 45, 16)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 30, 45, 16)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 43, 32)   4640        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 43, 32)   4640        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 43, 32)   4640        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 43, 32)   4640        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 43, 32)   4640        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 21, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 21, 32)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 14, 21, 32)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 14, 21, 32)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 14, 21, 32)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 9408)         0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 9408)         0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 9408)         0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 9408)         0           max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 9408)         0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 47040)        0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 47040)        0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           3010624     dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 12)           780         dropout_3[0][0]
# ==================================================================================================
# Total params: 3,047,004
# Trainable params: 3,047,004
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
concat_history = model.fit(xs_tmp, y_train,
                    validation_data = (xs_tmp_test, y_test),
                    epochs          = 15,
                    batch_size      = 32)
# Out:
# Epoch 1/15
# 71/71 [==============================] - 60s 824ms/step - loss: 2.3213 - accuracy: 0.2909 - val_loss: 1.9677 - val_accuracy: 0.4120
# Epoch 2/15
# 71/71 [==============================] - 57s 803ms/step - loss: 1.9793 - accuracy: 0.4005 - val_loss: 1.7488 - val_accuracy: 0.5035
# Epoch 3/15
# 71/71 [==============================] - 61s 856ms/step - loss: 1.7803 - accuracy: 0.4635 - val_loss: 1.6071 - val_accuracy: 0.5616
# Epoch 4/15
# 71/71 [==============================] - 59s 835ms/step - loss: 1.6387 - accuracy: 0.5106 - val_loss: 1.5063 - val_accuracy: 0.5898
# Epoch 5/15
# 71/71 [==============================] - 58s 820ms/step - loss: 1.5399 - accuracy: 0.5440 - val_loss: 1.4480 - val_accuracy: 0.6004
# Epoch 6/15
# 71/71 [==============================] - 58s 819ms/step - loss: 1.4435 - accuracy: 0.5915 - val_loss: 1.3913 - val_accuracy: 0.6303
# Epoch 7/15
# 71/71 [==============================] - 60s 843ms/step - loss: 1.3695 - accuracy: 0.6021 - val_loss: 1.3404 - val_accuracy: 0.6373
# Epoch 8/15
# 71/71 [==============================] - 58s 822ms/step - loss: 1.2796 - accuracy: 0.6272 - val_loss: 1.3161 - val_accuracy: 0.6408
# Epoch 9/15
# 71/71 [==============================] - 59s 825ms/step - loss: 1.2607 - accuracy: 0.6448 - val_loss: 1.2832 - val_accuracy: 0.6637
# Epoch 10/15
# 71/71 [==============================] - 58s 817ms/step - loss: 1.2009 - accuracy: 0.6695 - val_loss: 1.2784 - val_accuracy: 0.6567
# Epoch 11/15
# 71/71 [==============================] - 58s 819ms/step - loss: 1.1528 - accuracy: 0.6761 - val_loss: 1.2682 - val_accuracy: 0.6655
# Epoch 12/15
# 71/71 [==============================] - 62s 868ms/step - loss: 1.1374 - accuracy: 0.6681 - val_loss: 1.2478 - val_accuracy: 0.6725
# Epoch 13/15
# 71/71 [==============================] - 63s 891ms/step - loss: 1.0825 - accuracy: 0.6950 - val_loss: 1.2506 - val_accuracy: 0.6725
# Epoch 14/15
# 71/71 [==============================] - 63s 892ms/step - loss: 1.0142 - accuracy: 0.7143 - val_loss: 1.2244 - val_accuracy: 0.6831
# Epoch 15/15
# 71/71 [==============================] - 57s 806ms/step - loss: 1.0070 - accuracy: 0.7055 - val_loss: 1.2333 - val_accuracy: 0.6901

# %%
model.save('models/'+datetime.now().strftime("%Y%m%d-%H%M%S").replace('-', '_')+'_'+data_dir+'_concat'+'.h5')

# %%
concat_row = result_df(model, xs_tmp_test, y_test, 'concat')
concat_row
# Out:
#     model  top_1_acc  top_5_acc  precision        f1  trainable_params  \
# 0  concat   0.690141   0.950704   0.699391  0.691294           3047004
#
#    nontrainable_params  auc_CommonBuzzard  auc_CommonKestrel  auc_CommonSnipe  \
# 0                    0            0.93715           0.939437         0.923635
#
#    auc_EurasianCurlew  auc_EuropeanHerringGull  auc_EuropeanRobin  \
# 0            0.947568                 0.876564           0.938306
#
#    auc_MeadowPipit  auc_MuteSwan  auc_NorthernLapwing  auc_Rook  \
# 0         0.964384      0.943945             0.910337  0.984607
#
#    auc_TundraSwan  auc_TundraSwan(Bewicks)
# 0        0.952681                 0.946122

# %%
pd.concat([vgg_row, resnet_row, smallcnn_row, concat_row], axis=0)
# Out:
#        model  top_1_acc  top_5_acc  precision        f1  trainable_params  \
# 0     vgg_19   0.790493   0.987676   0.827645  0.790529           2638924
# 0  resnet_50   0.663732   0.924296   0.703638  0.657282          12600396
# 0  small_cnn   0.621479   0.931338   0.680576  0.635369            610364
# 0     concat   0.690141   0.950704   0.699391  0.691294           3047004
#
#    nontrainable_params  auc_CommonBuzzard  auc_CommonKestrel  auc_CommonSnipe  \
# 0             14714688           0.974413           0.978928         0.956504
# 0             23587712           0.911562           0.961612         0.898361
# 0                    0           0.922192           0.898967         0.839076
# 0                    0           0.937150           0.939437         0.923635
#
#    auc_EurasianCurlew  auc_EuropeanHerringGull  auc_EuropeanRobin  \
# 0            0.988131                 0.986097           0.998946
# 0            0.938864                 0.969911           0.991412
# 0            0.951816                 0.865690           0.954520
# 0            0.947568                 0.876564           0.938306
#
#    auc_MeadowPipit  auc_MuteSwan  auc_NorthernLapwing  auc_Rook  \
# 0         0.977788      0.973034             0.983461  0.998325
# 0         0.963159      0.934729             0.924497  0.973288
# 0         0.958793      0.920355             0.917077  0.973628
# 0         0.964384      0.943945             0.910337  0.984607
#
#    auc_TundraSwan  auc_TundraSwan(Bewicks)
# 0        0.976564                 0.988567
# 0        0.941609                 0.941398
# 0        0.936643                 0.939139
# 0        0.952681                 0.946122

# %%
model2 = concat_model2(xs_tmp[0].shape[1:], num_channels = len(xs_tmp), num_classes = len(categories))
model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 128, 187, 1) 0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 128, 187, 1) 0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 128, 187, 1) 0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 128, 187, 1) 0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 128, 187, 1) 0
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 126, 185, 16) 160         input_7[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 126, 185, 16) 160         input_8[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 126, 185, 16) 160         input_9[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 126, 185, 16) 160         input_10[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 126, 185, 16) 160         input_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 63, 92, 16)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 63, 92, 16)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 63, 92, 16)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 63, 92, 16)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 63, 92, 16)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 61, 90, 16)   2320        max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 61, 90, 16)   2320        max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 61, 90, 16)   2320        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 61, 90, 16)   2320        max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 61, 90, 16)   2320        max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 30, 45, 16)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 30, 45, 16)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 30, 45, 16)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 30, 45, 16)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 30, 45, 16)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 45, 80)   0           max_pooling2d_19[0][0]
#                                                                  max_pooling2d_21[0][0]
#                                                                  max_pooling2d_23[0][0]
#                                                                  max_pooling2d_25[0][0]
#                                                                  max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 43, 64)   46144       concatenate_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 14, 21, 64)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 12, 19, 64)   36928       max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 6, 9, 64)     0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 3456)         0           max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 3456)         0           flatten_6[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           221248      dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 12)           780         dropout_5[0][0]
# ==================================================================================================
# Total params: 317,500
# Trainable params: 317,500
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
concat_history2 = model2.fit(xs_tmp, y_train,
                    validation_data = (xs_tmp_test, y_test),
                    epochs          = 15,
                    batch_size      = 32)
# Out:
# Epoch 1/15
# 71/71 [==============================] - 60s 833ms/step - loss: 2.5485 - accuracy: 0.1615 - val_loss: 2.3822 - val_accuracy: 0.2958
# Epoch 2/15
# 71/71 [==============================] - 56s 789ms/step - loss: 2.3721 - accuracy: 0.2526 - val_loss: 2.2044 - val_accuracy: 0.3292
# Epoch 3/15
# 71/71 [==============================] - 56s 795ms/step - loss: 2.2337 - accuracy: 0.3169 - val_loss: 2.0825 - val_accuracy: 0.3556
# Epoch 4/15
# 71/71 [==============================] - 56s 792ms/step - loss: 2.1257 - accuracy: 0.3341 - val_loss: 1.9432 - val_accuracy: 0.4102
# Epoch 5/15
# 71/71 [==============================] - 54s 761ms/step - loss: 1.9970 - accuracy: 0.3860 - val_loss: 1.8445 - val_accuracy: 0.4613
# Epoch 6/15
# 71/71 [==============================] - 57s 799ms/step - loss: 1.9174 - accuracy: 0.3979 - val_loss: 1.7423 - val_accuracy: 0.4665
# Epoch 7/15
# 71/71 [==============================] - 56s 790ms/step - loss: 1.8186 - accuracy: 0.4371 - val_loss: 1.6948 - val_accuracy: 0.4877
# Epoch 8/15
# 71/71 [==============================] - 56s 790ms/step - loss: 1.7729 - accuracy: 0.4652 - val_loss: 1.6270 - val_accuracy: 0.5458
# Epoch 9/15
# 71/71 [==============================] - 56s 796ms/step - loss: 1.7194 - accuracy: 0.4705 - val_loss: 1.5969 - val_accuracy: 0.5616
# Epoch 10/15
# 71/71 [==============================] - 57s 807ms/step - loss: 1.6363 - accuracy: 0.4974 - val_loss: 1.5297 - val_accuracy: 0.5722
# Epoch 11/15
# 71/71 [==============================] - 57s 807ms/step - loss: 1.6285 - accuracy: 0.5088 - val_loss: 1.4939 - val_accuracy: 0.5898
# Epoch 12/15
# 71/71 [==============================] - 59s 837ms/step - loss: 1.5631 - accuracy: 0.5172 - val_loss: 1.4407 - val_accuracy: 0.5915
# Epoch 13/15
# 71/71 [==============================] - 57s 801ms/step - loss: 1.5387 - accuracy: 0.5383 - val_loss: 1.4177 - val_accuracy: 0.6127
# Epoch 14/15
# 71/71 [==============================] - 56s 794ms/step - loss: 1.4598 - accuracy: 0.5656 - val_loss: 1.3800 - val_accuracy: 0.6215
# Epoch 15/15
# 71/71 [==============================] - 58s 817ms/step - loss: 1.4719 - accuracy: 0.5599 - val_loss: 1.3569 - val_accuracy: 0.6338

# %%
model2.save('models/'+datetime.now().strftime("%Y%m%d-%H%M%S").replace('-', '_')+'_'+data_dir+'_concat2'+'.h5')

# %%
concat_row2 = result_df(model2, xs_tmp_test, y_test, 'concat2')
concat_row2
# Out:
#      model  top_1_acc  top_5_acc  precision        f1  trainable_params  \
# 0  concat2   0.633803   0.945423   0.689297  0.647392            317500
#
#    nontrainable_params  auc_CommonBuzzard  auc_CommonKestrel  auc_CommonSnipe  \
# 0                    0           0.888995           0.949851         0.863406
#
#    auc_EurasianCurlew  auc_EuropeanHerringGull  auc_EuropeanRobin  \
# 0             0.95015                 0.881678           0.971478
#
#    auc_MeadowPipit  auc_MuteSwan  auc_NorthernLapwing  auc_Rook  \
# 0          0.93727      0.924072             0.902351  0.974375
#
#    auc_TundraSwan  auc_TundraSwan(Bewicks)
# 0        0.942205                 0.911823

# %%
res_df = pd.concat([vgg_row, resnet_row, smallcnn_row, concat_row, concat_row2], axis=0)
res_df
# Out:
#        model  top_1_acc  top_5_acc  precision        f1  trainable_params  \
# 0     vgg_19   0.790493   0.987676   0.827645  0.790529           2638924
# 0  resnet_50   0.663732   0.924296   0.703638  0.657282          12600396
# 0  small_cnn   0.621479   0.931338   0.680576  0.635369            610364
# 0     concat   0.690141   0.950704   0.699391  0.691294           3047004
# 0    concat2   0.633803   0.945423   0.689297  0.647392            317500
#
#    nontrainable_params  auc_CommonBuzzard  auc_CommonKestrel  auc_CommonSnipe  \
# 0             14714688           0.974413           0.978928         0.956504
# 0             23587712           0.911562           0.961612         0.898361
# 0                    0           0.922192           0.898967         0.839076
# 0                    0           0.937150           0.939437         0.923635
# 0                    0           0.888995           0.949851         0.863406
#
#    auc_EurasianCurlew  auc_EuropeanHerringGull  auc_EuropeanRobin  \
# 0            0.988131                 0.986097           0.998946
# 0            0.938864                 0.969911           0.991412
# 0            0.951816                 0.865690           0.954520
# 0            0.947568                 0.876564           0.938306
# 0            0.950150                 0.881678           0.971478
#
#    auc_MeadowPipit  auc_MuteSwan  auc_NorthernLapwing  auc_Rook  \
# 0         0.977788      0.973034             0.983461  0.998325
# 0         0.963159      0.934729             0.924497  0.973288
# 0         0.958793      0.920355             0.917077  0.973628
# 0         0.964384      0.943945             0.910337  0.984607
# 0         0.937270      0.924072             0.902351  0.974375
#
#    auc_TundraSwan  auc_TundraSwan(Bewicks)
# 0        0.976564                 0.988567
# 0        0.941609                 0.941398
# 0        0.936643                 0.939139
# 0        0.952681                 0.946122
# 0        0.942205                 0.911823

# %%
res_df_t = res_df.transpose()
res_df_t.columns = res_df_t.iloc[0]
res_df_t = res_df_t.drop(res_df_t.index[0])
res_df_t
# Out:
# model                      vgg_19 resnet_50 small_cnn    concat   concat2
# top_1_acc                0.790493  0.663732  0.621479  0.690141  0.633803
# top_5_acc                0.987676  0.924296  0.931338  0.950704  0.945423
# precision                0.827645  0.703638  0.680576  0.699391  0.689297
# f1                       0.790529  0.657282  0.635369  0.691294  0.647392
# trainable_params          2638924  12600396    610364   3047004    317500
# nontrainable_params      14714688  23587712         0         0         0
# auc_CommonBuzzard        0.974413  0.911562  0.922192   0.93715  0.888995
# auc_CommonKestrel        0.978928  0.961612  0.898967  0.939437  0.949851
# auc_CommonSnipe          0.956504  0.898361  0.839076  0.923635  0.863406
# auc_EurasianCurlew       0.988131  0.938864  0.951816  0.947568   0.95015
# auc_EuropeanHerringGull  0.986097  0.969911   0.86569  0.876564  0.881678
# auc_EuropeanRobin        0.998946  0.991412   0.95452  0.938306  0.971478
# auc_MeadowPipit          0.977788  0.963159  0.958793  0.964384   0.93727
# auc_MuteSwan             0.973034  0.934729  0.920355  0.943945  0.924072
# auc_NorthernLapwing      0.983461  0.924497  0.917077  0.910337  0.902351
# auc_Rook                 0.998325  0.973288  0.973628  0.984607  0.974375
# auc_TundraSwan           0.976564  0.941609  0.936643  0.952681  0.942205
# auc_TundraSwan(Bewicks)  0.988567  0.941398  0.939139  0.946122  0.911823

# %%
print(res_df_t.to_latex(bold_rows = True))
# Out:
# \begin{tabular}{llllll}
# \toprule
# \textbf{model} &    vgg\_19 & resnet\_50 & small\_cnn &    concat &   concat2 \\
# \midrule
# \textbf{top\_1\_acc              } &  0.790493 &  0.663732 &  0.621479 &  0.690141 &  0.633803 \\
# \textbf{top\_5\_acc              } &  0.987676 &  0.924296 &  0.931338 &  0.950704 &  0.945423 \\
# \textbf{precision              } &  0.827645 &  0.703638 &  0.680576 &  0.699391 &  0.689297 \\
# \textbf{f1                     } &  0.790529 &  0.657282 &  0.635369 &  0.691294 &  0.647392 \\
# \textbf{trainable\_params       } &   2638924 &  12600396 &    610364 &   3047004 &    317500 \\
# \textbf{nontrainable\_params    } &  14714688 &  23587712 &         0 &         0 &         0 \\
# \textbf{auc\_CommonBuzzard      } &  0.974413 &  0.911562 &  0.922192 &   0.93715 &  0.888995 \\
# \textbf{auc\_CommonKestrel      } &  0.978928 &  0.961612 &  0.898967 &  0.939437 &  0.949851 \\
# \textbf{auc\_CommonSnipe        } &  0.956504 &  0.898361 &  0.839076 &  0.923635 &  0.863406 \\
# \textbf{auc\_EurasianCurlew     } &  0.988131 &  0.938864 &  0.951816 &  0.947568 &   0.95015 \\
# \textbf{auc\_EuropeanHerringGull} &  0.986097 &  0.969911 &   0.86569 &  0.876564 &  0.881678 \\
# \textbf{auc\_EuropeanRobin      } &  0.998946 &  0.991412 &   0.95452 &  0.938306 &  0.971478 \\
# \textbf{auc\_MeadowPipit        } &  0.977788 &  0.963159 &  0.958793 &  0.964384 &   0.93727 \\
# \textbf{auc\_MuteSwan           } &  0.973034 &  0.934729 &  0.920355 &  0.943945 &  0.924072 \\
# \textbf{auc\_NorthernLapwing    } &  0.983461 &  0.924497 &  0.917077 &  0.910337 &  0.902351 \\
# \textbf{auc\_Rook               } &  0.998325 &  0.973288 &  0.973628 &  0.984607 &  0.974375 \\
# \textbf{auc\_TundraSwan         } &  0.976564 &  0.941609 &  0.936643 &  0.952681 &  0.942205 \\
# \textbf{auc\_TundraSwan(Bewicks)} &  0.988567 &  0.941398 &  0.939139 &  0.946122 &  0.911823 \\
# \bottomrule
# \end{tabular}
